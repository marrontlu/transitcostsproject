# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### First we import and cleanup data. There is the costs database, countries, GDPs and regions that need to be joined.

# %%
#read cleaned up database
df = pd.read_excel(r"C:\Users\elife\Documents\NYU\CCP\ANALYSIS\240226_update_charts\240226_merged_costs.xlsx", sheet_name="Sheet1")
#read population, region and gdp data
ct = pd.read_csv(r"C:\Users\elife\Documents\NYU\CCP\countries_continents.csv")
gdp=pd.read_csv(r"C:\Users\elife\Documents\NYU\CCP\world bank statistics\gdp2020.csv")

# %%
#take fields that we will use
df=df[['Country','City','Phase','Line','Start year','End year','Length','TunnelPer','Tunnel','Stations','Real cost (2021 dollars)','Cost/km (2021 dollars)']]

# %%
#take columns we need, rename column to join with df
ct=ct[['ISO-3166', 'Country','Population','Region']]
ct = ct.rename({'ISO-3166': 'CO'}, axis='columns')
ct.head()
# Out:
#    CO       Country  Population  Region
# 0  AO        Angola  30,809,762  Africa
# 1  BF  Burkina Faso  19,751,535  Africa
# 2  BI       Burundi  11,175,378  Africa
# 3  BJ         Benin  11,485,048  Africa
# 4  BW      Botswana   2,254,126  Africa

# %%
df['Country'].nunique() #number of countries in database
# Out:
# 59

# %%
gdp = gdp.rename({'Country Name': 'Country','2020':'GDP in $'}, axis='columns')
gdp['GDP in $']=gdp['GDP in $'].round(0)
gdp['GDP in $']=gdp.apply(lambda x: "{:,}".format(x['GDP in $']), axis=1)

# %%
#take only lines with a country column value and count
df=df.dropna(how='all', subset=['Country'])
len(df)
# Out:
# 944

# %%
#remove all rows with no or 0.0 cost value
df=df.dropna(axis=0,how='all', subset=['Cost/km (2021 dollars)'])
df=df.loc[~((df['Cost/km (2021 dollars)'] == 0))]

# %%
median_cost=df['Cost/km (2021 dollars)'].median()
median_cost
# Out:
# 188.31137344515625

# %%
mean_cost=df['Cost/km (2021 dollars)'].mean()
mean_cost
# Out:
# 243.5552483380065

# %%
#30% of cost data
df['Cost/km (2021 dollars)'].quantile(0.05)
# Out:
# 81.3450389282798

# %%
len(df)
# Out:
# 883

# %%
df = df.rename({'Country': 'CO'}, axis='columns')

# %%
len(df)
# Out:
# 883

# %%
#combine all data
df=pd.merge(df, ct)

# %%
df['Country'].nunique()
# Out:
# 59

# %%
df=pd.merge(df, gdp)

# %%
df['Country'].nunique()
# Out:
# 59

# %%
df['City'].nunique()
# Out:
# 187

# %%
#replace "4 years","5 years", "?", "not started" values in column "Start year" with Nan, use a dictionary
df['Start year']=df['Start year'].replace(['4 years','5 years','?','not started',"X"],np.nan)

# %%
#replace "X" with Nan
df['End year']=df['End year'].replace(['X'],np.nan)
df['End year']=df['End year'].replace(['by 2026'], 2026)

# %% [markdown]
# #### Here we have all data in one dataframe. Now we need to create one group where all phases of one project is a single entry.

# %%
#defining the aggregate functions for group by per project (we will group the different phases of projects into single projects)
agg_functions={'Country':'first', 'City':'first','Line':'first','Phase':'count','Start year':'min', 'End year':'max','Length':'sum','Tunnel':'sum','Stations':'sum','Real cost (2021 dollars)':'sum', 'Population':'first','Region':'first','GDP in $':'first'}

# %%
#We are grouping the different phases of projects into single projects)
df_gr=df.groupby(['City','Line'], as_index=False).aggregate(agg_functions)
df_gr = df_gr.rename({'Phase':'Phases'}, axis='columns')
len(df_gr) #this gives us how many groups are created
# Out:
# 684

# %%
df_gr[df_gr['City']=='Istanbul']
# Out:
#     Country      City       Line  Phases  Start year  End year  Length  \
# 251  Turkey  Istanbul         M1       2      1987.0    2027.0   36.30
# 252  Turkey  Istanbul        M11       2      2016.0    2022.0   69.50
# 253  Turkey  Istanbul        M12       1      2017.0    2023.0   13.00
# 254  Turkey  Istanbul         M2       1      1992.0    2014.0   23.50
# 255  Turkey  Istanbul         M3       3      2006.0    2023.0   31.20
# 256  Turkey  Istanbul         M4       3      2005.0    2022.0   33.60
# 257  Turkey  Istanbul  M4 P4-M10       1      2017.0    2024.0   14.00
# 258  Turkey  Istanbul         M5       2      2011.0    2027.0   37.50
# 259  Turkey  Istanbul         M6       1      2013.0    2015.0    3.30
# 260  Turkey  Istanbul         M7       2      2014.0    2027.0   42.25
# 261  Turkey  Istanbul         M8       1      2016.0    2022.0   14.30
# 262  Turkey  Istanbul         M9       1      2016.0    2023.0   13.40
# 263  Turkey  Istanbul   Marmaray       2      2004.0    2019.0   76.60
#
#      Tunnel  Stations  Real cost (2021 dollars)  Population       Region  \
# 251   19.00        33               5769.026586  82,319,724  Middle East
# 252   69.50        16               6757.861508  82,319,724  Middle East
# 253   13.00        11               2411.614259  82,319,724  Middle East
# 254   21.50        17               7392.768478  82,319,724  Middle East
# 255   30.50        23               4442.449719  82,319,724  Middle East
# 256   33.60        23               3736.576528  82,319,724  Middle East
# 257   14.00         8               1188.531956  82,319,724  Middle East
# 258   37.50        29               4366.184309  82,319,724  Middle East
# 259    3.30         4                285.236398  82,319,724  Middle East
# 260   40.85        30               5945.749869  82,319,724  Middle East
# 261   14.30        11               2019.103134  82,319,724  Middle East
# 262   13.40        12               1336.061940  82,319,724  Middle East
# 263   13.60        40               7327.366933  82,319,724  Middle East
#
#      GDP in $
# 251  27,235.0
# 252  27,235.0
# 253  27,235.0
# 254  27,235.0
# 255  27,235.0
# 256  27,235.0
# 257  27,235.0
# 258  27,235.0
# 259  27,235.0
# 260  27,235.0
# 261  27,235.0
# 262  27,235.0
# 263  27,235.0

# %%
#Calculate Cost/km and tunnel percentage per project in the grouped section 
df_gr['Cost/km (2021 dollars)']=df_gr['Real cost (2021 dollars)']/df_gr['Length']
df_gr['TunnelPer']=df_gr['Tunnel']/df_gr['Length']
df_gr.sample(10)
# Out:
#         Country     City             Line  Phases  Start year  End year  \
# 135       China   Dalian           Line 1       1      2010.0    2021.0
# 140  Bangladesh    Dhaka           Line 1       1      2020.0    2026.0
# 656       China   Xiamen           Line 2       2      2015.0    2020.0
# 419       China  Qingdao  Line 1 + Line 7       1         NaN    2021.0
# 287     Ukraine     Kyiv               M3       1      2018.0    2022.0
# 46        China  Beijing   Yanfang Branch       1      2020.0       NaN
# 653       China    Xi'an           Line 8       1         NaN       NaN
# 374       China  Nanning           Line 5       1         NaN    2021.0
# 589       Japan    Tokyo    Tama Monorail       1      1991.0    2000.0
# 336       India   Mumbai           Line 3       1      2016.0    2022.0
#
#      Length  Tunnel  Stations  Real cost (2021 dollars)     Population  \
# 135  13.200    1.80         3               2040.344590  1,392,730,000
# 140  31.200   19.90        19              16819.520000    161,356,039
# 656  40.700   40.70        28               8117.636357  1,392,730,000
# 419  59.970   59.97        40               9557.610000  1,392,730,000
# 287   3.700    3.70         2                759.220854     44,622,516
# 46    6.015    0.00         3               1126.027236  1,392,730,000
# 653  50.000   50.00        35               9657.850424  1,392,730,000
# 374  20.220   20.22        17               3919.600000  1,392,730,000
# 589  16.000    0.00        19               2583.816299    126,529,100
# 336  33.500   33.50        27              15940.845743  1,352,617,328
#
#          Region  GDP in $  Cost/km (2021 dollars)  TunnelPer
# 135   East Asia  17,189.0              154.571560   0.136364
# 140  South Asia   5,995.0              539.087179   0.637821
# 656   East Asia  17,189.0              199.450525   1.000000
# 419   East Asia  17,189.0              159.373187   1.000000
# 287      Europe  13,087.0              205.194825   1.000000
# 46    East Asia  17,189.0              187.203198   0.000000
# 653   East Asia  17,189.0              193.157008   1.000000
# 374   East Asia  17,189.0              193.847676   1.000000
# 589   East Asia  42,100.0              161.488519   0.000000
# 336  South Asia   6,525.0              475.846142   1.000000

# %%
#Format the data
df_gr['Start year'] = df_gr['Start year'].astype( pd.Int64Dtype() )
df_gr['End year'] = df_gr['End year'].astype( pd.Int64Dtype() )
df_gr['Stations'] = df_gr['Stations'].astype( pd.Int64Dtype() )
df_gr['Real cost (2021 dollars)'] = df_gr['Real cost (2021 dollars)'].round(1)
df_gr["Cost/km (2021 dollars)"] = df_gr["Cost/km (2021 dollars)"].round(1)
df_gr["TunnelPer"] = df_gr["TunnelPer"].round(2)
df_gr['Tunnel Percentage']=(df_gr['TunnelPer']*100).astype(str)+" %"
df_gr['GDP in $'] = df_gr['GDP in $'].str.replace(",","").astype( float ).astype( pd.Int64Dtype() )
df_gr.head()
# Out:
#         Country       City                   Line  Phases  Start year  \
# 0  Saudi Arabia  Ad Dammam           Dammam Metro       1        2014
# 1        Turkey      Adana            First stage       1        1996
# 2         India  Ahmadabad                   Line       1        2015
# 3   Netherlands  Amsterdam  Amsterdam North South       1        2003
# 4        Turkey     Ankara                     M4       1        2003
#
#    End year  Length  Tunnel  Stations  Real cost (2021 dollars)  \
# 0      <NA>   50.00    0.00         0                   32269.5
# 1      2010   13.90    3.50        13                    1435.5
# 2      2023   40.00    6.40        33                    6326.5
# 3      2018    9.70    7.10         8                    5090.1
# 4      2017    9.22    9.22         9                    1366.9
#
#       Population       Region  GDP in $  Cost/km (2021 dollars)  TunnelPer  \
# 0     33,699,947  Middle East     46778                   645.4       0.00
# 1     82,319,724  Middle East     27235                   103.3       0.25
# 2  1,352,617,328   South Asia      6525                   158.2       0.16
# 3     17,231,017       Europe     59267                   524.7       0.73
# 4     82,319,724  Middle East     27235                   148.3       1.00
#
#   Tunnel Percentage
# 0             0.0 %
# 1            25.0 %
# 2            16.0 %
# 3            73.0 %
# 4           100.0 %

# %%
df_gr['Country'].nunique()
# Out:
# 59

# %%
#create json dictionary. This is the format the vega library reads data in. Add data-elif to the top because that is what our map jsons have at the top.
data_dict = df_gr.to_dict(
    orient= 'records'
)

data_dict = {
    "data-elif": data_dict
}

data_dict
# Out:
# {'data-elif': [{'Country': 'Saudi Arabia',
#    'City': 'Ad Dammam',
#    'Line': 'Dammam Metro',
#    'Phases': 1,
#    'Start year': 2014,
#    'End year': <NA>,
#    'Length': 50.0,
#    'Tunnel': 0.0,
#    'Stations': 0,
#    'Real cost (2021 dollars)': 32269.5,
#    'Population': '33,699,947',
#    'Region': 'Middle East',
#    'GDP in $': 46778,
#    'Cost/km (2021 dollars)': 645.4,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Turkey',
#    'City': 'Adana',
#    'Line': 'First stage',
#    'Phases': 1,
#    'Start year': 1996,
#    'End year': 2010,
#    'Length': 13.9,
#    'Tunnel': 3.5,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 1435.5,
#    'Population': '82,319,724',
#    'Region': 'Middle East',
#    'GDP in $': 27235,
#    'Cost/km (2021 dollars)': 103.3,
#    'TunnelPer': 0.25,
#    'Tunnel Percentage': '25.0 %'},
#   {'Country': 'India',
#    'City': 'Ahmadabad',
#    'Line': 'Line',
#    'Phases': 1,
#    'Start year': 2015,
#    'End year': 2023,
#    'Length': 40.0,
#    'Tunnel': 6.4,
#    'Stations': 33,
#    'Real cost (2021 dollars)': 6326.5,
#    'Population': '1,352,617,328',
#    'Region': 'South Asia',
#    'GDP in $': 6525,
#    'Cost/km (2021 dollars)': 158.2,
#    'TunnelPer': 0.16,
#    'Tunnel Percentage': '16.0 %'},
#   {'Country': 'Netherlands',
#    'City': 'Amsterdam',
#    'Line': 'Amsterdam North South',
#    'Phases': 1,
#    'Start year': 2003,
#    'End year': 2018,
#    'Length': 9.7,
#    'Tunnel': 7.1,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 5090.1,
#    'Population': '17,231,017',
#    'Region': 'Europe',
#    'GDP in $': 59267,
#    'Cost/km (2021 dollars)': 524.7,
#    'TunnelPer': 0.73,
#    'Tunnel Percentage': '73.0 %'},
#   {'Country': 'Turkey',
#    'City': 'Ankara',
#    'Line': 'M4',
#    'Phases': 1,
#    'Start year': 2003,
#    'End year': 2017,
#    'Length': 9.22,
#    'Tunnel': 9.22,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 1366.9,
#    'Population': '82,319,724',
#    'Region': 'Middle East',
#    'GDP in $': 27235,
#    'Cost/km (2021 dollars)': 148.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Greece',
#    'City': 'Athens',
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': 2012,
#    'End year': 2021,
#    'Length': 7.6,
#    'Tunnel': 7.6,
#    'Stations': 6,
#    'Real cost (2021 dollars)': 1089.0,
#    'Population': '10,727,668',
#    'Region': 'Europe',
#    'GDP in $': 27949,
#    'Cost/km (2021 dollars)': 143.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Greece',
#    'City': 'Athens',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2027,
#    'Length': 12.8,
#    'Tunnel': 12.8,
#    'Stations': 15,
#    'Real cost (2021 dollars)': 1726.4,
#    'Population': '10,727,668',
#    'Region': 'Europe',
#    'GDP in $': 27949,
#    'Cost/km (2021 dollars)': 134.9,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'New Zealand',
#    'City': 'Auckland',
#    'Line': 'City Rail Link',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2024,
#    'Length': 3.5,
#    'Tunnel': 3.5,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 3228.3,
#    'Population': '4,885,500',
#    'Region': 'Oceania',
#    'GDP in $': 44658,
#    'Cost/km (2021 dollars)': 922.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Bahrain',
#    'City': 'Bahrain',
#    'Line': 'Phase 1',
#    'Phases': 1,
#    'Start year': 2018,
#    'End year': 2023,
#    'Length': 28.6,
#    'Tunnel': 0.0,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 2400.7,
#    'Population': '1,569,439',
#    'Region': 'Middle East',
#    'GDP in $': 43821,
#    'Cost/km (2021 dollars)': 83.9,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Bahrain',
#    'City': 'Bahrain',
#    'Line': 'Phase 2',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 72.7,
#    'Tunnel': 0.0,
#    'Stations': 0,
#    'Real cost (2021 dollars)': 9320.0,
#    'Population': '1,569,439',
#    'Region': 'Middle East',
#    'GDP in $': 43821,
#    'Cost/km (2021 dollars)': 128.2,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'India',
#    'City': 'Bangalore',
#    'Line': 'Green line',
#    'Phases': 2,
#    'Start year': 2006,
#    'End year': 2024,
#    'Length': 116.2,
#    'Tunnel': 22.3,
#    'Stations': 103,
#    'Real cost (2021 dollars)': 26210.2,
#    'Population': '1,352,617,328',
#    'Region': 'South Asia',
#    'GDP in $': 6525,
#    'Cost/km (2021 dollars)': 225.6,
#    'TunnelPer': 0.19,
#    'Tunnel Percentage': '19.0 %'},
#   {'Country': 'Thailand',
#    'City': 'Bangkok',
#    'Line': 'Blue Line',
#    'Phases': 1,
#    'Start year': 2011,
#    'End year': 2020,
#    'Length': 26.9,
#    'Tunnel': 5.4,
#    'Stations': 19,
#    'Real cost (2021 dollars)': 6638.5,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Cost/km (2021 dollars)': 246.8,
#    'TunnelPer': 0.2,
#    'Tunnel Percentage': '20.0 %'},
#   {'Country': 'Thailand',
#    'City': 'Bangkok',
#    'Line': 'Brown Line',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 22.1,
#    'Tunnel': 0.0,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 4103.4,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Cost/km (2021 dollars)': 185.7,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Thailand',
#    'City': 'Bangkok',
#    'Line': 'Orange Line',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2025,
#    'Length': 35.9,
#    'Tunnel': 27.0,
#    'Stations': 28,
#    'Real cost (2021 dollars)': 19060.9,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Cost/km (2021 dollars)': 530.9,
#    'TunnelPer': 0.75,
#    'Tunnel Percentage': '75.0 %'},
#   {'Country': 'Thailand',
#    'City': 'Bangkok',
#    'Line': 'Pink Line',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2022,
#    'Length': 34.5,
#    'Tunnel': 0.0,
#    'Stations': 30,
#    'Real cost (2021 dollars)': 4869.9,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Cost/km (2021 dollars)': 141.2,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Thailand',
#    'City': 'Bangkok',
#    'Line': 'Sukhumvit Line',
#    'Phases': 2,
#    'Start year': 2012,
#    'End year': 2020,
#    'Length': 31.8,
#    'Tunnel': 0.0,
#    'Stations': 25,
#    'Real cost (2021 dollars)': 7761.1,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Cost/km (2021 dollars)': 244.1,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Thailand',
#    'City': 'Bangkok',
#    'Line': 'Yellow Line',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2022,
#    'Length': 30.4,
#    'Tunnel': 0.0,
#    'Stations': 23,
#    'Real cost (2021 dollars)': 4701.9,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Cost/km (2021 dollars)': 154.7,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Spain',
#    'City': 'Barcelona',
#    'Line': 'L2',
#    'Phases': 1,
#    'Start year': 2006,
#    'End year': 2010,
#    'Length': 0.7,
#    'Tunnel': 0.7,
#    'Stations': 1,
#    'Real cost (2021 dollars)': 110.1,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Cost/km (2021 dollars)': 157.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Spain',
#    'City': 'Barcelona',
#    'Line': 'L3',
#    'Phases': 1,
#    'Start year': 2001,
#    'End year': 2008,
#    'Length': 1.9,
#    'Tunnel': 1.9,
#    'Stations': 2,
#    'Real cost (2021 dollars)': 270.8,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Cost/km (2021 dollars)': 142.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Spain',
#    'City': 'Barcelona',
#    'Line': 'L5',
#    'Phases': 1,
#    'Start year': 2007,
#    'End year': 2010,
#    'Length': 2.5,
#    'Tunnel': 2.5,
#    'Stations': 3,
#    'Real cost (2021 dollars)': 503.4,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Cost/km (2021 dollars)': 201.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Spain',
#    'City': 'Barcelona',
#    'Line': 'L9/10',
#    'Phases': 1,
#    'Start year': 2003,
#    'End year': 2026,
#    'Length': 47.8,
#    'Tunnel': 43.7,
#    'Stations': 52,
#    'Real cost (2021 dollars)': 8859.5,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Cost/km (2021 dollars)': 185.3,
#    'TunnelPer': 0.91,
#    'Tunnel Percentage': '91.0 %'},
#   {'Country': 'Spain',
#    'City': 'Barcelona',
#    'Line': 'Sabadell tunnel',
#    'Phases': 1,
#    'Start year': 2006,
#    'End year': 2017,
#    'Length': 4.4,
#    'Tunnel': 4.4,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 673.4,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Cost/km (2021 dollars)': 153.0,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Spain',
#    'City': 'Barcelona',
#    'Line': 'Terrassa tunnel',
#    'Phases': 1,
#    'Start year': 2008,
#    'End year': 2015,
#    'Length': 4.5,
#    'Tunnel': 4.5,
#    'Stations': 3,
#    'Real cost (2021 dollars)': 628.0,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Cost/km (2021 dollars)': 139.6,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Capital Airport Express',
#    'Phases': 2,
#    'Start year': 2005,
#    'End year': 2020,
#    'Length': 29.93,
#    'Tunnel': 1.83,
#    'Stations': 5,
#    'Real cost (2021 dollars)': 764.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 25.5,
#    'TunnelPer': 0.06,
#    'Tunnel Percentage': '6.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Daxing Airport Express',
#    'Phases': 2,
#    'Start year': 2016,
#    'End year': 2019,
#    'Length': 47.5,
#    'Tunnel': 0.0,
#    'Stations': 5,
#    'Real cost (2021 dollars)': 8036.9,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 169.2,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Daxing Line',
#    'Phases': 1,
#    'Start year': 2007,
#    'End year': 2010,
#    'Length': 21.8,
#    'Tunnel': 17.5,
#    'Stations': 11,
#    'Real cost (2021 dollars)': 4756.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 218.2,
#    'TunnelPer': 0.8,
#    'Tunnel Percentage': '80.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 10',
#    'Phases': 1,
#    'Start year': 2003,
#    'End year': 2008,
#    'Length': 24.64,
#    'Tunnel': 24.64,
#    'Stations': 22,
#    'Real cost (2021 dollars)': 6689.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 271.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 11',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2021,
#    'Length': 4.2,
#    'Tunnel': 4.2,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 1430.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 340.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 12',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2021,
#    'Length': 29.2,
#    'Tunnel': 29.2,
#    'Stations': 21,
#    'Real cost (2021 dollars)': 9556.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 327.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 13',
#    'Phases': 3,
#    'Start year': 1999,
#    'End year': 2022,
#    'Length': 103.25,
#    'Tunnel': 28.5,
#    'Stations': 50,
#    'Real cost (2021 dollars)': 13154.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 127.4,
#    'TunnelPer': 0.28,
#    'Tunnel Percentage': '28.000000000000004 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 15',
#    'Phases': 1,
#    'Start year': 2009,
#    'End year': 2014,
#    'Length': 41.4,
#    'Tunnel': 27.7,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 6747.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 163.0,
#    'TunnelPer': 0.67,
#    'Tunnel Percentage': '67.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 16',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2021,
#    'Length': 49.8,
#    'Tunnel': 49.8,
#    'Stations': 29,
#    'Real cost (2021 dollars)': 15718.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 315.6,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 17',
#    'Phases': 1,
#    'Start year': 2015,
#    'End year': 2022,
#    'Length': 49.7,
#    'Tunnel': 49.7,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 12886.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 259.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 19',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2021,
#    'Length': 22.4,
#    'Tunnel': 22.4,
#    'Stations': 10,
#    'Real cost (2021 dollars)': 6542.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 292.1,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 22',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2022,
#    'Length': 78.6,
#    'Tunnel': 48.5,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 16126.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 205.2,
#    'TunnelPer': 0.62,
#    'Tunnel Percentage': '62.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 25',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2020,
#    'Length': 5.0,
#    'Tunnel': 0.0,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 1433.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 286.7,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 27',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2021,
#    'Length': 16.6,
#    'Tunnel': 0.0,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 4197.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 252.8,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 28',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2021,
#    'Length': 8.777,
#    'Tunnel': 8.777,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 3216.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 366.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': 2016,
#    'End year': 2021,
#    'Length': 37.4,
#    'Tunnel': 20.8,
#    'Stations': 27,
#    'Real cost (2021 dollars)': 12240.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 327.3,
#    'TunnelPer': 0.56,
#    'Tunnel Percentage': '56.00000000000001 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2004,
#    'End year': 2009,
#    'Length': 28.2,
#    'Tunnel': 26.837,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 7509.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 266.3,
#    'TunnelPer': 0.95,
#    'Tunnel Percentage': '95.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 5',
#    'Phases': 1,
#    'Start year': 2002,
#    'End year': 2007,
#    'Length': 27.6,
#    'Tunnel': 0.0,
#    'Stations': 23,
#    'Real cost (2021 dollars)': 6110.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 221.4,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 6',
#    'Phases': 2,
#    'Start year': 2008,
#    'End year': 2014,
#    'Length': 42.8,
#    'Tunnel': 42.8,
#    'Stations': 28,
#    'Real cost (2021 dollars)': 12343.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 288.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 7',
#    'Phases': 2,
#    'Start year': 2009,
#    'End year': 2020,
#    'Length': 40.9,
#    'Tunnel': 38.7,
#    'Stations': 30,
#    'Real cost (2021 dollars)': 9215.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 225.3,
#    'TunnelPer': 0.95,
#    'Tunnel Percentage': '95.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 8',
#    'Phases': 3,
#    'Start year': 2005,
#    'End year': 2018,
#    'Length': 14.256,
#    'Tunnel': 10.1646,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 3289.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 230.7,
#    'TunnelPer': 0.71,
#    'Tunnel Percentage': '71.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line 9',
#    'Phases': 1,
#    'Start year': 2007,
#    'End year': 2012,
#    'Length': 16.5,
#    'Tunnel': 16.5,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 4809.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 291.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Line M101',
#    'Phases': 1,
#    'Start year': 2022,
#    'End year': 2027,
#    'Length': 19.0,
#    'Tunnel': 19.0,
#    'Stations': 14,
#    'Real cost (2021 dollars)': 4482.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 235.9,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Beijing',
#    'Line': 'Yanfang Branch',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 6.015,
#    'Tunnel': 0.0,
#    'Stations': 3,
#    'Real cost (2021 dollars)': 1126.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 187.2,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Serbia',
#    'City': 'Belgrade',
#    'Line': 'Metro Line 1',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': 2026,
#    'Length': 22.0,
#    'Tunnel': 22.0,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 5490.0,
#    'Population': '6,982,084',
#    'Region': 'Europe',
#    'GDP in $': 19094,
#    'Cost/km (2021 dollars)': 249.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Serbia',
#    'City': 'Belgrade',
#    'Line': 'Metro Line 2',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': 2026,
#    'Length': 20.0,
#    'Tunnel': 20.0,
#    'Stations': 21,
#    'Real cost (2021 dollars)': 6710.0,
#    'Population': '6,982,084',
#    'Region': 'Europe',
#    'GDP in $': 19094,
#    'Cost/km (2021 dollars)': 335.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Germany',
#    'City': 'Berlin',
#    'Line': 'U2',
#    'Phases': 1,
#    'Start year': 1997,
#    'End year': 2000,
#    'Length': 0.8,
#    'Tunnel': 0.8,
#    'Stations': 1,
#    'Real cost (2021 dollars)': 116.7,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Cost/km (2021 dollars)': 145.9,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Germany',
#    'City': 'Berlin',
#    'Line': 'U5-U55 connection',
#    'Phases': 1,
#    'Start year': 2010,
#    'End year': 2020,
#    'Length': 2.2,
#    'Tunnel': 2.2,
#    'Stations': 3,
#    'Real cost (2021 dollars)': 780.3,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Cost/km (2021 dollars)': 354.7,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Germany',
#    'City': 'Berlin',
#    'Line': 'U55',
#    'Phases': 1,
#    'Start year': 2004,
#    'End year': 2009,
#    'Length': 1.8,
#    'Tunnel': 1.8,
#    'Stations': 3,
#    'Real cost (2021 dollars)': 559.1,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Cost/km (2021 dollars)': 310.6,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Germany',
#    'City': 'Berlin',
#    'Line': 'U7',
#    'Phases': 1,
#    'Start year': 1978,
#    'End year': 1984,
#    'Length': 4.9,
#    'Tunnel': 4.9,
#    'Stations': 5,
#    'Real cost (2021 dollars)': 1064.1,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Cost/km (2021 dollars)': 217.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Germany',
#    'City': 'Berlin',
#    'Line': 'U8',
#    'Phases': 1,
#    'Start year': 1985,
#    'End year': 1994,
#    'Length': 3.6,
#    'Tunnel': 3.6,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 707.8,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Cost/km (2021 dollars)': 196.6,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Germany',
#    'City': 'Berlin',
#    'Line': 'U9',
#    'Phases': 1,
#    'Start year': 1968,
#    'End year': 1974,
#    'Length': 1.5,
#    'Tunnel': 1.5,
#    'Stations': 2,
#    'Real cost (2021 dollars)': 308.0,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Cost/km (2021 dollars)': 205.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Spain',
#    'City': 'Bilbao',
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': 2007,
#    'End year': 2016,
#    'Length': 5.9,
#    'Tunnel': 5.6,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 436.9,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Cost/km (2021 dollars)': 74.1,
#    'TunnelPer': 0.95,
#    'Tunnel Percentage': '95.0 %'},
#   {'Country': 'United States',
#    'City': 'Boston',
#    'Line': 'Green Line',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2022,
#    'Length': 7.6,
#    'Tunnel': 0.0,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 2396.5,
#    'Population': '327,167,434',
#    'Region': 'N.America',
#    'GDP in $': 63028,
#    'Cost/km (2021 dollars)': 315.3,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Italy',
#    'City': 'Brescia',
#    'Line': 'Metro',
#    'Phases': 1,
#    'Start year': 2003,
#    'End year': 2013,
#    'Length': 13.7,
#    'Tunnel': 9.7,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 1171.5,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Cost/km (2021 dollars)': 85.5,
#    'TunnelPer': 0.71,
#    'Tunnel Percentage': '71.0 %'},
#   {'Country': 'Belgium',
#    'City': 'Brussels',
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': 2028,
#    'Length': 4.8,
#    'Tunnel': 4.8,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 3380.0,
#    'Population': '11,422,068',
#    'Region': 'Europe',
#    'GDP in $': 53070,
#    'Cost/km (2021 dollars)': 704.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Romania',
#    'City': 'Bucharest',
#    'Line': 'Line 5',
#    'Phases': 1,
#    'Start year': 2014,
#    'End year': 2019,
#    'Length': 6.9,
#    'Tunnel': 6.9,
#    'Stations': 10,
#    'Real cost (2021 dollars)': 2100.8,
#    'Population': '19,473,936',
#    'Region': 'Europe',
#    'GDP in $': 32202,
#    'Cost/km (2021 dollars)': 304.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Hungary',
#    'City': 'Budapest',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2006,
#    'End year': 2014,
#    'Length': 7.4,
#    'Tunnel': 7.4,
#    'Stations': 10,
#    'Real cost (2021 dollars)': 4448.5,
#    'Population': '9,768,785',
#    'Region': 'Europe',
#    'GDP in $': 33274,
#    'Cost/km (2021 dollars)': 601.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Argentina',
#    'City': 'Buenos Aires',
#    'Line': 'RER',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': 2026,
#    'Length': 20.0,
#    'Tunnel': 20.0,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 4646.0,
#    'Population': '44,494,502',
#    'Region': 'S.America',
#    'GDP in $': 20769,
#    'Cost/km (2021 dollars)': 232.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Turkey',
#    'City': 'Bursa',
#    'Line': 'Bursaray',
#    'Phases': 1,
#    'Start year': 1997,
#    'End year': 2014,
#    'Length': 39.0,
#    'Tunnel': 6.25,
#    'Stations': 38,
#    'Real cost (2021 dollars)': 1199.6,
#    'Population': '82,319,724',
#    'Region': 'Middle East',
#    'GDP in $': 27235,
#    'Cost/km (2021 dollars)': 30.8,
#    'TunnelPer': 0.16,
#    'Tunnel Percentage': '16.0 %'},
#   {'Country': 'South Korea',
#    'City': 'Busan',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2009,
#    'End year': 2017,
#    'Length': 8.0,
#    'Tunnel': 8.0,
#    'Stations': 6,
#    'Real cost (2021 dollars)': 1282.8,
#    'Population': '51,635,256',
#    'Region': 'East Asia',
#    'GDP in $': 45226,
#    'Cost/km (2021 dollars)': 160.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Egypt',
#    'City': 'Cairo',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 1982,
#    'End year': 1987,
#    'Length': 44.0,
#    'Tunnel': 6.3,
#    'Stations': 35,
#    'Real cost (2021 dollars)': 5802.2,
#    'Population': '98,423,595',
#    'Region': 'Middle East',
#    'GDP in $': 12606,
#    'Cost/km (2021 dollars)': 131.9,
#    'TunnelPer': 0.14,
#    'Tunnel Percentage': '14.000000000000002 %'},
#   {'Country': 'Egypt',
#    'City': 'Cairo',
#    'Line': 'Line 2',
#    'Phases': 1,
#    'Start year': 1993,
#    'End year': 2005,
#    'Length': 22.0,
#    'Tunnel': 9.5,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 13458.3,
#    'Population': '98,423,595',
#    'Region': 'Middle East',
#    'GDP in $': 12606,
#    'Cost/km (2021 dollars)': 611.7,
#    'TunnelPer': 0.43,
#    'Tunnel Percentage': '43.0 %'},
#   {'Country': 'Egypt',
#    'City': 'Cairo',
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': 2006,
#    'End year': 2012,
#    'Length': 4.3,
#    'Tunnel': 4.3,
#    'Stations': 5,
#    'Real cost (2021 dollars)': 3789.1,
#    'Population': '98,423,595',
#    'Region': 'Middle East',
#    'GDP in $': 12606,
#    'Cost/km (2021 dollars)': 881.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Egypt',
#    'City': 'Cairo',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': <NA>,
#    'Length': 19.0,
#    'Tunnel': 0.0,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 13736.3,
#    'Population': '98,423,595',
#    'Region': 'Middle East',
#    'GDP in $': 12606,
#    'Cost/km (2021 dollars)': 723.0,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'Egypt',
#    'City': 'Cairo',
#    'Line': 'Line 6',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': <NA>,
#    'Length': 21.0,
#    'Tunnel': 13.7,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 13707.7,
#    'Population': '98,423,595',
#    'Region': 'Middle East',
#    'GDP in $': 12606,
#    'Cost/km (2021 dollars)': 652.7,
#    'TunnelPer': 0.65,
#    'Tunnel Percentage': '65.0 %'},
#   {'Country': 'Canada',
#    'City': 'Calgary',
#    'Line': 'Green Line',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': 2027,
#    'Length': 20.0,
#    'Tunnel': 4.0,
#    'Stations': 15,
#    'Real cost (2021 dollars)': 4620.0,
#    'Population': '37,058,856',
#    'Region': 'N.America',
#    'GDP in $': 46572,
#    'Cost/km (2021 dollars)': 231.0,
#    'TunnelPer': 0.2,
#    'Tunnel Percentage': '20.0 %'},
#   {'Country': 'Italy',
#    'City': 'Catania',
#    'Line': 'Borgo-Nesima',
#    'Phases': 1,
#    'Start year': 2007,
#    'End year': 2017,
#    'Length': 3.1,
#    'Tunnel': 3.1,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 159.6,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Cost/km (2021 dollars)': 51.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Italy',
#    'City': 'Catania',
#    'Line': 'Galatea-Stesicoro',
#    'Phases': 1,
#    'Start year': 2001,
#    'End year': 2016,
#    'Length': 1.9,
#    'Tunnel': 1.9,
#    'Stations': 2,
#    'Real cost (2021 dollars)': 130.4,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Cost/km (2021 dollars)': 68.6,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Italy',
#    'City': 'Catania',
#    'Line': "Misterbianco Centro-Paterno'",
#    'Phases': 1,
#    'Start year': 2022,
#    'End year': 2026,
#    'Length': 11.5,
#    'Tunnel': 6.0,
#    'Stations': 5,
#    'Real cost (2021 dollars)': 561.6,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Cost/km (2021 dollars)': 48.8,
#    'TunnelPer': 0.52,
#    'Tunnel Percentage': '52.0 %'},
#   {'Country': 'Italy',
#    'City': 'Catania',
#    'Line': 'Monte-Po- MisterbiancoCentro',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 2.1,
#    'Tunnel': 2.1,
#    'Stations': 2,
#    'Real cost (2021 dollars)': 161.2,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Cost/km (2021 dollars)': 76.8,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Italy',
#    'City': 'Catania',
#    'Line': 'Nesima-Monte Po',
#    'Phases': 1,
#    'Start year': 2015,
#    'End year': 2022,
#    'Length': 1.7,
#    'Tunnel': 1.7,
#    'Stations': 2,
#    'Real cost (2021 dollars)': 130.5,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Cost/km (2021 dollars)': 76.7,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'Italy',
#    'City': 'Catania',
#    'Line': 'Stesicoro-Aeroporto',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2025,
#    'Length': 6.4,
#    'Tunnel': 6.4,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 570.3,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Cost/km (2021 dollars)': 89.1,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2010,
#    'End year': 2019,
#    'Length': 8.0,
#    'Tunnel': 8.0,
#    'Stations': 6,
#    'Real cost (2021 dollars)': 1628.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 203.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 2',
#    'Phases': 3,
#    'Start year': 2015,
#    'End year': 2025,
#    'Length': 37.2,
#    'Tunnel': 37.2,
#    'Stations': 27,
#    'Real cost (2021 dollars)': 6050.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 162.7,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 3.0,
#    'Tunnel': 0.8,
#    'Stations': 2,
#    'Real cost (2021 dollars)': 214.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 71.5,
#    'TunnelPer': 0.27,
#    'Tunnel Percentage': '27.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 4.0,
#    'Tunnel': 0.0,
#    'Stations': 6,
#    'Real cost (2021 dollars)': 514.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 128.7,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 5',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': <NA>,
#    'Length': 19.567,
#    'Tunnel': 19.567,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 5045.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 257.8,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 6',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 29.7,
#    'Tunnel': 29.7,
#    'Stations': 22,
#    'Real cost (2021 dollars)': 4999.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 168.3,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 7',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': 2025,
#    'Length': 22.5,
#    'Tunnel': 22.5,
#    'Stations': 19,
#    'Real cost (2021 dollars)': 3985.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 177.1,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'Line 9',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2025,
#    'Length': 28.2,
#    'Tunnel': 13.9,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 3232.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 114.6,
#    'TunnelPer': 0.49,
#    'Tunnel Percentage': '49.0 %'},
#   {'Country': 'China',
#    'City': 'Changchun',
#    'Line': 'New Beihu Line',
#    'Phases': 1,
#    'Start year': 2010,
#    'End year': 2019,
#    'Length': 13.4,
#    'Tunnel': 0.0,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 1241.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 92.7,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'First',
#    'Phases': 1,
#    'Start year': 2008,
#    'End year': 2015,
#    'Length': 45.92,
#    'Tunnel': 44.61,
#    'Stations': 32,
#    'Real cost (2021 dollars)': 7352.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 160.1,
#    'TunnelPer': 0.97,
#    'Tunnel Percentage': '97.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 1 North Extension',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2021,
#    'Length': 9.93,
#    'Tunnel': 5.4,
#    'Stations': 5,
#    'Real cost (2021 dollars)': 1614.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 162.6,
#    'TunnelPer': 0.54,
#    'Tunnel Percentage': '54.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 2',
#    'Phases': 3,
#    'Start year': 2011,
#    'End year': 2021,
#    'Length': 41.146,
#    'Tunnel': 33.446,
#    'Stations': 34,
#    'Real cost (2021 dollars)': 7109.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 172.8,
#    'TunnelPer': 0.81,
#    'Tunnel Percentage': '81.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 2 West Extension',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': 2025,
#    'Length': 13.99,
#    'Tunnel': 13.78,
#    'Stations': 11,
#    'Real cost (2021 dollars)': 2949.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 210.8,
#    'TunnelPer': 0.98,
#    'Tunnel Percentage': '98.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': 2012,
#    'End year': 2016,
#    'Length': 35.6,
#    'Tunnel': 0.0,
#    'Stations': 25,
#    'Real cost (2021 dollars)': 6242.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 175.4,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 4',
#    'Phases': 2,
#    'Start year': 2013,
#    'End year': 2022,
#    'Length': 47.76,
#    'Tunnel': 2.06,
#    'Stations': 32,
#    'Real cost (2021 dollars)': 9075.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 190.0,
#    'TunnelPer': 0.04,
#    'Tunnel Percentage': '4.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 5',
#    'Phases': 3,
#    'Start year': 2014,
#    'End year': 2022,
#    'Length': 34.78,
#    'Tunnel': 32.9,
#    'Stations': 27,
#    'Real cost (2021 dollars)': 7582.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 218.0,
#    'TunnelPer': 0.95,
#    'Tunnel Percentage': '95.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 6',
#    'Phases': 3,
#    'Start year': 2017,
#    'End year': 2022,
#    'Length': 48.699999999999996,
#    'Tunnel': 48.699999999999996,
#    'Stations': 32,
#    'Real cost (2021 dollars)': 9528.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 195.7,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changsha',
#    'Line': 'Line 7',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2021,
#    'Length': 21.6,
#    'Tunnel': 21.6,
#    'Stations': 16,
#    'Real cost (2021 dollars)': 4790.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 221.8,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Changzhou',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': <NA>,
#    'Length': 34.237,
#    'Tunnel': 31.635,
#    'Stations': 29,
#    'Real cost (2021 dollars)': 5568.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 162.6,
#    'TunnelPer': 0.92,
#    'Tunnel Percentage': '92.0 %'},
#   {'Country': 'China',
#    'City': 'Changzhou',
#    'Line': 'Line 2',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': <NA>,
#    'Length': 19.79,
#    'Tunnel': 19.79,
#    'Stations': 15,
#    'Real cost (2021 dollars)': 3552.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 179.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2020,
#    'Length': 13.0,
#    'Tunnel': 5.6,
#    'Stations': 10,
#    'Real cost (2021 dollars)': 1537.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 118.3,
#    'TunnelPer': 0.43,
#    'Tunnel Percentage': '43.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 10',
#    'Phases': 3,
#    'Start year': 2013,
#    'End year': 2025,
#    'Length': 43.1,
#    'Tunnel': 26.8,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 6124.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 142.1,
#    'TunnelPer': 0.62,
#    'Tunnel Percentage': '62.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 13',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 28.85,
#    'Tunnel': 26.3,
#    'Stations': 19,
#    'Real cost (2021 dollars)': 5964.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 206.7,
#    'TunnelPer': 0.91,
#    'Tunnel Percentage': '91.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 17',
#    'Phases': 2,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 53.74,
#    'Tunnel': 48.24,
#    'Stations': 26,
#    'Real cost (2021 dollars)': 9147.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 170.2,
#    'TunnelPer': 0.9,
#    'Tunnel Percentage': '90.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 18',
#    'Phases': 2,
#    'Start year': 2016,
#    'End year': 2024,
#    'Length': 72.89,
#    'Tunnel': 52.19,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 12571.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 172.5,
#    'TunnelPer': 0.72,
#    'Tunnel Percentage': '72.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 19',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 42.87,
#    'Tunnel': 42.87,
#    'Stations': 12,
#    'Real cost (2021 dollars)': 8959.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 209.0,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 27',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 24.86,
#    'Tunnel': 17.35,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 4184.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 168.3,
#    'TunnelPer': 0.7,
#    'Tunnel Percentage': '70.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 3',
#    'Phases': 2,
#    'Start year': 2013,
#    'End year': 2020,
#    'Length': 27.6,
#    'Tunnel': 16.2,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 3697.9,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 134.0,
#    'TunnelPer': 0.59,
#    'Tunnel Percentage': '59.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 30',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 24.78,
#    'Tunnel': 24.78,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 4821.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 194.6,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2020,
#    'Length': 21.3,
#    'Tunnel': 21.3,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 2700.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 126.8,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 5',
#    'Phases': 1,
#    'Start year': 2015,
#    'End year': 2020,
#    'Length': 49.0,
#    'Tunnel': 33.2,
#    'Stations': 39,
#    'Real cost (2021 dollars)': 8306.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 169.5,
#    'TunnelPer': 0.68,
#    'Tunnel Percentage': '68.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 7',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2020,
#    'Length': 38.6,
#    'Tunnel': 38.6,
#    'Stations': 31,
#    'Real cost (2021 dollars)': 7136.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 184.9,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 8',
#    'Phases': 2,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 36.93,
#    'Tunnel': 36.93,
#    'Stations': 32,
#    'Real cost (2021 dollars)': 7872.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 213.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line 9',
#    'Phases': 1,
#    'Start year': 2016,
#    'End year': 2020,
#    'Length': 22.2,
#    'Tunnel': 22.2,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 5351.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 241.0,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line S3',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': <NA>,
#    'Length': 38.7,
#    'Tunnel': 10.42,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 3083.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 79.7,
#    'TunnelPer': 0.27,
#    'Tunnel Percentage': '27.0 %'},
#   {'Country': 'China',
#    'City': 'Chengdu',
#    'Line': 'Line S5',
#    'Phases': 1,
#    'Start year': 2022,
#    'End year': <NA>,
#    'Length': 59.0,
#    'Tunnel': 9.85,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 5401.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 91.5,
#    'TunnelPer': 0.17,
#    'Tunnel Percentage': '17.0 %'},
#   {'Country': 'India',
#    'City': 'Chennai',
#    'Line': 'Phase 1',
#    'Phases': 2,
#    'Start year': 2009,
#    'End year': 2020,
#    'Length': 54.2,
#    'Tunnel': 26.4,
#    'Stations': 43,
#    'Real cost (2021 dollars)': 14314.5,
#    'Population': '1,352,617,328',
#    'Region': 'South Asia',
#    'GDP in $': 6525,
#    'Cost/km (2021 dollars)': 264.1,
#    'TunnelPer': 0.49,
#    'Tunnel Percentage': '49.0 %'},
#   {'Country': 'India',
#    'City': 'Chennai',
#    'Line': 'Phase 2',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': 2026,
#    'Length': 118.9,
#    'Tunnel': 42.8,
#    'Stations': 128,
#    'Real cost (2021 dollars)': 32514.6,
#    'Population': '1,352,617,328',
#    'Region': 'South Asia',
#    'GDP in $': 6525,
#    'Cost/km (2021 dollars)': 273.5,
#    'TunnelPer': 0.36,
#    'Tunnel Percentage': '36.0 %'},
#   {'Country': 'Thailand',
#    'City': 'Chiang Mai',
#    'Line': 'Red Line',
#    'Phases': 1,
#    'Start year': 2022,
#    'End year': 2027,
#    'Length': 15.8,
#    'Tunnel': 7.2,
#    'Stations': 12,
#    'Real cost (2021 dollars)': 2187.0,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Cost/km (2021 dollars)': 138.4,
#    'TunnelPer': 0.46,
#    'Tunnel Percentage': '46.0 %'},
#   {'Country': 'United States',
#    'City': 'Chicago',
#    'Line': 'Orange Line',
#    'Phases': 1,
#    'Start year': 1987,
#    'End year': 1993,
#    'Length': 14.4,
#    'Tunnel': 0.0,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 1036.6,
#    'Population': '327,167,434',
#    'Region': 'N.America',
#    'GDP in $': 63028,
#    'Cost/km (2021 dollars)': 72.0,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Chongqing',
#    'Line': 'Bishan-Tongliang Line',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 37.353,
#    'Tunnel': 10.386,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 2162.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 57.9,
#    'TunnelPer': 0.28,
#    'Tunnel Percentage': '28.000000000000004 %'},
#   {'Country': 'China',
#    'City': 'Chongqing',
#    'Line': 'Jiangjin Line',
#    'Phases': 2,
#    'Start year': 2018,
#    'End year': <NA>,
#    'Length': 32.82,
#    'Tunnel': 5.8,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 2619.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 79.8,
#    'TunnelPer': 0.18,
#    'Tunnel Percentage': '18.0 %'},
#   {'Country': 'China',
#    'City': 'Chongqing',
#    'Line': 'Line 1',
#    'Phases': 2,
#    'Start year': 2007,
#    'End year': <NA>,
#    'Length': 32.0,
#    'Tunnel': 0.0,
#    'Stations': 23,
#    'Real cost (2021 dollars)': 5446.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 170.2,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Chongqing',
#    'Line': 'Line 10',
#    'Phases': 1,
#    'Start year': 2014,
#    'End year': 2020,
#    'Length': 44.09,
#    'Tunnel': 35.78,
#    'Stations': 27,
#    'Real cost (2021 dollars)': 7953.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 180.4,
#    'TunnelPer': 0.81,
#    'Tunnel Percentage': '81.0 %'},
#   {'Country': 'China',
#    'City': 'Chongqing',
#    'Line': 'Line 15',
#    'Phases': 2,
#    'Start year': 2021,
#    'End year': 2027,
# ...
#    'Line': 'Line 10',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': 2026,
#    'Length': 34.11,
#    'Tunnel': 0.0,
#    'Stations': 16,
#    'Real cost (2021 dollars)': 5234.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 153.5,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 14',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 13.8,
#    'Tunnel': 13.8,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 2097.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 152.0,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 15',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': 2025,
#    'Length': 19.0,
#    'Tunnel': 19.0,
#    'Stations': 11,
#    'Real cost (2021 dollars)': 3137.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 165.1,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 16',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 15.03,
#    'Tunnel': 15.03,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 2540.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 169.0,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 2',
#    'Phases': 2,
#    'Start year': 2006,
#    'End year': 2011,
#    'Length': 33.760000000000005,
#    'Tunnel': 33.760000000000005,
#    'Stations': 25,
#    'Real cost (2021 dollars)': 6272.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 185.8,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 3',
#    'Phases': 1,
#    'Start year': 2012,
#    'End year': 2016,
#    'Length': 38.4,
#    'Tunnel': 27.13,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 5489.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 143.0,
#    'TunnelPer': 0.71,
#    'Tunnel Percentage': '71.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2018,
#    'Length': 33.3,
#    'Tunnel': 33.3,
#    'Stations': 28,
#    'Real cost (2021 dollars)': 5760.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 173.0,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 5',
#    'Phases': 2,
#    'Start year': 2014,
#    'End year': 2021,
#    'Length': 45.57,
#    'Tunnel': 27.5,
#    'Stations': 33,
#    'Real cost (2021 dollars)': 7102.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 155.9,
#    'TunnelPer': 0.6,
#    'Tunnel Percentage': '60.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 6',
#    'Phases': 1,
#    'Start year': 2016,
#    'End year': 2022,
#    'Length': 39.8,
#    'Tunnel': 39.8,
#    'Stations': 32,
#    'Real cost (2021 dollars)': 7290.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 183.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 8',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 50.0,
#    'Tunnel': 50.0,
#    'Stations': 35,
#    'Real cost (2021 dollars)': 9657.9,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 193.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': "Xi'an",
#    'Line': 'Line 9',
#    'Phases': 1,
#    'Start year': 2016,
#    'End year': 2020,
#    'Length': 25.296,
#    'Tunnel': 25.296,
#    'Stations': 15,
#    'Real cost (2021 dollars)': 3551.8,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 140.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xiamen',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2011,
#    'End year': 2020,
#    'Length': 31.5,
#    'Tunnel': 26.36,
#    'Stations': 23,
#    'Real cost (2021 dollars)': 5778.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 183.4,
#    'TunnelPer': 0.84,
#    'Tunnel Percentage': '84.0 %'},
#   {'Country': 'China',
#    'City': 'Xiamen',
#    'Line': 'Line 2',
#    'Phases': 2,
#    'Start year': 2015,
#    'End year': 2020,
#    'Length': 40.7,
#    'Tunnel': 40.7,
#    'Stations': 28,
#    'Real cost (2021 dollars)': 8117.6,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 199.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xiamen',
#    'Line': 'Line 3',
#    'Phases': 2,
#    'Start year': 2011,
#    'End year': 2020,
#    'Length': 41.2,
#    'Tunnel': 16.8,
#    'Stations': 29,
#    'Real cost (2021 dollars)': 7797.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 189.2,
#    'TunnelPer': 0.41,
#    'Tunnel Percentage': '41.0 %'},
#   {'Country': 'China',
#    'City': 'Xiamen',
#    'Line': 'Line 4',
#    'Phases': 2,
#    'Start year': 2017,
#    'End year': 2022,
#    'Length': 114.38,
#    'Tunnel': 53.68,
#    'Stations': 28,
#    'Real cost (2021 dollars)': 15766.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 137.8,
#    'TunnelPer': 0.47,
#    'Tunnel Percentage': '47.0 %'},
#   {'Country': 'China',
#    'City': 'Xiamen',
#    'Line': 'Line 6',
#    'Phases': 1,
#    'Start year': 2017,
#    'End year': 2022,
#    'Length': 44.5,
#    'Tunnel': 44.5,
#    'Stations': 27,
#    'Real cost (2021 dollars)': 10333.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 232.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xiamen',
#    'Line': 'Line 9',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': <NA>,
#    'Length': 44.2,
#    'Tunnel': 44.2,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 9688.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 219.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xiamen',
#    'Line': 'Quanzhou-Xiamen-Zhangzhou Regional Rail R1',
#    'Phases': 3,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 167.2,
#    'Tunnel': 0.0,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 19559.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 117.0,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Xuzhou',
#    'Line': 'First Phase Program (Lines 1, 2 and 3)',
#    'Phases': 1,
#    'Start year': 2013,
#    'End year': 2020,
#    'Length': 67.0,
#    'Tunnel': 60.6,
#    'Stations': 0,
#    'Real cost (2021 dollars)': 11711.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 174.8,
#    'TunnelPer': 0.9,
#    'Tunnel Percentage': '90.0 %'},
#   {'Country': 'China',
#    'City': 'Xuzhou',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2014,
#    'End year': 2019,
#    'Length': 21.967,
#    'Tunnel': 20.996,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 4300.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 195.8,
#    'TunnelPer': 0.96,
#    'Tunnel Percentage': '96.0 %'},
#   {'Country': 'China',
#    'City': 'Xuzhou',
#    'Line': 'Line 2',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 24.15,
#    'Tunnel': 24.15,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 4243.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 175.7,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xuzhou',
#    'Line': 'Line 3',
#    'Phases': 2,
#    'Start year': 2021,
#    'End year': <NA>,
#    'Length': 24.8,
#    'Tunnel': 24.8,
#    'Stations': 21,
#    'Real cost (2021 dollars)': 4487.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 181.0,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xuzhou',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': <NA>,
#    'Length': 26.2,
#    'Tunnel': 26.2,
#    'Stations': 19,
#    'Real cost (2021 dollars)': 4414.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 168.5,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xuzhou',
#    'Line': 'Line 5',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 24.6,
#    'Tunnel': 24.6,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 4211.3,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 171.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Xuzhou',
#    'Line': 'Line 6',
#    'Phases': 1,
#    'Start year': 2021,
#    'End year': <NA>,
#    'Length': 22.912,
#    'Tunnel': 22.912,
#    'Stations': 16,
#    'Real cost (2021 dollars)': 4578.5,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 199.8,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Yiwu',
#    'Line': 'Phase 1',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 107.17,
#    'Tunnel': 0.0,
#    'Stations': 31,
#    'Real cost (2021 dollars)': 8678.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 81.0,
#    'TunnelPer': 0.0,
#    'Tunnel Percentage': '0.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2009,
#    'End year': 2013,
#    'Length': 25.2,
#    'Tunnel': 25.2,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 4904.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 194.6,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 10',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 21.3,
#    'Tunnel': 21.3,
#    'Stations': 12,
#    'Real cost (2021 dollars)': 3303.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 155.1,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 12',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 17.034,
#    'Tunnel': 17.034,
#    'Stations': 12,
#    'Real cost (2021 dollars)': 2864.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 168.2,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 14',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 8.3,
#    'Tunnel': 8.3,
#    'Stations': 6,
#    'Real cost (2021 dollars)': 1686.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 203.1,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 2',
#    'Phases': 1,
#    'Start year': 2010,
#    'End year': 2016,
#    'Length': 18.27,
#    'Tunnel': 18.27,
#    'Stations': 16,
#    'Real cost (2021 dollars)': 3305.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 180.9,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 3',
#    'Phases': 2,
#    'Start year': 2017,
#    'End year': 2020,
#    'Length': 31.791999999999998,
#    'Tunnel': 31.791999999999998,
#    'Stations': 25,
#    'Real cost (2021 dollars)': 6052.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 190.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 4',
#    'Phases': 1,
#    'Start year': 2014,
#    'End year': 2020,
#    'Length': 30.1,
#    'Tunnel': 30.1,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 5028.9,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 167.1,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 6',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 36.5,
#    'Tunnel': 33.7,
#    'Stations': 24,
#    'Real cost (2021 dollars)': 7392.1,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 202.5,
#    'TunnelPer': 0.92,
#    'Tunnel Percentage': '92.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 7',
#    'Phases': 1,
#    'Start year': <NA>,
#    'End year': <NA>,
#    'Length': 26.9,
#    'Tunnel': 26.9,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 5337.2,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 198.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Line 8',
#    'Phases': 1,
#    'Start year': 2019,
#    'End year': 2024,
#    'Length': 50.63,
#    'Tunnel': 50.63,
#    'Stations': 27,
#    'Real cost (2021 dollars)': 7413.7,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 146.4,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'},
#   {'Country': 'China',
#    'City': 'Zhengzhou',
#    'Line': 'Zhengxu Regional',
#    'Phases': 2,
#    'Start year': 2020,
#    'End year': 2022,
#    'Length': 65.05,
#    'Tunnel': 32.196,
#    'Stations': 26,
#    'Real cost (2021 dollars)': 6831.9,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 105.0,
#    'TunnelPer': 0.49,
#    'Tunnel Percentage': '49.0 %'},
#   {'Country': 'China',
#    'City': 'Zibo',
#    'Line': 'Line 1',
#    'Phases': 1,
#    'Start year': 2020,
#    'End year': <NA>,
#    'Length': 20.82,
#    'Tunnel': 12.86,
#    'Stations': 15,
#    'Real cost (2021 dollars)': 3366.0,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Cost/km (2021 dollars)': 161.7,
#    'TunnelPer': 0.62,
#    'Tunnel Percentage': '62.0 %'},
#   {'Country': 'Switzerland',
#    'City': 'Zurich',
#    'Line': 'Durchmesserlinie',
#    'Phases': 1,
#    'Start year': 2007,
#    'End year': 2014,
#    'Length': 9.6,
#    'Tunnel': 4.8,
#    'Stations': 1,
#    'Real cost (2021 dollars)': 1715.4,
#    'Population': '8,516,543',
#    'Region': 'Europe',
#    'GDP in $': 71745,
#    'Cost/km (2021 dollars)': 178.7,
#    'TunnelPer': 0.5,
#    'Tunnel Percentage': '50.0 %'},
#   {'Country': 'Poland',
#    'City': 'Łódź',
#    'Line': 'Cross-City Line',
#    'Phases': 1,
#    'Start year': 2018,
#    'End year': 2023,
#    'Length': 5.25,
#    'Tunnel': 5.25,
#    'Stations': 2,
#    'Real cost (2021 dollars)': 1033.7,
#    'Population': '37,978,548',
#    'Region': 'Europe',
#    'GDP in $': 34287,
#    'Cost/km (2021 dollars)': 196.9,
#    'TunnelPer': 1.0,
#    'Tunnel Percentage': '100.0 %'}]}

# %%
#save the data on file
import json
import os
folder = r'C:\Users\elife\Documents\NYU\CCP\ANALYSIS\240226_update_charts'
file = "data_phase_group.js"

# To export Np formats
def np_encoder(object):
    if isinstance(object, np.generic):
        return object.item()

with open(os.path.join(folder,file), "w") as outfile: 
    json_text = json.dumps(data_dict, indent=1 , default=np_encoder)
    test = "var data = " + json_text
    outfile.write( test )

print('done')
# Out:
# done

# %%
df.sample(10)
# Out:
#      CO          City                                              Phase  \
# 264  GR  Thessaloniki                                Kalamaria Extension
# 718  CN     Changchun                                             Line 2
# 749  CN        Fuzhou                              Line 6 East Extension
# 43   CA     Vancouver                 Expo Line Surrey-Langley extension
# 791  CN       Nanjing  Line S4 Nanjing-Chuzhou Phase 2 (Chuzhou Section)
# 807  CN      Shenzhen  Guangzhou-Dongguan-Shenzhen Regional Rail Sout...
# 55   US      New York                              Second Avenue Phase 2
# 35   CA       Toronto                                 Eglinton Crosstown
# 90   FR         Paris                           Line 12 to Aubervilliers
# 557  CN     Chongqing                       Line 6 Branch (EXPO) Phase 2
#
#                                           Line  Start year  End year Length  \
# 264                        Kalamaria Extension      2013.0    2021.0    4.8
# 718                                     Line 2         NaN    2020.0   22.8
# 749                                     Line 6      2020.0       NaN   5.29
# 43                                   Expo Line      2022.0       NaN     16
# 791                    Line S4 Nanjing-Chuzhou      2022.0       NaN  13.28
# 807  Guangzhou-Dongguan-Shenzhen Regional Rail      2021.0       NaN  15.15
# 55                               Second Avenue      2019.0    2029.0    2.6
# 35                          Eglinton Crosstown      2011.0    2022.0     19
# 90                                     Line 12      2012.0    2021.0    1.7
# 557                                     Line 6      2016.0    2020.0  13.99
#
#     TunnelPer Tunnel Stations  Real cost (2021 dollars)  \
# 264         1    4.8        5                814.833498
# 718         1   22.8       19               3853.515430
# 749         1   5.29        6               1021.682046
# 43          0      0        8               3144.120000
# 791       NaN    NaN        6               1056.380000
# 807         1  15.15        3               2844.100000
# 55          1    2.6        3               6949.000000
# 35       0.53     10       25               4966.509435
# 90          1    1.7        2                294.189280
# 557  0.638313   8.93        7               1911.453914
#
#      Cost/km (2021 dollars)        Country     Population     Region  GDP in $
# 264              169.756979         Greece     10,727,668     Europe  27,949.0
# 718              169.013835          China  1,392,730,000  East Asia  17,189.0
# 749              193.134602          China  1,392,730,000  East Asia  17,189.0
# 43               196.507500         Canada     37,058,856  N.America  46,572.0
# 791               79.546687          China  1,392,730,000  East Asia  17,189.0
# 807              187.729373          China  1,392,730,000  East Asia  17,189.0
# 55              2672.692308  United States    327,167,434  N.America  63,028.0
# 35               261.395233         Canada     37,058,856  N.America  46,572.0
# 90               173.052517         France     66,987,244     Europe  46,991.0
# 557              136.630015          China  1,392,730,000  East Asia  17,189.0

# %% [markdown]
# #### Now we go back to the ungrouped df and group by country

# %%
#defining the aggregate functions for group by per project (we will count all phases of projects separately)
agg2_functions={'Country':'first','Phase':'count','Length':'sum','Tunnel':'sum','Stations':'sum','Real cost (2021 dollars)':'sum', 'Population':'first','Region':'first','GDP in $':'first'}

# %%
df_gr_co=df.groupby(['Country'], as_index=False).aggregate(agg2_functions)
df_gr_co = df_gr_co.rename({'Phase': '# Records in Database'}, axis='columns')

# %%
df_gr_co.sort_values(by='# Records in Database', ascending=False)
# Out:
#                  Country  # Records in Database      Length     Tunnel  \
# 10                 China                    495  12882.2566  9085.5316
# 22                 India                     34   1184.1350   261.1910
# 26                 Italy                     34    194.5000   174.4000
# 52                Turkey                     28    489.7700   354.0200
# 18               Germany                     21     74.2000    65.2000
# 56         United States                     21    180.8000    62.0000
# 46           South Korea                     19    379.0510   260.4510
# 17                France                     17    286.9000   231.2000
# 50                Taiwan                     17    381.0900   174.6000
# 8                 Canada                     16    191.3000    82.1000
# 27                 Japan                     16    189.2000    80.6000
# 47                 Spain                     15    253.8000   205.7000
# 20             Hong Kong                     14    120.6000    78.6750
# 43          Saudi Arabia                      9    575.5000    53.9000
# 51              Thailand                      8    197.4000    39.6000
# 48                Sweden                      6     51.3000    36.9000
# 7               Bulgaria                      6     41.5000    37.8000
# 6                 Brazil                      6    107.9000    42.2000
# 42                Russia                      5     92.2000    82.0000
# 58               Vietnam                      5     63.9000    31.9000
# 38                Poland                      5     22.2500    22.2500
# 15                 Egypt                      5    110.3000    33.8000
# 19                Greece                      4     34.7000    34.7000
# 37           Philippines                      4     77.7000    42.7000
# 2                Austria                      4     30.7000    24.5000
# 45             Singapore                      4    124.4000   124.4000
# 1              Australia                      4     83.5000    47.9000
# 16               Finland                      3     38.5000    28.5000
# 35                Panama                      3     61.4000     7.3000
# 4             Bangladesh                      3     72.1000    33.9000
# 55        United Kingdom                      3     40.2000    37.0000
# 11        Czech Republic                      3     21.2000    20.0000
# 54  United Arab Emirates                      3     72.5000    15.8000
# 53               Ukraine                      3     27.2000    20.2000
# 49           Switzerland                      3     19.9000    14.6000
# 24                  Iran                      3     70.0000    70.0000
# 44                Serbia                      2     42.0000    42.0000
# 57            Uzbekistan                      2      9.8400     2.9000
# 41               Romania                      2     27.9000    27.9000
# 29              Malaysia                      2    103.2000    23.0000
# 25                Israel                      2     62.6000    16.6000
# 3                Bahrain                      2    101.3000     0.0000
# 33                Norway                      2      9.8000     9.8000
# 9                  Chile                      2     61.8000    61.8000
# 30                Mexico                      2     46.0000    15.9000
# 13    Dominican Republic                      2     31.0000    26.0000
# 39              Portugal                      2      8.0000     4.8000
# 21               Hungary                      1      7.4000     7.4000
# 5                Belgium                      1      4.8000     4.8000
# 12               Denmark                      1     15.5000    15.5000
# 14               Ecuador                      1     22.9000    22.9000
# 40                 Qatar                      1    124.0000   111.5000
# 23             Indonesia                      1     15.7000     5.9000
# 28                Kuwait                      1    160.0000    56.0000
# 31           Netherlands                      1      9.7000     7.1000
# 32           New Zealand                      1      3.5000     3.5000
# 34              Pakistan                      1     27.1000     1.6000
# 36                  Peru                      1     35.0000    35.0000
# 0              Argentina                      1     20.0000    20.0000
#
#     Stations  Real cost (2021 dollars)     Population           Region  \
# 10      7068              2.328258e+06  1,392,730,000        East Asia
# 22      1000              2.283231e+05  1,352,617,328       South Asia
# 26       216              3.373683e+04     60,431,283           Europe
# 52       335              5.944759e+04     82,319,724      Middle East
# 18        71              2.594427e+04     82,927,922           Europe
# 56        98              1.011273e+05    327,167,434        N.America
# 46       174              3.632598e+04     51,635,256        East Asia
# 17       137              7.331591e+04     66,987,244           Europe
# 50       312              1.404427e+05     22,894,384        East Asia
# 8        157              5.069519e+04     37,058,856        N.America
# 27       107              4.533678e+04    126,529,100        East Asia
# 47       200              2.647037e+04     46,723,749           Europe
# 20        78              9.203822e+04      7,451,000        East Asia
# 43       251              1.465463e+05     33,699,947      Middle East
# 51       155              4.932270e+04     69,428,524  South East Asia
# 48        18              1.072831e+04     10,183,175           Europe
# 7         35              7.194164e+03      7,000,039           Europe
# 6         87              2.430761e+04    209,469,333        S.America
# 42        41              2.768274e+04    144,478,050           Europe
# 58        56              2.543000e+04     95,540,395  South East Asia
# 38        18              7.161537e+03     37,978,548           Europe
# 15       101              5.049364e+04     98,423,595      Middle East
# 19        39              5.284921e+03     10,727,668           Europe
# 37        48              3.365730e+04    106,651,922  South East Asia
# 2         19              6.497320e+03      8,847,037           Europe
# 45        99              7.679607e+04      5,638,676  South East Asia
# 1         28              2.683948e+04     24,992,369          Oceania
# 16        18              4.646344e+03      5,518,050           Europe
# 35        42              1.431797e+04      4,176,873        N.America
# 4         49              4.136828e+04    161,356,039       South Asia
# 55        21              3.174460e+04     66,488,991           Europe
# 11        17              8.848733e+03     10,625,695           Europe
# 54        56              2.590362e+04      9,630,959      Middle East
# 53        17              8.249021e+03     44,622,516           Europe
# 49         6              3.104469e+03      8,516,543           Europe
# 24        65              1.552650e+04     81,800,269      Middle East
# 44        45              1.220000e+04      6,982,084           Europe
# 57         8              1.440601e+03     32,955,400     Central Asia
# 41        29              6.546760e+03     19,473,936           Europe
# 29        72              3.947679e+04     31,528,585  South East Asia
# 25        96              1.070172e+04      8,883,800      Middle East
# 3         20              1.172063e+04      1,569,439      Middle East
# 33         7              2.882089e+03      5,314,336           Europe
# 9         49              1.068794e+04     18,729,160        S.America
# 30        38              1.143015e+04    126,190,788        N.America
# 13        34              4.926508e+03     10,627,165        N.America
# 39         9              6.812000e+02     10,281,762           Europe
# 21        10              4.448533e+03      9,768,785           Europe
# 5          7              3.380000e+03     11,422,068           Europe
# 12        17              3.996286e+03      5,797,446           Europe
# 14        15              4.311684e+03     17,084,357        S.America
# 40         0              1.046858e+05      2,781,677      Middle East
# 23        13              3.312854e+03    267,663,435  South East Asia
# 28        68              3.182820e+04      4,137,309      Middle East
# 31         8              5.090074e+03     17,231,017           Europe
# 32         4              3.228309e+03      4,885,500          Oceania
# 34        26              6.675864e+03    212,215,030       South Asia
# 36        35              1.175256e+04     31,989,256        S.America
# 0          4              4.646000e+03     44,494,502        S.America
#
#     GDP in $
# 10  17,189.0
# 22   6,525.0
# 26  41,988.0
# 52  27,235.0
# 18  54,845.0
# 56  63,028.0
# 46  45,226.0
# 17  46,991.0
# 50  55,724.0
# 8   46,572.0
# 27  42,100.0
# 47  37,756.0
# 20  58,980.0
# 43  46,778.0
# 51  18,198.0
# 48  55,065.0
# 7   24,564.0
# 6   14,834.0
# 42  29,916.0
# 58  10,904.0
# 38  34,287.0
# 15  12,606.0
# 19  27,949.0
# 37   8,394.0
# 2   55,686.0
# 45  99,681.0
# 1   53,317.0
# 16  50,937.0
# 35  26,780.0
# 4    5,995.0
# 55  46,527.0
# 11  41,608.0
# 54  66,766.0
# 53  13,087.0
# 49  71,745.0
# 24  15,791.0
# 44  19,094.0
# 57   7,746.0
# 41  32,202.0
# 29  27,921.0
# 25  39,489.0
# 3   43,821.0
# 33  62,645.0
# 9   25,089.0
# 30  18,671.0
# 13  17,934.0
# 39  34,177.0
# 21  33,274.0
# 5   53,070.0
# 12  60,230.0
# 14  10,890.0
# 40  89,961.0
# 23  12,072.0
# 28  47,303.0
# 31  59,267.0
# 32  44,658.0
# 34   5,426.0
# 36  11,908.0
# 0   20,769.0

# %% [markdown]
# ### Now we convert km to miles

# %%
df_gr_co['Lenght_in_miles']=(df_gr_co['Length']*0.621371).round(2)
df_gr_co['Tunnel_in_miles']=(df_gr_co['Tunnel']*0.621371).round(2)
df_gr_co["Avg Cost/miles"]=(df_gr_co['Real cost (2021 dollars)']/df_gr_co['Lenght_in_miles']).round(2)
df_gr_co["Avg Tunnel %"]= (df_gr_co['Tunnel']/df_gr_co['Length']).round(2)*100

# %%
df_gr_co["Avg Cost/km"]=(df_gr_co['Real cost (2021 dollars)']/df_gr_co['Length']).round(2)
#df_gr_co["Avg Tunnel %"]= (df_gr_co['Tunnel']/df_gr_co['Length']).round(2)*100

# %%
df_gr_co['GDP in $'] = df_gr_co['GDP in $'].str.replace(",","").astype( float ).astype( pd.Int64Dtype() )

# %%
df_gr_co['Length']=df_gr_co['Length'].astype( float ).round(2)
df_gr_co['Lenght_in_miles']=df_gr_co['Lenght_in_miles'].astype( float ).round(2)

# %%
df_gr_co['Avg Cost/km (all projects)']=(df_gr_co['Real cost (2021 dollars)'].sum()/df_gr_co['Length'].sum()).round(2)
df_gr_co['Avg Cost/miles (all projects)']=(df_gr_co['Real cost (2021 dollars)'].sum()/df_gr_co['Lenght_in_miles'].sum()).round(2)

# %%
#create json dictionary. This is the format the vega library reads data in. Add data-elif to the top because that is what our map jsons have at the top.
data_dict = df_gr_co.to_dict(
    orient= 'records'
)

data_dict = {
    "data-elif": data_dict
}

data_dict
# Out:
# {'data-elif': [{'Country': 'Argentina',
#    '# Records in Database': 1,
#    'Length': 20.0,
#    'Tunnel': 20.0,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 4646.0,
#    'Population': '44,494,502',
#    'Region': 'S.America',
#    'GDP in $': 20769,
#    'Lenght_in_miles': 12.43,
#    'Tunnel_in_miles': 12.43,
#    'Avg Cost/miles': 373.77,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 232.3,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Australia',
#    '# Records in Database': 4,
#    'Length': 83.5,
#    'Tunnel': 47.9,
#    'Stations': 28,
#    'Real cost (2021 dollars)': 26839.480193769086,
#    'Population': '24,992,369',
#    'Region': 'Oceania',
#    'GDP in $': 53317,
#    'Lenght_in_miles': 51.88,
#    'Tunnel_in_miles': 29.76,
#    'Avg Cost/miles': 517.34,
#    'Avg Tunnel %': 56.99999999999999,
#    'Avg Cost/km': 321.43,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Austria',
#    '# Records in Database': 4,
#    'Length': 30.7,
#    'Tunnel': 24.5,
#    'Stations': 19,
#    'Real cost (2021 dollars)': 6497.319658911716,
#    'Population': '8,847,037',
#    'Region': 'Europe',
#    'GDP in $': 55686,
#    'Lenght_in_miles': 19.08,
#    'Tunnel_in_miles': 15.22,
#    'Avg Cost/miles': 340.53,
#    'Avg Tunnel %': 80.0,
#    'Avg Cost/km': 211.64,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Bahrain',
#    '# Records in Database': 2,
#    'Length': 101.3,
#    'Tunnel': 0.0,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 11720.634196339235,
#    'Population': '1,569,439',
#    'Region': 'Middle East',
#    'GDP in $': 43821,
#    'Lenght_in_miles': 62.94,
#    'Tunnel_in_miles': 0.0,
#    'Avg Cost/miles': 186.22,
#    'Avg Tunnel %': 0.0,
#    'Avg Cost/km': 115.7,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Bangladesh',
#    '# Records in Database': 3,
#    'Length': 72.1,
#    'Tunnel': 33.9,
#    'Stations': 49,
#    'Real cost (2021 dollars)': 41368.275504132485,
#    'Population': '161,356,039',
#    'Region': 'South Asia',
#    'GDP in $': 5995,
#    'Lenght_in_miles': 44.8,
#    'Tunnel_in_miles': 21.06,
#    'Avg Cost/miles': 923.4,
#    'Avg Tunnel %': 47.0,
#    'Avg Cost/km': 573.76,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Belgium',
#    '# Records in Database': 1,
#    'Length': 4.8,
#    'Tunnel': 4.8,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 3380.0,
#    'Population': '11,422,068',
#    'Region': 'Europe',
#    'GDP in $': 53070,
#    'Lenght_in_miles': 2.98,
#    'Tunnel_in_miles': 2.98,
#    'Avg Cost/miles': 1134.23,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 704.17,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Brazil',
#    '# Records in Database': 6,
#    'Length': 107.9,
#    'Tunnel': 42.2,
#    'Stations': 87,
#    'Real cost (2021 dollars)': 24307.606212546794,
#    'Population': '209,469,333',
#    'Region': 'S.America',
#    'GDP in $': 14834,
#    'Lenght_in_miles': 67.05,
#    'Tunnel_in_miles': 26.22,
#    'Avg Cost/miles': 362.53,
#    'Avg Tunnel %': 39.0,
#    'Avg Cost/km': 225.28,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Bulgaria',
#    '# Records in Database': 6,
#    'Length': 41.5,
#    'Tunnel': 37.800000000000004,
#    'Stations': 35,
#    'Real cost (2021 dollars)': 7194.1644665764525,
#    'Population': '7,000,039',
#    'Region': 'Europe',
#    'GDP in $': 24564,
#    'Lenght_in_miles': 25.79,
#    'Tunnel_in_miles': 23.49,
#    'Avg Cost/miles': 278.95,
#    'Avg Tunnel %': 91.0,
#    'Avg Cost/km': 173.35,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Canada',
#    '# Records in Database': 16,
#    'Length': 191.3,
#    'Tunnel': 82.1,
#    'Stations': 157,
#    'Real cost (2021 dollars)': 50695.193724107376,
#    'Population': '37,058,856',
#    'Region': 'N.America',
#    'GDP in $': 46572,
#    'Lenght_in_miles': 118.87,
#    'Tunnel_in_miles': 51.01,
#    'Avg Cost/miles': 426.48,
#    'Avg Tunnel %': 43.0,
#    'Avg Cost/km': 265.0,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Chile',
#    '# Records in Database': 2,
#    'Length': 61.8,
#    'Tunnel': 61.8,
#    'Stations': 49,
#    'Real cost (2021 dollars)': 10687.944559950334,
#    'Population': '18,729,160',
#    'Region': 'S.America',
#    'GDP in $': 25089,
#    'Lenght_in_miles': 38.4,
#    'Tunnel_in_miles': 38.4,
#    'Avg Cost/miles': 278.33,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 172.94,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'China',
#    '# Records in Database': 495,
#    'Length': 12882.26,
#    'Tunnel': 9085.531600000002,
#    'Stations': 7068,
#    'Real cost (2021 dollars)': 2328257.901865203,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Lenght_in_miles': 8004.66,
#    'Tunnel_in_miles': 5645.49,
#    'Avg Cost/miles': 290.86,
#    'Avg Tunnel %': 71.0,
#    'Avg Cost/km': 180.73,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Czech Republic',
#    '# Records in Database': 3,
#    'Length': 21.2,
#    'Tunnel': 20.0,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 8848.732548133881,
#    'Population': '10,625,695',
#    'Region': 'Europe',
#    'GDP in $': 41608,
#    'Lenght_in_miles': 13.17,
#    'Tunnel_in_miles': 12.43,
#    'Avg Cost/miles': 671.89,
#    'Avg Tunnel %': 94.0,
#    'Avg Cost/km': 417.39,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Denmark',
#    '# Records in Database': 1,
#    'Length': 15.5,
#    'Tunnel': 15.5,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 3996.2855585969187,
#    'Population': '5,797,446',
#    'Region': 'Europe',
#    'GDP in $': 60230,
#    'Lenght_in_miles': 9.63,
#    'Tunnel_in_miles': 9.63,
#    'Avg Cost/miles': 414.98,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 257.82,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Dominican Republic',
#    '# Records in Database': 2,
#    'Length': 31.0,
#    'Tunnel': 26.0,
#    'Stations': 34,
#    'Real cost (2021 dollars)': 4926.507831164114,
#    'Population': '10,627,165',
#    'Region': 'N.America',
#    'GDP in $': 17934,
#    'Lenght_in_miles': 19.26,
#    'Tunnel_in_miles': 16.16,
#    'Avg Cost/miles': 255.79,
#    'Avg Tunnel %': 84.0,
#    'Avg Cost/km': 158.92,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Ecuador',
#    '# Records in Database': 1,
#    'Length': 22.9,
#    'Tunnel': 22.9,
#    'Stations': 15,
#    'Real cost (2021 dollars)': 4311.68436753928,
#    'Population': '17,084,357',
#    'Region': 'S.America',
#    'GDP in $': 10890,
#    'Lenght_in_miles': 14.23,
#    'Tunnel_in_miles': 14.23,
#    'Avg Cost/miles': 303.0,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 188.28,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Egypt',
#    '# Records in Database': 5,
#    'Length': 110.3,
#    'Tunnel': 33.8,
#    'Stations': 101,
#    'Real cost (2021 dollars)': 50493.63927933467,
#    'Population': '98,423,595',
#    'Region': 'Middle East',
#    'GDP in $': 12606,
#    'Lenght_in_miles': 68.54,
#    'Tunnel_in_miles': 21.0,
#    'Avg Cost/miles': 736.7,
#    'Avg Tunnel %': 31.0,
#    'Avg Cost/km': 457.78,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Finland',
#    '# Records in Database': 3,
#    'Length': 38.5,
#    'Tunnel': 28.5,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 4646.343652816713,
#    'Population': '5,518,050',
#    'Region': 'Europe',
#    'GDP in $': 50937,
#    'Lenght_in_miles': 23.92,
#    'Tunnel_in_miles': 17.71,
#    'Avg Cost/miles': 194.25,
#    'Avg Tunnel %': 74.0,
#    'Avg Cost/km': 120.68,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'France',
#    '# Records in Database': 17,
#    'Length': 286.9,
#    'Tunnel': 231.2,
#    'Stations': 137,
#    'Real cost (2021 dollars)': 73315.9052051634,
#    'Population': '66,987,244',
#    'Region': 'Europe',
#    'GDP in $': 46991,
#    'Lenght_in_miles': 178.27,
#    'Tunnel_in_miles': 143.66,
#    'Avg Cost/miles': 411.26,
#    'Avg Tunnel %': 81.0,
#    'Avg Cost/km': 255.55,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Germany',
#    '# Records in Database': 21,
#    'Length': 74.2,
#    'Tunnel': 65.2,
#    'Stations': 71,
#    'Real cost (2021 dollars)': 25944.270908785944,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Lenght_in_miles': 46.11,
#    'Tunnel_in_miles': 40.51,
#    'Avg Cost/miles': 562.66,
#    'Avg Tunnel %': 88.0,
#    'Avg Cost/km': 349.65,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Greece',
#    '# Records in Database': 4,
#    'Length': 34.7,
#    'Tunnel': 34.699999999999996,
#    'Stations': 39,
#    'Real cost (2021 dollars)': 5284.92114226215,
#    'Population': '10,727,668',
#    'Region': 'Europe',
#    'GDP in $': 27949,
#    'Lenght_in_miles': 21.56,
#    'Tunnel_in_miles': 21.56,
#    'Avg Cost/miles': 245.13,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 152.3,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Hong Kong',
#    '# Records in Database': 14,
#    'Length': 120.6,
#    'Tunnel': 78.67499999999998,
#    'Stations': 78,
#    'Real cost (2021 dollars)': 92038.22404511474,
#    'Population': '7,451,000',
#    'Region': 'East Asia',
#    'GDP in $': 58980,
#    'Lenght_in_miles': 74.94,
#    'Tunnel_in_miles': 48.89,
#    'Avg Cost/miles': 1228.16,
#    'Avg Tunnel %': 65.0,
#    'Avg Cost/km': 763.17,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Hungary',
#    '# Records in Database': 1,
#    'Length': 7.4,
#    'Tunnel': 7.4,
#    'Stations': 10,
#    'Real cost (2021 dollars)': 4448.532692519353,
#    'Population': '9,768,785',
#    'Region': 'Europe',
#    'GDP in $': 33274,
#    'Lenght_in_miles': 4.6,
#    'Tunnel_in_miles': 4.6,
#    'Avg Cost/miles': 967.07,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 601.15,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'India',
#    '# Records in Database': 34,
#    'Length': 1184.14,
#    'Tunnel': 261.19100000000003,
#    'Stations': 1000,
#    'Real cost (2021 dollars)': 228323.12314328,
#    'Population': '1,352,617,328',
#    'Region': 'South Asia',
#    'GDP in $': 6525,
#    'Lenght_in_miles': 735.79,
#    'Tunnel_in_miles': 162.3,
#    'Avg Cost/miles': 310.31,
#    'Avg Tunnel %': 22.0,
#    'Avg Cost/km': 192.82,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Indonesia',
#    '# Records in Database': 1,
#    'Length': 15.7,
#    'Tunnel': 5.9,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 3312.8536231139096,
#    'Population': '267,663,435',
#    'Region': 'South East Asia',
#    'GDP in $': 12072,
#    'Lenght_in_miles': 9.76,
#    'Tunnel_in_miles': 3.67,
#    'Avg Cost/miles': 339.43,
#    'Avg Tunnel %': 38.0,
#    'Avg Cost/km': 211.01,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Iran',
#    '# Records in Database': 3,
#    'Length': 70.0,
#    'Tunnel': 70.0,
#    'Stations': 65,
#    'Real cost (2021 dollars)': 15526.504994797782,
#    'Population': '81,800,269',
#    'Region': 'Middle East',
#    'GDP in $': 15791,
#    'Lenght_in_miles': 43.5,
#    'Tunnel_in_miles': 43.5,
#    'Avg Cost/miles': 356.93,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 221.81,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Israel',
#    '# Records in Database': 2,
#    'Length': 62.6,
#    'Tunnel': 16.6,
#    'Stations': 96,
#    'Real cost (2021 dollars)': 10701.721101921557,
#    'Population': '8,883,800',
#    'Region': 'Middle East',
#    'GDP in $': 39489,
#    'Lenght_in_miles': 38.9,
#    'Tunnel_in_miles': 10.31,
#    'Avg Cost/miles': 275.11,
#    'Avg Tunnel %': 27.0,
#    'Avg Cost/km': 170.95,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Italy',
#    '# Records in Database': 34,
#    'Length': 194.5,
#    'Tunnel': 174.4,
#    'Stations': 216,
#    'Real cost (2021 dollars)': 33736.83005945629,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Lenght_in_miles': 120.86,
#    'Tunnel_in_miles': 108.37,
#    'Avg Cost/miles': 279.14,
#    'Avg Tunnel %': 90.0,
#    'Avg Cost/km': 173.45,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Japan',
#    '# Records in Database': 16,
#    'Length': 189.2,
#    'Tunnel': 80.60000000000001,
#    'Stations': 107,
#    'Real cost (2021 dollars)': 45336.78228009197,
#    'Population': '126,529,100',
#    'Region': 'East Asia',
#    'GDP in $': 42100,
#    'Lenght_in_miles': 117.56,
#    'Tunnel_in_miles': 50.08,
#    'Avg Cost/miles': 385.65,
#    'Avg Tunnel %': 43.0,
#    'Avg Cost/km': 239.62,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Kuwait',
#    '# Records in Database': 1,
#    'Length': 160.0,
#    'Tunnel': 56.0,
#    'Stations': 68,
#    'Real cost (2021 dollars)': 31828.19895599492,
#    'Population': '4,137,309',
#    'Region': 'Middle East',
#    'GDP in $': 47303,
#    'Lenght_in_miles': 99.42,
#    'Tunnel_in_miles': 34.8,
#    'Avg Cost/miles': 320.14,
#    'Avg Tunnel %': 35.0,
#    'Avg Cost/km': 198.93,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Malaysia',
#    '# Records in Database': 2,
#    'Length': 103.2,
#    'Tunnel': 23.0,
#    'Stations': 72,
#    'Real cost (2021 dollars)': 39476.79408630439,
#    'Population': '31,528,585',
#    'Region': 'South East Asia',
#    'GDP in $': 27921,
#    'Lenght_in_miles': 64.13,
#    'Tunnel_in_miles': 14.29,
#    'Avg Cost/miles': 615.57,
#    'Avg Tunnel %': 22.0,
#    'Avg Cost/km': 382.53,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Mexico',
#    '# Records in Database': 2,
#    'Length': 46.0,
#    'Tunnel': 15.9,
#    'Stations': 38,
#    'Real cost (2021 dollars)': 11430.154363048798,
#    'Population': '126,190,788',
#    'Region': 'N.America',
#    'GDP in $': 18671,
#    'Lenght_in_miles': 28.58,
#    'Tunnel_in_miles': 9.88,
#    'Avg Cost/miles': 399.94,
#    'Avg Tunnel %': 35.0,
#    'Avg Cost/km': 248.48,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Netherlands',
#    '# Records in Database': 1,
#    'Length': 9.7,
#    'Tunnel': 7.1,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 5090.073507133968,
#    'Population': '17,231,017',
#    'Region': 'Europe',
#    'GDP in $': 59267,
#    'Lenght_in_miles': 6.03,
#    'Tunnel_in_miles': 4.41,
#    'Avg Cost/miles': 844.12,
#    'Avg Tunnel %': 73.0,
#    'Avg Cost/km': 524.75,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'New Zealand',
#    '# Records in Database': 1,
#    'Length': 3.5,
#    'Tunnel': 3.5,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 3228.308741333376,
#    'Population': '4,885,500',
#    'Region': 'Oceania',
#    'GDP in $': 44658,
#    'Lenght_in_miles': 2.17,
#    'Tunnel_in_miles': 2.17,
#    'Avg Cost/miles': 1487.7,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 922.37,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Norway',
#    '# Records in Database': 2,
#    'Length': 9.8,
#    'Tunnel': 9.799999999999999,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 2882.0892128784803,
#    'Population': '5,314,336',
#    'Region': 'Europe',
#    'GDP in $': 62645,
#    'Lenght_in_miles': 6.09,
#    'Tunnel_in_miles': 6.09,
#    'Avg Cost/miles': 473.25,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 294.09,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Pakistan',
#    '# Records in Database': 1,
#    'Length': 27.1,
#    'Tunnel': 1.6,
#    'Stations': 26,
#    'Real cost (2021 dollars)': 6675.864188968669,
#    'Population': '212,215,030',
#    'Region': 'South Asia',
#    'GDP in $': 5426,
#    'Lenght_in_miles': 16.84,
#    'Tunnel_in_miles': 0.99,
#    'Avg Cost/miles': 396.43,
#    'Avg Tunnel %': 6.0,
#    'Avg Cost/km': 246.34,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Panama',
#    '# Records in Database': 3,
#    'Length': 61.4,
#    'Tunnel': 7.3,
#    'Stations': 42,
#    'Real cost (2021 dollars)': 14317.966978527973,
#    'Population': '4,176,873',
#    'Region': 'N.America',
#    'GDP in $': 26780,
#    'Lenght_in_miles': 38.15,
#    'Tunnel_in_miles': 4.54,
#    'Avg Cost/miles': 375.31,
#    'Avg Tunnel %': 12.0,
#    'Avg Cost/km': 233.19,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Peru',
#    '# Records in Database': 1,
#    'Length': 35.0,
#    'Tunnel': 35.0,
#    'Stations': 35,
#    'Real cost (2021 dollars)': 11752.558107151377,
#    'Population': '31,989,256',
#    'Region': 'S.America',
#    'GDP in $': 11908,
#    'Lenght_in_miles': 21.75,
#    'Tunnel_in_miles': 21.75,
#    'Avg Cost/miles': 540.35,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 335.79,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Philippines',
#    '# Records in Database': 4,
#    'Length': 77.7,
#    'Tunnel': 42.7,
#    'Stations': 48,
#    'Real cost (2021 dollars)': 33657.296272505344,
#    'Population': '106,651,922',
#    'Region': 'South East Asia',
#    'GDP in $': 8394,
#    'Lenght_in_miles': 48.28,
#    'Tunnel_in_miles': 26.53,
#    'Avg Cost/miles': 697.13,
#    'Avg Tunnel %': 55.00000000000001,
#    'Avg Cost/km': 433.17,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Poland',
#    '# Records in Database': 5,
#    'Length': 22.25,
#    'Tunnel': 22.25,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 7161.537371535174,
#    'Population': '37,978,548',
#    'Region': 'Europe',
#    'GDP in $': 34287,
#    'Lenght_in_miles': 13.83,
#    'Tunnel_in_miles': 13.83,
#    'Avg Cost/miles': 517.83,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 321.87,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Portugal',
#    '# Records in Database': 2,
#    'Length': 8.0,
#    'Tunnel': 4.8,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 681.2,
#    'Population': '10,281,762',
#    'Region': 'Europe',
#    'GDP in $': 34177,
#    'Lenght_in_miles': 4.97,
#    'Tunnel_in_miles': 2.98,
#    'Avg Cost/miles': 137.06,
#    'Avg Tunnel %': 60.0,
#    'Avg Cost/km': 85.15,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Qatar',
#    '# Records in Database': 1,
#    'Length': 124.0,
#    'Tunnel': 111.5,
#    'Stations': 0,
#    'Real cost (2021 dollars)': 104685.84331013881,
#    'Population': '2,781,677',
#    'Region': 'Middle East',
#    'GDP in $': 89961,
#    'Lenght_in_miles': 77.05,
#    'Tunnel_in_miles': 69.28,
#    'Avg Cost/miles': 1358.67,
#    'Avg Tunnel %': 90.0,
#    'Avg Cost/km': 844.24,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Romania',
#    '# Records in Database': 2,
#    'Length': 27.9,
#    'Tunnel': 27.9,
#    'Stations': 29,
#    'Real cost (2021 dollars)': 6546.760105496924,
#    'Population': '19,473,936',
#    'Region': 'Europe',
#    'GDP in $': 32202,
#    'Lenght_in_miles': 17.34,
#    'Tunnel_in_miles': 17.34,
#    'Avg Cost/miles': 377.55,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 234.65,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Russia',
#    '# Records in Database': 5,
#    'Length': 92.2,
#    'Tunnel': 82.0,
#    'Stations': 41,
#    'Real cost (2021 dollars)': 27682.739000762456,
#    'Population': '144,478,050',
#    'Region': 'Europe',
#    'GDP in $': 29916,
#    'Lenght_in_miles': 57.29,
#    'Tunnel_in_miles': 50.95,
#    'Avg Cost/miles': 483.2,
#    'Avg Tunnel %': 89.0,
#    'Avg Cost/km': 300.25,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Saudi Arabia',
#    '# Records in Database': 9,
#    'Length': 575.5,
#    'Tunnel': 53.9,
#    'Stations': 251,
#    'Real cost (2021 dollars)': 146546.34407321326,
#    'Population': '33,699,947',
#    'Region': 'Middle East',
#    'GDP in $': 46778,
#    'Lenght_in_miles': 357.6,
#    'Tunnel_in_miles': 33.49,
#    'Avg Cost/miles': 409.81,
#    'Avg Tunnel %': 9.0,
#    'Avg Cost/km': 254.64,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Serbia',
#    '# Records in Database': 2,
#    'Length': 42.0,
#    'Tunnel': 42.0,
#    'Stations': 45,
#    'Real cost (2021 dollars)': 12200.0,
#    'Population': '6,982,084',
#    'Region': 'Europe',
#    'GDP in $': 19094,
#    'Lenght_in_miles': 26.1,
#    'Tunnel_in_miles': 26.1,
#    'Avg Cost/miles': 467.43,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 290.48,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Singapore',
#    '# Records in Database': 4,
#    'Length': 124.4,
#    'Tunnel': 124.4,
#    'Stations': 99,
#    'Real cost (2021 dollars)': 76796.0743746688,
#    'Population': '5,638,676',
#    'Region': 'South East Asia',
#    'GDP in $': 99681,
#    'Lenght_in_miles': 77.3,
#    'Tunnel_in_miles': 77.3,
#    'Avg Cost/miles': 993.48,
#    'Avg Tunnel %': 100.0,
#    'Avg Cost/km': 617.33,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'South Korea',
#    '# Records in Database': 19,
#    'Length': 379.05,
#    'Tunnel': 260.451,
#    'Stations': 174,
#    'Real cost (2021 dollars)': 36325.98355605313,
#    'Population': '51,635,256',
#    'Region': 'East Asia',
#    'GDP in $': 45226,
#    'Lenght_in_miles': 235.53,
#    'Tunnel_in_miles': 161.84,
#    'Avg Cost/miles': 154.23,
#    'Avg Tunnel %': 69.0,
#    'Avg Cost/km': 95.83,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Spain',
#    '# Records in Database': 15,
#    'Length': 253.8,
#    'Tunnel': 205.7,
#    'Stations': 200,
#    'Real cost (2021 dollars)': 26470.366527181686,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Lenght_in_miles': 157.7,
#    'Tunnel_in_miles': 127.82,
#    'Avg Cost/miles': 167.85,
#    'Avg Tunnel %': 81.0,
#    'Avg Cost/km': 104.3,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Sweden',
#    '# Records in Database': 6,
#    'Length': 51.3,
#    'Tunnel': 36.9,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 10728.30996736903,
#    'Population': '10,183,175',
#    'Region': 'Europe',
#    'GDP in $': 55065,
#    'Lenght_in_miles': 31.88,
#    'Tunnel_in_miles': 22.93,
#    'Avg Cost/miles': 336.52,
#    'Avg Tunnel %': 72.0,
#    'Avg Cost/km': 209.13,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Switzerland',
#    '# Records in Database': 3,
#    'Length': 19.9,
#    'Tunnel': 14.6,
#    'Stations': 6,
#    'Real cost (2021 dollars)': 3104.4690782168614,
#    'Population': '8,516,543',
#    'Region': 'Europe',
#    'GDP in $': 71745,
#    'Lenght_in_miles': 12.37,
#    'Tunnel_in_miles': 9.07,
#    'Avg Cost/miles': 250.97,
#    'Avg Tunnel %': 73.0,
#    'Avg Cost/km': 156.0,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Taiwan',
#    '# Records in Database': 17,
#    'Length': 381.09,
#    'Tunnel': 174.60000000000002,
#    'Stations': 312,
#    'Real cost (2021 dollars)': 140442.6972061943,
#    'Population': '22,894,384',
#    'Region': 'East Asia',
#    'GDP in $': 55724,
#    'Lenght_in_miles': 236.8,
#    'Tunnel_in_miles': 108.49,
#    'Avg Cost/miles': 593.09,
#    'Avg Tunnel %': 46.0,
#    'Avg Cost/km': 368.53,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Thailand',
#    '# Records in Database': 8,
#    'Length': 197.4,
#    'Tunnel': 39.6,
#    'Stations': 155,
#    'Real cost (2021 dollars)': 49322.69924462515,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Lenght_in_miles': 122.66,
#    'Tunnel_in_miles': 24.61,
#    'Avg Cost/miles': 402.11,
#    'Avg Tunnel %': 20.0,
#    'Avg Cost/km': 249.86,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Turkey',
#    '# Records in Database': 28,
#    'Length': 489.77,
#    'Tunnel': 354.02,
#    'Stations': 335,
#    'Real cost (2021 dollars)': 59447.59168818831,
#    'Population': '82,319,724',
#    'Region': 'Middle East',
#    'GDP in $': 27235,
#    'Lenght_in_miles': 304.33,
#    'Tunnel_in_miles': 219.98,
#    'Avg Cost/miles': 195.34,
#    'Avg Tunnel %': 72.0,
#    'Avg Cost/km': 121.38,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Ukraine',
#    '# Records in Database': 3,
#    'Length': 27.2,
#    'Tunnel': 20.2,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 8249.020853866336,
#    'Population': '44,622,516',
#    'Region': 'Europe',
#    'GDP in $': 13087,
#    'Lenght_in_miles': 16.9,
#    'Tunnel_in_miles': 12.55,
#    'Avg Cost/miles': 488.11,
#    'Avg Tunnel %': 74.0,
#    'Avg Cost/km': 303.27,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'United Arab Emirates',
#    '# Records in Database': 3,
#    'Length': 72.5,
#    'Tunnel': 15.8,
#    'Stations': 56,
#    'Real cost (2021 dollars)': 25903.624432543435,
#    'Population': '9,630,959',
#    'Region': 'Middle East',
#    'GDP in $': 66766,
#    'Lenght_in_miles': 45.05,
#    'Tunnel_in_miles': 9.82,
#    'Avg Cost/miles': 575.0,
#    'Avg Tunnel %': 22.0,
#    'Avg Cost/km': 357.29,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'United Kingdom',
#    '# Records in Database': 3,
#    'Length': 40.2,
#    'Tunnel': 37.0,
#    'Stations': 21,
#    'Real cost (2021 dollars)': 31744.599613861028,
#    'Population': '66,488,991',
#    'Region': 'Europe',
#    'GDP in $': 46527,
#    'Lenght_in_miles': 24.98,
#    'Tunnel_in_miles': 22.99,
#    'Avg Cost/miles': 1270.8,
#    'Avg Tunnel %': 92.0,
#    'Avg Cost/km': 789.67,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'United States',
#    '# Records in Database': 21,
#    'Length': 180.8,
#    'Tunnel': 62.00000000000001,
#    'Stations': 98,
#    'Real cost (2021 dollars)': 101127.32298875922,
#    'Population': '327,167,434',
#    'Region': 'N.America',
#    'GDP in $': 63028,
#    'Lenght_in_miles': 112.34,
#    'Tunnel_in_miles': 38.53,
#    'Avg Cost/miles': 900.19,
#    'Avg Tunnel %': 34.0,
#    'Avg Cost/km': 559.33,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Uzbekistan',
#    '# Records in Database': 2,
#    'Length': 9.84,
#    'Tunnel': 2.9,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 1440.60081957094,
#    'Population': '32,955,400',
#    'Region': 'Central Asia',
#    'GDP in $': 7746,
#    'Lenght_in_miles': 6.11,
#    'Tunnel_in_miles': 1.8,
#    'Avg Cost/miles': 235.78,
#    'Avg Tunnel %': 28.999999999999996,
#    'Avg Cost/km': 146.4,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94},
#   {'Country': 'Vietnam',
#    '# Records in Database': 5,
#    'Length': 63.9,
#    'Tunnel': 31.9,
#    'Stations': 56,
#    'Real cost (2021 dollars)': 25429.997275583984,
#    'Population': '95,540,395',
#    'Region': 'South East Asia',
#    'GDP in $': 10904,
#    'Lenght_in_miles': 39.71,
#    'Tunnel_in_miles': 19.82,
#    'Avg Cost/miles': 640.39,
#    'Avg Tunnel %': 50.0,
#    'Avg Cost/km': 397.97,
#    'Avg Cost/km (all projects)': 211.85,
#    'Avg Cost/miles (all projects)': 340.94}]}

# %%
#save the data on file
import json
import os
folder = r'C:\Users\elife\Documents\NYU\CCP\ANALYSIS\240226_update_charts'
file = "data_country_group.js"

# To export Np formats
def np_encoder(object):
    if isinstance(object, np.generic):
        return object.item()

with open(os.path.join(folder,file), "w") as outfile: 
    json_text = json.dumps(data_dict, indent=1 , default=np_encoder)
    test = "var data = " + json_text
    outfile.write( test )

print('done')
# Out:
# done

# %% [markdown]
# ### Calculate weighted average

# %%
total_length_miles=df_gr_co['Lenght_in_miles'].sum()
total_length_miles
# Out:
# 12298.759999999998

# %%
total_length_km=df_gr_co['Length'].sum()
total_length_km
# Out:
# 19792.900000000005

# %%
total_cost=df_gr_co['Real cost (2021 dollars)'].sum()
total_cost
# Out:
# 4193164.468717305

# %%
WAv_CostpMiles=total_cost/total_length_miles
WAv_Costpkm=total_cost/total_length_km

# %%
print('Weighted Average of Cost/Km is '+WAv_Costpkm.round(2).astype(str))
print('Weighted Average of Cost/Miles is '+WAv_CostpMiles.round(2).astype(str))
# Out:
# Weighted Average of Cost/Km is 211.85
# Weighted Average of Cost/Miles is 340.94

# %%
df['Duration']=df['End year']-df['Start year']
df['Duration/km']=df['Length']/df['Duration']
df.sample(10)
# Out:
#      CO        City             Phase              Line  Start year  End year  \
# 526  CN       Xi'an   Line 15 Phase 1           Line 15      2020.0    2025.0
# 216  DK  Copenhagen  City Circle Line  City Circle Line      2009.0    2019.0
# 497  CN      Fuzhou            Line 6            Line 6      2015.0    2019.0
# 641  CN        Wuxi      Line 1 South            Line 1         NaN    2019.0
# 521  CN    Hangzhou            Line 7            Line 7      2017.0    2021.0
# 279  PH      Manila            Line 4            Line 4      2021.0    2025.0
# 239  IN      Mumbai           Line 12           Line 12      2020.0    2026.0
# 16   TR    Istanbul    M5 Phase 2-M13                M5      2016.0    2027.0
# 684  CN      Urumqi            Line 1            Line 1      2014.0    2019.0
# 804  CN    Shenyang    Line 9 Phase 1            Line 9      2012.0    2020.0
#
#      Length TunnelPer  Tunnel Stations  ...  Cost/km (2021 dollars)  \
# 526      19         1      19       11  ...              165.107801
# 216    15.5         1    15.5       17  ...              257.824875
# 497    40.5  0.790123      32       20  ...              201.853809
# 641   5.187         1   5.187        3  ...              126.346547
# 521      45       NaN     NaN       22  ...              182.604543
# 279    15.6         0       0       11  ...              209.070513
# 239    20.8         0       0       17  ...              117.987324
# 16     17.8         1    17.8       13  ...              117.362714
# 684  27.615         1  27.615       21  ...              207.555838
# 804    29.2         1    29.2       23  ...              174.405597
#
#          Country     Population           Region  GDP in $ Duration  \
# 526        China  1,392,730,000        East Asia  17,189.0      5.0
# 216      Denmark      5,797,446           Europe  60,230.0     10.0
# 497        China  1,392,730,000        East Asia  17,189.0      4.0
# 641        China  1,392,730,000        East Asia  17,189.0      NaN
# 521        China  1,392,730,000        East Asia  17,189.0      4.0
# 279  Philippines    106,651,922  South East Asia   8,394.0      4.0
# 239        India  1,352,617,328       South Asia   6,525.0      6.0
# 16        Turkey     82,319,724      Middle East  27,235.0     11.0
# 684        China  1,392,730,000        East Asia  17,189.0      5.0
# 804        China  1,392,730,000        East Asia  17,189.0      8.0
#
#      Duration/km                       Detail  \
# 526          3.8        Xi'an Line 15 Phase 1
# 216         1.55  Copenhagen City Circle Line
# 497       10.125                Fuzhou Line 6
# 641          NaN            Wuxi Line 1 South
# 521        11.25              Hangzhou Line 7
# 279          3.9                Manila Line 4
# 239      3.46667               Mumbai Line 12
# 16       1.61818      Istanbul M5 Phase 2-M13
# 684        5.523                Urumqi Line 1
# 804         3.65      Shenyang Line 9 Phase 1
#
#                            Detail Start                        Detail End
# 526        Xi'an Line 15 Phase 1 starts        Xi'an Line 15 Phase 1 ends
# 216  Copenhagen City Circle Line starts  Copenhagen City Circle Line ends
# 497                Fuzhou Line 6 starts                Fuzhou Line 6 ends
# 641            Wuxi Line 1 South starts            Wuxi Line 1 South ends
# 521              Hangzhou Line 7 starts              Hangzhou Line 7 ends
# 279                Manila Line 4 starts                Manila Line 4 ends
# 239               Mumbai Line 12 starts               Mumbai Line 12 ends
# 16       Istanbul M5 Phase 2-M13 starts      Istanbul M5 Phase 2-M13 ends
# 684                Urumqi Line 1 starts                Urumqi Line 1 ends
# 804      Shenyang Line 9 Phase 1 starts      Shenyang Line 9 Phase 1 ends
#
# [10 rows x 21 columns]

# %%
len(df)
# Out:
# 883

# %%
#drop all rows with no Duration value
df_dur=df.dropna(axis=0,how='all', subset=['Duration'])

# %%
len(df_dur)
# Out:
# 629

# %%
df_dur.sample(10)
# Out:
#      CO       City                               Phase                   Line  \
# 295  ES  Barcelona                     Sabadell tunnel        Sabadell tunnel
# 30   CA    Toronto                         Scarborough            Scarborough
# 243  IN      Delhi                 Phase 4 second half                Phase 4
# 429  CN    Beijing  Line 7 Phase 2 (Eastern Extension)                 Line 7
# 719  CN  Changchun              Line 1 South Extension                 Line 1
# 279  PH     Manila                              Line 4                 Line 4
# 332  JP      Tokyo    Sotetsu Shin-Yokohama Tokyu Line  Sotetsu Shin-Yokohama
# 317  TH    Bangkok                           Pink Line              Pink Line
# 708  CN  Zhengzhou                      Line 1 Phase 1                 Line 1
# 730  CN    Chengdu                      Line 3 Phase 2                 Line 3
#
#      Start year  End year Length TunnelPer Tunnel Stations  ...  \
# 295      2006.0    2017.0    4.4         1    4.4        4  ...
# 30       2020.0    2030.0    7.8         1    7.8        3  ...
# 243      2019.0    2025.0   42.3      0.35   14.7       43  ...
# 429      2016.0    2020.0   17.2  0.872093     15        9  ...
# 719      2010.0    2019.0      8         1      8        6  ...
# 279      2021.0    2025.0   15.6         0      0       11  ...
# 332      2010.0    2022.0     10       0.8      8        2  ...
# 317      2017.0    2022.0   34.5         0      0       30  ...
# 708      2009.0    2013.0   25.2         1   25.2       20  ...
# 730      2013.0    2020.0     15       0.6      9        9  ...
#
#      Cost/km (2021 dollars)      Country     Population           Region  \
# 295              153.043744        Spain     46,723,749           Europe
# 30               639.160260       Canada     37,058,856        N.America
# 243              239.292778        India  1,352,617,328       South Asia
# 429              252.571726        China  1,392,730,000        East Asia
# 719              203.521601        China  1,392,730,000        East Asia
# 279              209.070513  Philippines    106,651,922  South East Asia
# 332              311.899954        Japan    126,529,100        East Asia
# 317              141.157498     Thailand     69,428,524  South East Asia
# 708              194.619833        China  1,392,730,000        East Asia
# 730              123.823886        China  1,392,730,000        East Asia
#
#      GDP in $ Duration  Duration/km  \
# 295  37,756.0     11.0          0.4
# 30   46,572.0     10.0         0.78
# 243   6,525.0      6.0         7.05
# 429  17,189.0      4.0          4.3
# 719  17,189.0      9.0     0.888889
# 279   8,394.0      4.0          3.9
# 332  42,100.0     12.0     0.833333
# 317  18,198.0      5.0          6.9
# 708  17,189.0      4.0          6.3
# 730  17,189.0      7.0      2.14286
#
#                                          Detail  \
# 295                   Barcelona Sabadell tunnel
# 30                          Toronto Scarborough
# 243                   Delhi Phase 4 second half
# 429  Beijing Line 7 Phase 2 (Eastern Extension)
# 719            Changchun Line 1 South Extension
# 279                               Manila Line 4
# 332      Tokyo Sotetsu Shin-Yokohama Tokyu Line
# 317                           Bangkok Pink Line
# 708                    Zhengzhou Line 1 Phase 1
# 730                      Chengdu Line 3 Phase 2
#
#                                           Detail Start  \
# 295                   Barcelona Sabadell tunnel starts
# 30                          Toronto Scarborough starts
# 243                   Delhi Phase 4 second half starts
# 429  Beijing Line 7 Phase 2 (Eastern Extension) starts
# 719            Changchun Line 1 South Extension starts
# 279                               Manila Line 4 starts
# 332      Tokyo Sotetsu Shin-Yokohama Tokyu Line starts
# 317                           Bangkok Pink Line starts
# 708                    Zhengzhou Line 1 Phase 1 starts
# 730                      Chengdu Line 3 Phase 2 starts
#
#                                           Detail End
# 295                   Barcelona Sabadell tunnel ends
# 30                          Toronto Scarborough ends
# 243                   Delhi Phase 4 second half ends
# 429  Beijing Line 7 Phase 2 (Eastern Extension) ends
# 719            Changchun Line 1 South Extension ends
# 279                               Manila Line 4 ends
# 332      Tokyo Sotetsu Shin-Yokohama Tokyu Line ends
# 317                           Bangkok Pink Line ends
# 708                    Zhengzhou Line 1 Phase 1 ends
# 730                      Chengdu Line 3 Phase 2 ends
#
# [10 rows x 21 columns]

# %% [markdown]
# #### We go back again and regroup by country, this time also taking into account the duration info. We didn't do this before not to lose entries without duration information.

# %%
#defining the aggregate functions for group by per project (we will group the different phases of projects into single projects)
agg3_functions={'Country':'first','Phase':'count','Length':'sum','Tunnel':'sum','Stations':'sum','Real cost (2021 dollars)':'sum', 'Population':'first','Region':'first','GDP in $':'first','Duration':'sum'}

# %%
df_gr_co_dur=df_dur.groupby(['Country'], as_index=False).aggregate(agg3_functions)
df_gr_co_dur = df_gr_co_dur.rename({'Phase': '# Records in Database'}, axis='columns')
df_gr_co_dur["Avg Cost/km"]=(df_gr_co_dur['Real cost (2021 dollars)']/df_gr_co['Length']).round(2)
df_gr_co_dur["Avg Tunnel %"]= ((df_gr_co_dur['Tunnel']/df_gr_co_dur['Length'])*100).round(2)
df_gr_co_dur['Length']=df_gr_co_dur['Length'].astype( float ).round(2)
df_gr_co_dur["Avg Duration/km"] = (df_gr_co_dur['Duration']/df_gr_co_dur['Length']).round(2)
df_gr_co_dur['GDP in $'] = df_gr_co_dur['GDP in $'].str.replace(",","").astype( float ).astype( pd.Int64Dtype() )
df_gr_co_dur['Avg Cost/km (all projects)']=(df_gr_co_dur['Real cost (2021 dollars)'].sum()/df_gr_co_dur['Length'].sum()).round(2)

# %%
len(df_gr_co_dur)
# Out:
# 59

# %%
df_gr_co_dur['Real cost (2021 dollars)']= df_gr_co_dur['Real cost (2021 dollars)'].round(2)

# %%
df_gr_co_dur.sample(10)
# Out:
#                Country  # Records in Database  Length   Tunnel  Stations  \
# 28              Kuwait                      1   160.0   56.000        68
# 43        Saudi Arabia                      7   337.5   53.900       161
# 13  Dominican Republic                      2    31.0   26.000        34
# 20           Hong Kong                     14   120.6   78.675        78
# 4           Bangladesh                      3    72.1   33.900        49
# 12             Denmark                      1    15.5   15.500        17
# 45           Singapore                      4   124.4  124.400        99
# 37         Philippines                      4    77.7   42.700        48
# 17              France                     17   286.9  231.200       137
# 39            Portugal                      2     8.0    4.800         9
#
#     Real cost (2021 dollars)   Population           Region  GDP in $  \
# 28                  31828.20    4,137,309      Middle East     47303
# 43                  66817.12   33,699,947      Middle East     46778
# 13                   4926.51   10,627,165        N.America     17934
# 20                  92038.22    7,451,000        East Asia     58980
# 4                   41368.28  161,356,039       South Asia      5995
# 12                   3996.29    5,797,446           Europe     60230
# 45                  76796.07    5,638,676  South East Asia     99681
# 37                  33657.30  106,651,922  South East Asia      8394
# 17                  73315.91   66,987,244           Europe     46991
# 39                    681.20   10,281,762           Europe     34177
#
#     Duration  Avg Cost/km  Avg Tunnel %  Avg Duration/km  \
# 28       5.0       198.93         35.00             0.03
# 43      33.0       116.10         15.97             0.10
# 13      12.0       158.92         83.87             0.39
# 20      72.0       763.17         65.24             0.60
# 4       21.0       573.76         47.02             0.29
# 12      10.0       257.82        100.00             0.65
# 45      37.0       617.33        100.00             0.30
# 37      22.0       433.17         54.95             0.28
# 17     108.0       255.55         80.59             0.38
# 39       6.0        85.15         60.00             0.75
#
#     Avg Cost/km (all projects)
# 28                      230.16
# 43                      230.16
# 13                      230.16
# 20                      230.16
# 4                       230.16
# 12                      230.16
# 45                      230.16
# 37                      230.16
# 17                      230.16
# 39                      230.16

# %%
#create json dictionary. This is the format the vega library reads data in. Add data-elif to the top because that is what our map jsons have at the top.
data_dict = df_gr_co_dur.to_dict(
    orient= 'records'
)

data_dict = {
    "data-elif": data_dict
}

data_dict
# Out:
# {'data-elif': [{'Country': 'Argentina',
#    '# Records in Database': 1,
#    'Length': 20.0,
#    'Tunnel': 20.0,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 4646.0,
#    'Population': '44,494,502',
#    'Region': 'S.America',
#    'GDP in $': 20769,
#    'Duration': 6.0,
#    'Avg Cost/km': 232.3,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.3,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Australia',
#    '# Records in Database': 4,
#    'Length': 83.5,
#    'Tunnel': 47.9,
#    'Stations': 28,
#    'Real cost (2021 dollars)': 26839.48,
#    'Population': '24,992,369',
#    'Region': 'Oceania',
#    'GDP in $': 53317,
#    'Duration': 25.0,
#    'Avg Cost/km': 321.43,
#    'Avg Tunnel %': 57.37,
#    'Avg Duration/km': 0.3,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Austria',
#    '# Records in Database': 4,
#    'Length': 30.7,
#    'Tunnel': 24.5,
#    'Stations': 19,
#    'Real cost (2021 dollars)': 6497.32,
#    'Population': '8,847,037',
#    'Region': 'Europe',
#    'GDP in $': 55686,
#    'Duration': 31.0,
#    'Avg Cost/km': 211.64,
#    'Avg Tunnel %': 79.8,
#    'Avg Duration/km': 1.01,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Bahrain',
#    '# Records in Database': 1,
#    'Length': 28.6,
#    'Tunnel': 0.0,
#    'Stations': 20,
#    'Real cost (2021 dollars)': 2400.67,
#    'Population': '1,569,439',
#    'Region': 'Middle East',
#    'GDP in $': 43821,
#    'Duration': 5.0,
#    'Avg Cost/km': 23.7,
#    'Avg Tunnel %': 0.0,
#    'Avg Duration/km': 0.17,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Bangladesh',
#    '# Records in Database': 3,
#    'Length': 72.1,
#    'Tunnel': 33.9,
#    'Stations': 49,
#    'Real cost (2021 dollars)': 41368.28,
#    'Population': '161,356,039',
#    'Region': 'South Asia',
#    'GDP in $': 5995,
#    'Duration': 21.0,
#    'Avg Cost/km': 573.76,
#    'Avg Tunnel %': 47.02,
#    'Avg Duration/km': 0.29,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Belgium',
#    '# Records in Database': 1,
#    'Length': 4.8,
#    'Tunnel': 4.8,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 3380.0,
#    'Population': '11,422,068',
#    'Region': 'Europe',
#    'GDP in $': 53070,
#    'Duration': 8.0,
#    'Avg Cost/km': 704.17,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 1.67,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Brazil',
#    '# Records in Database': 6,
#    'Length': 107.9,
#    'Tunnel': 42.2,
#    'Stations': 87,
#    'Real cost (2021 dollars)': 24307.61,
#    'Population': '209,469,333',
#    'Region': 'S.America',
#    'GDP in $': 14834,
#    'Duration': 51.0,
#    'Avg Cost/km': 225.28,
#    'Avg Tunnel %': 39.11,
#    'Avg Duration/km': 0.47,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Bulgaria',
#    '# Records in Database': 5,
#    'Length': 38.4,
#    'Tunnel': 34.7,
#    'Stations': 31,
#    'Real cost (2021 dollars)': 6820.66,
#    'Population': '7,000,039',
#    'Region': 'Europe',
#    'GDP in $': 24564,
#    'Duration': 18.0,
#    'Avg Cost/km': 164.35,
#    'Avg Tunnel %': 90.36,
#    'Avg Duration/km': 0.47,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Canada',
#    '# Records in Database': 15,
#    'Length': 175.3,
#    'Tunnel': 82.1,
#    'Stations': 149,
#    'Real cost (2021 dollars)': 47551.07,
#    'Population': '37,058,856',
#    'Region': 'N.America',
#    'GDP in $': 46572,
#    'Duration': 105.0,
#    'Avg Cost/km': 248.57,
#    'Avg Tunnel %': 46.83,
#    'Avg Duration/km': 0.6,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Chile',
#    '# Records in Database': 2,
#    'Length': 61.8,
#    'Tunnel': 61.8,
#    'Stations': 49,
#    'Real cost (2021 dollars)': 10687.94,
#    'Population': '18,729,160',
#    'Region': 'S.America',
#    'GDP in $': 25089,
#    'Duration': 11.0,
#    'Avg Cost/km': 172.94,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.18,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'China',
#    '# Records in Database': 262,
#    'Length': 6673.38,
#    'Tunnel': 4961.7476,
#    'Stations': 3818,
#    'Real cost (2021 dollars)': 1279433.4,
#    'Population': '1,392,730,000',
#    'Region': 'East Asia',
#    'GDP in $': 17189,
#    'Duration': 1230.0,
#    'Avg Cost/km': 99.32,
#    'Avg Tunnel %': 74.35,
#    'Avg Duration/km': 0.18,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Czech Republic',
#    '# Records in Database': 3,
#    'Length': 21.2,
#    'Tunnel': 20.0,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 8848.73,
#    'Population': '10,625,695',
#    'Region': 'Europe',
#    'GDP in $': 41608,
#    'Duration': 17.0,
#    'Avg Cost/km': 417.39,
#    'Avg Tunnel %': 94.34,
#    'Avg Duration/km': 0.8,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Denmark',
#    '# Records in Database': 1,
#    'Length': 15.5,
#    'Tunnel': 15.5,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 3996.29,
#    'Population': '5,797,446',
#    'Region': 'Europe',
#    'GDP in $': 60230,
#    'Duration': 10.0,
#    'Avg Cost/km': 257.82,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.65,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Dominican Republic',
#    '# Records in Database': 2,
#    'Length': 31.0,
#    'Tunnel': 26.0,
#    'Stations': 34,
#    'Real cost (2021 dollars)': 4926.51,
#    'Population': '10,627,165',
#    'Region': 'N.America',
#    'GDP in $': 17934,
#    'Duration': 12.0,
#    'Avg Cost/km': 158.92,
#    'Avg Tunnel %': 83.87,
#    'Avg Duration/km': 0.39,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Ecuador',
#    '# Records in Database': 1,
#    'Length': 22.9,
#    'Tunnel': 22.9,
#    'Stations': 15,
#    'Real cost (2021 dollars)': 4311.68,
#    'Population': '17,084,357',
#    'Region': 'S.America',
#    'GDP in $': 10890,
#    'Duration': 7.0,
#    'Avg Cost/km': 188.28,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.31,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Egypt',
#    '# Records in Database': 3,
#    'Length': 70.3,
#    'Tunnel': 20.1,
#    'Stations': 60,
#    'Real cost (2021 dollars)': 23049.69,
#    'Population': '98,423,595',
#    'Region': 'Middle East',
#    'GDP in $': 12606,
#    'Duration': 23.0,
#    'Avg Cost/km': 208.97,
#    'Avg Tunnel %': 28.59,
#    'Avg Duration/km': 0.33,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Finland',
#    '# Records in Database': 3,
#    'Length': 38.5,
#    'Tunnel': 28.5,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 4646.34,
#    'Population': '5,518,050',
#    'Region': 'Europe',
#    'GDP in $': 50937,
#    'Duration': 23.0,
#    'Avg Cost/km': 120.68,
#    'Avg Tunnel %': 74.03,
#    'Avg Duration/km': 0.6,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'France',
#    '# Records in Database': 17,
#    'Length': 286.9,
#    'Tunnel': 231.2,
#    'Stations': 137,
#    'Real cost (2021 dollars)': 73315.91,
#    'Population': '66,987,244',
#    'Region': 'Europe',
#    'GDP in $': 46991,
#    'Duration': 108.0,
#    'Avg Cost/km': 255.55,
#    'Avg Tunnel %': 80.59,
#    'Avg Duration/km': 0.38,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Germany',
#    '# Records in Database': 20,
#    'Length': 71.6,
#    'Tunnel': 62.60000000000001,
#    'Stations': 68,
#    'Real cost (2021 dollars)': 25214.97,
#    'Population': '82,927,922',
#    'Region': 'Europe',
#    'GDP in $': 54845,
#    'Duration': 148.0,
#    'Avg Cost/km': 339.82,
#    'Avg Tunnel %': 87.43,
#    'Avg Duration/km': 2.07,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Greece',
#    '# Records in Database': 4,
#    'Length': 34.7,
#    'Tunnel': 34.699999999999996,
#    'Stations': 39,
#    'Real cost (2021 dollars)': 5284.92,
#    'Population': '10,727,668',
#    'Region': 'Europe',
#    'GDP in $': 27949,
#    'Duration': 39.0,
#    'Avg Cost/km': 152.3,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 1.12,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Hong Kong',
#    '# Records in Database': 14,
#    'Length': 120.6,
#    'Tunnel': 78.67499999999998,
#    'Stations': 78,
#    'Real cost (2021 dollars)': 92038.22,
#    'Population': '7,451,000',
#    'Region': 'East Asia',
#    'GDP in $': 58980,
#    'Duration': 72.0,
#    'Avg Cost/km': 763.17,
#    'Avg Tunnel %': 65.24,
#    'Avg Duration/km': 0.6,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Hungary',
#    '# Records in Database': 1,
#    'Length': 7.4,
#    'Tunnel': 7.4,
#    'Stations': 10,
#    'Real cost (2021 dollars)': 4448.53,
#    'Population': '9,768,785',
#    'Region': 'Europe',
#    'GDP in $': 33274,
#    'Duration': 8.0,
#    'Avg Cost/km': 601.15,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 1.08,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'India',
#    '# Records in Database': 32,
#    'Length': 1109.34,
#    'Tunnel': 258.69100000000003,
#    'Stations': 958,
#    'Real cost (2021 dollars)': 220225.41,
#    'Population': '1,352,617,328',
#    'Region': 'South Asia',
#    'GDP in $': 6525,
#    'Duration': 184.0,
#    'Avg Cost/km': 185.98,
#    'Avg Tunnel %': 23.32,
#    'Avg Duration/km': 0.17,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Indonesia',
#    '# Records in Database': 1,
#    'Length': 15.7,
#    'Tunnel': 5.9,
#    'Stations': 13,
#    'Real cost (2021 dollars)': 3312.85,
#    'Population': '267,663,435',
#    'Region': 'South East Asia',
#    'GDP in $': 12072,
#    'Duration': 6.0,
#    'Avg Cost/km': 211.01,
#    'Avg Tunnel %': 37.58,
#    'Avg Duration/km': 0.38,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Iran',
#    '# Records in Database': 1,
#    'Length': 12.0,
#    'Tunnel': 12.0,
#    'Stations': 11,
#    'Real cost (2021 dollars)': 2791.62,
#    'Population': '81,800,269',
#    'Region': 'Middle East',
#    'GDP in $': 15791,
#    'Duration': 2.0,
#    'Avg Cost/km': 39.88,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.17,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Israel',
#    '# Records in Database': 2,
#    'Length': 62.6,
#    'Tunnel': 16.6,
#    'Stations': 96,
#    'Real cost (2021 dollars)': 10701.72,
#    'Population': '8,883,800',
#    'Region': 'Middle East',
#    'GDP in $': 39489,
#    'Duration': 13.0,
#    'Avg Cost/km': 170.95,
#    'Avg Tunnel %': 26.52,
#    'Avg Duration/km': 0.21,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Italy',
#    '# Records in Database': 32,
#    'Length': 185.8,
#    'Tunnel': 170.5,
#    'Stations': 210,
#    'Real cost (2021 dollars)': 33128.99,
#    'Population': '60,431,283',
#    'Region': 'Europe',
#    'GDP in $': 41988,
#    'Duration': 306.0,
#    'Avg Cost/km': 170.33,
#    'Avg Tunnel %': 91.77,
#    'Avg Duration/km': 1.65,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Japan',
#    '# Records in Database': 16,
#    'Length': 189.2,
#    'Tunnel': 80.60000000000001,
#    'Stations': 107,
#    'Real cost (2021 dollars)': 45336.78,
#    'Population': '126,529,100',
#    'Region': 'East Asia',
#    'GDP in $': 42100,
#    'Duration': 148.0,
#    'Avg Cost/km': 239.62,
#    'Avg Tunnel %': 42.6,
#    'Avg Duration/km': 0.78,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Kuwait',
#    '# Records in Database': 1,
#    'Length': 160.0,
#    'Tunnel': 56.0,
#    'Stations': 68,
#    'Real cost (2021 dollars)': 31828.2,
#    'Population': '4,137,309',
#    'Region': 'Middle East',
#    'GDP in $': 47303,
#    'Duration': 5.0,
#    'Avg Cost/km': 198.93,
#    'Avg Tunnel %': 35.0,
#    'Avg Duration/km': 0.03,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Malaysia',
#    '# Records in Database': 2,
#    'Length': 103.2,
#    'Tunnel': 23.0,
#    'Stations': 72,
#    'Real cost (2021 dollars)': 39476.79,
#    'Population': '31,528,585',
#    'Region': 'South East Asia',
#    'GDP in $': 27921,
#    'Duration': 12.0,
#    'Avg Cost/km': 382.53,
#    'Avg Tunnel %': 22.29,
#    'Avg Duration/km': 0.12,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Mexico',
#    '# Records in Database': 2,
#    'Length': 46.0,
#    'Tunnel': 15.9,
#    'Stations': 38,
#    'Real cost (2021 dollars)': 11430.15,
#    'Population': '126,190,788',
#    'Region': 'N.America',
#    'GDP in $': 18671,
#    'Duration': 10.0,
#    'Avg Cost/km': 248.48,
#    'Avg Tunnel %': 34.57,
#    'Avg Duration/km': 0.22,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Netherlands',
#    '# Records in Database': 1,
#    'Length': 9.7,
#    'Tunnel': 7.1,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 5090.07,
#    'Population': '17,231,017',
#    'Region': 'Europe',
#    'GDP in $': 59267,
#    'Duration': 15.0,
#    'Avg Cost/km': 524.75,
#    'Avg Tunnel %': 73.2,
#    'Avg Duration/km': 1.55,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'New Zealand',
#    '# Records in Database': 1,
#    'Length': 3.5,
#    'Tunnel': 3.5,
#    'Stations': 4,
#    'Real cost (2021 dollars)': 3228.31,
#    'Population': '4,885,500',
#    'Region': 'Oceania',
#    'GDP in $': 44658,
#    'Duration': 11.0,
#    'Avg Cost/km': 922.37,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 3.14,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Norway',
#    '# Records in Database': 2,
#    'Length': 9.8,
#    'Tunnel': 9.799999999999999,
#    'Stations': 7,
#    'Real cost (2021 dollars)': 2882.09,
#    'Population': '5,314,336',
#    'Region': 'Europe',
#    'GDP in $': 62645,
#    'Duration': 12.0,
#    'Avg Cost/km': 294.09,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 1.22,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Pakistan',
#    '# Records in Database': 1,
#    'Length': 27.1,
#    'Tunnel': 1.6,
#    'Stations': 26,
#    'Real cost (2021 dollars)': 6675.86,
#    'Population': '212,215,030',
#    'Region': 'South Asia',
#    'GDP in $': 5426,
#    'Duration': 5.0,
#    'Avg Cost/km': 246.34,
#    'Avg Tunnel %': 5.9,
#    'Avg Duration/km': 0.18,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Panama',
#    '# Records in Database': 3,
#    'Length': 61.4,
#    'Tunnel': 7.3,
#    'Stations': 42,
#    'Real cost (2021 dollars)': 14317.97,
#    'Population': '4,176,873',
#    'Region': 'N.America',
#    'GDP in $': 26780,
#    'Duration': 12.0,
#    'Avg Cost/km': 233.19,
#    'Avg Tunnel %': 11.89,
#    'Avg Duration/km': 0.2,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Peru',
#    '# Records in Database': 1,
#    'Length': 35.0,
#    'Tunnel': 35.0,
#    'Stations': 35,
#    'Real cost (2021 dollars)': 11752.56,
#    'Population': '31,989,256',
#    'Region': 'S.America',
#    'GDP in $': 11908,
#    'Duration': 11.0,
#    'Avg Cost/km': 335.79,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.31,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Philippines',
#    '# Records in Database': 4,
#    'Length': 77.7,
#    'Tunnel': 42.7,
#    'Stations': 48,
#    'Real cost (2021 dollars)': 33657.3,
#    'Population': '106,651,922',
#    'Region': 'South East Asia',
#    'GDP in $': 8394,
#    'Duration': 22.0,
#    'Avg Cost/km': 433.17,
#    'Avg Tunnel %': 54.95,
#    'Avg Duration/km': 0.28,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Poland',
#    '# Records in Database': 5,
#    'Length': 22.25,
#    'Tunnel': 22.25,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 7161.54,
#    'Population': '37,978,548',
#    'Region': 'Europe',
#    'GDP in $': 34287,
#    'Duration': 23.0,
#    'Avg Cost/km': 321.87,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 1.03,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Portugal',
#    '# Records in Database': 2,
#    'Length': 8.0,
#    'Tunnel': 4.8,
#    'Stations': 9,
#    'Real cost (2021 dollars)': 681.2,
#    'Population': '10,281,762',
#    'Region': 'Europe',
#    'GDP in $': 34177,
#    'Duration': 6.0,
#    'Avg Cost/km': 85.15,
#    'Avg Tunnel %': 60.0,
#    'Avg Duration/km': 0.75,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Qatar',
#    '# Records in Database': 1,
#    'Length': 124.0,
#    'Tunnel': 111.5,
#    'Stations': 0,
#    'Real cost (2021 dollars)': 104685.84,
#    'Population': '2,781,677',
#    'Region': 'Middle East',
#    'GDP in $': 89961,
#    'Duration': 13.0,
#    'Avg Cost/km': 844.24,
#    'Avg Tunnel %': 89.92,
#    'Avg Duration/km': 0.1,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Romania',
#    '# Records in Database': 2,
#    'Length': 27.9,
#    'Tunnel': 27.9,
#    'Stations': 29,
#    'Real cost (2021 dollars)': 6546.76,
#    'Population': '19,473,936',
#    'Region': 'Europe',
#    'GDP in $': 32202,
#    'Duration': 13.0,
#    'Avg Cost/km': 234.65,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.47,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Russia',
#    '# Records in Database': 5,
#    'Length': 92.2,
#    'Tunnel': 82.0,
#    'Stations': 41,
#    'Real cost (2021 dollars)': 27682.74,
#    'Population': '144,478,050',
#    'Region': 'Europe',
#    'GDP in $': 29916,
#    'Duration': 22.0,
#    'Avg Cost/km': 300.25,
#    'Avg Tunnel %': 88.94,
#    'Avg Duration/km': 0.24,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Saudi Arabia',
#    '# Records in Database': 7,
#    'Length': 337.5,
#    'Tunnel': 53.9,
#    'Stations': 161,
#    'Real cost (2021 dollars)': 66817.12,
#    'Population': '33,699,947',
#    'Region': 'Middle East',
#    'GDP in $': 46778,
#    'Duration': 33.0,
#    'Avg Cost/km': 116.1,
#    'Avg Tunnel %': 15.97,
#    'Avg Duration/km': 0.1,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Serbia',
#    '# Records in Database': 2,
#    'Length': 42.0,
#    'Tunnel': 42.0,
#    'Stations': 45,
#    'Real cost (2021 dollars)': 12200.0,
#    'Population': '6,982,084',
#    'Region': 'Europe',
#    'GDP in $': 19094,
#    'Duration': 10.0,
#    'Avg Cost/km': 290.48,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.24,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Singapore',
#    '# Records in Database': 4,
#    'Length': 124.4,
#    'Tunnel': 124.4,
#    'Stations': 99,
#    'Real cost (2021 dollars)': 76796.07,
#    'Population': '5,638,676',
#    'Region': 'South East Asia',
#    'GDP in $': 99681,
#    'Duration': 37.0,
#    'Avg Cost/km': 617.33,
#    'Avg Tunnel %': 100.0,
#    'Avg Duration/km': 0.3,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'South Korea',
#    '# Records in Database': 14,
#    'Length': 339.5,
#    'Tunnel': 250.1,
#    'Stations': 163,
#    'Real cost (2021 dollars)': 30983.35,
#    'Population': '51,635,256',
#    'Region': 'East Asia',
#    'GDP in $': 45226,
#    'Duration': 95.0,
#    'Avg Cost/km': 81.74,
#    'Avg Tunnel %': 73.67,
#    'Avg Duration/km': 0.28,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Spain',
#    '# Records in Database': 15,
#    'Length': 253.8,
#    'Tunnel': 205.7,
#    'Stations': 200,
#    'Real cost (2021 dollars)': 26470.37,
#    'Population': '46,723,749',
#    'Region': 'Europe',
#    'GDP in $': 37756,
#    'Duration': 107.0,
#    'Avg Cost/km': 104.3,
#    'Avg Tunnel %': 81.05,
#    'Avg Duration/km': 0.42,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Sweden',
#    '# Records in Database': 6,
#    'Length': 51.3,
#    'Tunnel': 36.9,
#    'Stations': 18,
#    'Real cost (2021 dollars)': 10728.31,
#    'Population': '10,183,175',
#    'Region': 'Europe',
#    'GDP in $': 55065,
#    'Duration': 49.0,
#    'Avg Cost/km': 209.13,
#    'Avg Tunnel %': 71.93,
#    'Avg Duration/km': 0.96,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Switzerland',
#    '# Records in Database': 3,
#    'Length': 19.9,
#    'Tunnel': 14.6,
#    'Stations': 6,
#    'Real cost (2021 dollars)': 3104.47,
#    'Population': '8,516,543',
#    'Region': 'Europe',
#    'GDP in $': 71745,
#    'Duration': 18.0,
#    'Avg Cost/km': 156.0,
#    'Avg Tunnel %': 73.37,
#    'Avg Duration/km': 0.9,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Taiwan',
#    '# Records in Database': 16,
#    'Length': 369.59,
#    'Tunnel': 174.60000000000002,
#    'Stations': 304,
#    'Real cost (2021 dollars)': 139083.04,
#    'Population': '22,894,384',
#    'Region': 'East Asia',
#    'GDP in $': 55724,
#    'Duration': 151.0,
#    'Avg Cost/km': 364.96,
#    'Avg Tunnel %': 47.24,
#    'Avg Duration/km': 0.41,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Thailand',
#    '# Records in Database': 7,
#    'Length': 175.3,
#    'Tunnel': 39.6,
#    'Stations': 137,
#    'Real cost (2021 dollars)': 45219.31,
#    'Population': '69,428,524',
#    'Region': 'South East Asia',
#    'GDP in $': 18198,
#    'Duration': 43.0,
#    'Avg Cost/km': 229.07,
#    'Avg Tunnel %': 22.59,
#    'Avg Duration/km': 0.25,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Turkey',
#    '# Records in Database': 28,
#    'Length': 489.77,
#    'Tunnel': 354.02,
#    'Stations': 335,
#    'Real cost (2021 dollars)': 59447.59,
#    'Population': '82,319,724',
#    'Region': 'Middle East',
#    'GDP in $': 27235,
#    'Duration': 250.0,
#    'Avg Cost/km': 121.38,
#    'Avg Tunnel %': 72.28,
#    'Avg Duration/km': 0.51,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Ukraine',
#    '# Records in Database': 3,
#    'Length': 27.2,
#    'Tunnel': 20.2,
#    'Stations': 17,
#    'Real cost (2021 dollars)': 8249.02,
#    'Population': '44,622,516',
#    'Region': 'Europe',
#    'GDP in $': 13087,
#    'Duration': 15.0,
#    'Avg Cost/km': 303.27,
#    'Avg Tunnel %': 74.26,
#    'Avg Duration/km': 0.55,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'United Arab Emirates',
#    '# Records in Database': 3,
#    'Length': 72.5,
#    'Tunnel': 15.8,
#    'Stations': 56,
#    'Real cost (2021 dollars)': 25903.62,
#    'Population': '9,630,959',
#    'Region': 'Middle East',
#    'GDP in $': 66766,
#    'Duration': 13.0,
#    'Avg Cost/km': 357.29,
#    'Avg Tunnel %': 21.79,
#    'Avg Duration/km': 0.18,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'United Kingdom',
#    '# Records in Database': 3,
#    'Length': 40.2,
#    'Tunnel': 37.0,
#    'Stations': 21,
#    'Real cost (2021 dollars)': 31744.6,
#    'Population': '66,488,991',
#    'Region': 'Europe',
#    'GDP in $': 46527,
#    'Duration': 24.0,
#    'Avg Cost/km': 789.67,
#    'Avg Tunnel %': 92.04,
#    'Avg Duration/km': 0.6,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'United States',
#    '# Records in Database': 21,
#    'Length': 180.8,
#    'Tunnel': 62.00000000000001,
#    'Stations': 98,
#    'Real cost (2021 dollars)': 101127.32,
#    'Population': '327,167,434',
#    'Region': 'N.America',
#    'GDP in $': 63028,
#    'Duration': 180.0,
#    'Avg Cost/km': 559.33,
#    'Avg Tunnel %': 34.29,
#    'Avg Duration/km': 1.0,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Uzbekistan',
#    '# Records in Database': 2,
#    'Length': 9.84,
#    'Tunnel': 2.9,
#    'Stations': 8,
#    'Real cost (2021 dollars)': 1440.6,
#    'Population': '32,955,400',
#    'Region': 'Central Asia',
#    'GDP in $': 7746,
#    'Duration': 6.0,
#    'Avg Cost/km': 146.4,
#    'Avg Tunnel %': 29.47,
#    'Avg Duration/km': 0.61,
#    'Avg Cost/km (all projects)': 230.16},
#   {'Country': 'Vietnam',
#    '# Records in Database': 5,
#    'Length': 63.9,
#    'Tunnel': 31.9,
#    'Stations': 56,
#    'Real cost (2021 dollars)': 25430.0,
#    'Population': '95,540,395',
#    'Region': 'South East Asia',
#    'GDP in $': 10904,
#    'Duration': 31.0,
#    'Avg Cost/km': 397.97,
#    'Avg Tunnel %': 49.92,
#    'Avg Duration/km': 0.49,
#    'Avg Cost/km (all projects)': 230.16}]}

# %%
#save the data on file
import json
import os
folder = r'C:\Users\elife\Documents\NYU\CCP\ANALYSIS\240226_update_charts'
file = "data_country_dur_group.js"

# To export Np formats
def np_encoder(object):
    if isinstance(object, np.generic):
        return object.item()

with open(os.path.join(folder,file), "w") as outfile: 
    json_text = json.dumps(data_dict, indent=1 , default=np_encoder)
    test = "var data = " + json_text
    outfile.write( test )

print('done')
# Out:
# done

# %% [markdown]
# #### Timeline database

# %%
df['Detail']=df['City'].str.cat(df['Phase'],sep=" ")

# %%
df['Detail']
# Out:
# 0                     Istanbul M4 Phase 3
# 1                             Istanbul M2
# 2                     Istanbul M3 Phase 1
# 3                     Istanbul M4 Phase 1
# 4                     Istanbul M4 Phase 2
#                       ...
# 878    Hong Kong Eastern Harbour Crossing
# 879                 Belgrade Metro Line 1
# 880                 Belgrade Metro Line 2
# 881                  Santo Domingo Line 1
# 882             Santo Domingo Line 2a, 2b
# Name: Detail, Length: 883, dtype: object

# %%
df['Detail Start']=df['Detail'].astype(str)+" starts"

# %%
df['Detail End']=df['Detail'].astype(str)+" ends"

# %%
df01=df[['Country','Start year','Detail Start']]
df02=df[['Country','End year','Detail End']]

# %%
df01= df01.rename({'Start year': 'Year','Detail Start':'Detail'}, axis='columns')
df02= df02.rename({'End year': 'Year','Detail End':'Detail'}, axis='columns')

# %%
df_time = pd.concat([ df01,df02] )

# %%
df_time.sample(10)
# Out:
#          Country    Year                                             Detail
# 411        China  2019.0                   Guangzhou Line 13 Phase 2 starts
# 217       Norway  2013.0                             Oslo Løren Line starts
# 455        China  2017.0                     Hangzhou Line 6 Phase 2 starts
# 216      Denmark  2019.0                   Copenhagen City Circle Line ends
# 284         Iran  2014.0                 Tehran Line 3 extension to SW ends
# 835        China     NaN  Xiamen Quanzhou-Xiamen-Zhangzhou Regional Rail...
# 190  South Korea  2019.0                        Seoul Sin Ansan Line starts
# 170      Vietnam  2013.0                                  Hanoi Line 3 ends
# 188  South Korea  2018.0                                 Seoul GTX A starts
# 857        Egypt  1982.0                                Cairo Line 1 starts

# %%
df_time.dropna(how='all', subset=['Year'])
df_time=df_time.groupby(['Country','Year'])['Detail'].apply(', '.join).reset_index()
df_time.sample(10)
# Out:
#             Country    Year                                             Detail
# 238          Israel  2022.0                             Tel Aviv Red Line ends
# 197       Hong Kong  1998.0                     Hong Kong Airport Railway ends
# 128         Finland  2015.0                       Helsinki Ring Rail Line ends
# 134          France  2005.0  Paris Line 13 to Courtilles starts, Lyon Line ...
# 433          Taiwan  2026.0                 Taipei Taoyuan MRT Green Line ends
# 482  United Kingdom  2009.0                            London Crossrail starts
# 8         Australia  2024.0                        Sydney Metro City & SW ends
# 91            China  2016.0  Beijing Capital Airport Express west extenion ...
# 258           Italy  2015.0  Milan Line 4 starts, Catania Nesima-Monte Po s...
# 283           Japan  2004.0                        Tokyo Minatomirai Line ends

# %%
df_time['Year'] = df_time['Year'].astype( pd.Int64Dtype() )

# %%
df_time.sample(10)
# Out:
#       Country  Year                                             Detail
# 164   Germany  2009                                    Berlin U55 ends
# 465    Turkey  2019                                  Istanbul CR3 ends
# 171   Germany  2018                      Hamburg U4 to Elbbrücken ends
# 286     Japan  2009                      Osaka Hanshin Namba Line ends
# 467    Turkey  2023  Istanbul M3 Phase 2 ends, Istanbul M12  ends, ...
# 159   Germany  1997                         Berlin U2 to Pankow starts
# 300  Malaysia  2017                      Kuala Lumpur Kajang Line ends
# 99      China  2024  Dongguan Line 3 feeder starts, Hefei Line 2 Ea...
# 518   Vietnam  2029           Ho Chi Minh City Line 5 first phase ends
# 406    Sweden  2026  Stockholm Barkarby ends, Gothenburg West Link ...

# %%
#create json dictionary. This is the format the vega library reads data in. Add data-elif to the top because that is what our map jsons have at the top.
data_dict = df_time.to_dict(
    orient= 'records'
)

data_dict = {
    "data-elif": data_dict
}

data_dict
# Out:
# {'data-elif': [{'Country': 'Argentina',
#    'Year': 2020,
#    'Detail': 'Buenos Aires RER starts'},
#   {'Country': 'Argentina', 'Year': 2026, 'Detail': 'Buenos Aires RER ends'},
#   {'Country': 'Australia', 'Year': 2013, 'Detail': 'Sydney Metro NW starts'},
#   {'Country': 'Australia',
#    'Year': 2016,
#    'Detail': 'Perth Forrestfield-Airport Link starts'},
#   {'Country': 'Australia',
#    'Year': 2017,
#    'Detail': 'Sydney Metro City & SW starts'},
#   {'Country': 'Australia',
#    'Year': 2018,
#    'Detail': 'Melbourne Metro Tunnel starts'},
#   {'Country': 'Australia', 'Year': 2019, 'Detail': 'Sydney Metro NW ends'},
#   {'Country': 'Australia',
#    'Year': 2021,
#    'Detail': 'Perth Forrestfield-Airport Link ends'},
#   {'Country': 'Australia',
#    'Year': 2024,
#    'Detail': 'Sydney Metro City & SW ends'},
#   {'Country': 'Australia',
#    'Year': 2025,
#    'Detail': 'Melbourne Metro Tunnel ends'},
#   {'Country': 'Austria', 'Year': 1999, 'Detail': 'Vienna Lainz Tunnel starts'},
#   {'Country': 'Austria',
#    'Year': 2010,
#    'Detail': 'Vienna Line 2 extension starts'},
#   {'Country': 'Austria',
#    'Year': 2012,
#    'Detail': 'Vienna Line 1 extension starts, Vienna Lainz Tunnel ends'},
#   {'Country': 'Austria',
#    'Year': 2013,
#    'Detail': 'Vienna Line 2 extension ends'},
#   {'Country': 'Austria',
#    'Year': 2017,
#    'Detail': 'Vienna Line 1 extension ends'},
#   {'Country': 'Austria', 'Year': 2019, 'Detail': 'Vienna U2/U5 cross starts'},
#   {'Country': 'Austria', 'Year': 2029, 'Detail': 'Vienna U2/U5 cross ends'},
#   {'Country': 'Bahrain',
#    'Year': 2018,
#    'Detail': 'Bahrain Phase 1 (Red & Blue) starts'},
#   {'Country': 'Bahrain', 'Year': 2020, 'Detail': 'Bahrain Phase 2 starts'},
#   {'Country': 'Bahrain',
#    'Year': 2023,
#    'Detail': 'Bahrain Phase 1 (Red & Blue) ends'},
#   {'Country': 'Bangladesh', 'Year': 2015, 'Detail': 'Dhaka Line 6 starts'},
#   {'Country': 'Bangladesh',
#    'Year': 2020,
#    'Detail': 'Dhaka Line 1 starts, Dhaka Line 5 starts'},
#   {'Country': 'Bangladesh', 'Year': 2022, 'Detail': 'Dhaka Line 6 ends'},
#   {'Country': 'Bangladesh', 'Year': 2026, 'Detail': 'Dhaka Line 1 ends'},
#   {'Country': 'Bangladesh', 'Year': 2028, 'Detail': 'Dhaka Line 5 ends'},
#   {'Country': 'Belgium', 'Year': 2020, 'Detail': 'Brussels Line 3 starts'},
#   {'Country': 'Belgium', 'Year': 2028, 'Detail': 'Brussels Line 3 ends'},
#   {'Country': 'Brazil', 'Year': 2000, 'Detail': 'Salvador Lines 1-2 starts'},
#   {'Country': 'Brazil',
#    'Year': 2010,
#    'Detail': 'Sao Paulo Line 5 extension starts, Rio de Janeiro Line 4 starts'},
#   {'Country': 'Brazil', 'Year': 2012, 'Detail': 'Sao Paulo Line 17 starts'},
#   {'Country': 'Brazil',
#    'Year': 2015,
#    'Detail': 'Sao Paulo Line 6 phase 1 starts'},
#   {'Country': 'Brazil', 'Year': 2016, 'Detail': 'Rio de Janeiro Line 4 ends'},
#   {'Country': 'Brazil', 'Year': 2017, 'Detail': 'Salvador Lines 1-2 ends'},
#   {'Country': 'Brazil',
#    'Year': 2019,
#    'Detail': 'Sao Paulo Line 5 extension ends'},
#   {'Country': 'Brazil',
#    'Year': 2020,
#    'Detail': 'Salvador SkyRail Bahia starts'},
#   {'Country': 'Brazil', 'Year': 2021, 'Detail': 'Sao Paulo Line 17 ends'},
#   {'Country': 'Brazil', 'Year': 2022, 'Detail': 'Salvador SkyRail Bahia ends'},
#   {'Country': 'Brazil',
#    'Year': 2023,
#    'Detail': 'Sao Paulo Line 6 phase 1 ends'},
#   {'Country': 'Bulgaria', 'Year': 2008, 'Detail': 'Sofia Line 2 starts'},
#   {'Country': 'Bulgaria',
#    'Year': 2009,
#    'Detail': 'Sofia Line 1 northern starts'},
#   {'Country': 'Bulgaria',
#    'Year': 2012,
#    'Detail': 'Sofia Line 2 extension starts, Sofia Line 1 northern ends, Sofia Line 2 ends'},
#   {'Country': 'Bulgaria',
#    'Year': 2013,
#    'Detail': 'Sofia Line 1 southern starts'},
#   {'Country': 'Bulgaria',
#    'Year': 2015,
#    'Detail': 'Sofia Line 1 southern ends'},
#   {'Country': 'Bulgaria',
#    'Year': 2016,
#    'Detail': 'Sofia Line 3 starts, Sofia Line 2 extension ends'},
#   {'Country': 'Bulgaria',
#    'Year': 2021,
#    'Detail': 'Sofia Line 3 extension (Third Stage) starts, Sofia Line 3 ends'},
#   {'Country': 'Canada', 'Year': 1994, 'Detail': 'Toronto Sheppard starts'},
#   {'Country': 'Canada',
#    'Year': 1998,
#    'Detail': 'Vancouver Millennium Line Phase 1 starts'},
#   {'Country': 'Canada',
#    'Year': 2001,
#    'Detail': 'Montreal Laval extension starts'},
#   {'Country': 'Canada',
#    'Year': 2002,
#    'Detail': 'Toronto Sheppard ends, Vancouver Millennium Line Phase 1 ends'},
#   {'Country': 'Canada',
#    'Year': 2005,
#    'Detail': 'Vancouver Canada Line starts'},
#   {'Country': 'Canada',
#    'Year': 2007,
#    'Detail': 'Montreal Laval extension ends'},
#   {'Country': 'Canada',
#    'Year': 2009,
#    'Detail': 'Toronto Vaughan starts, Vancouver Canada Line ends'},
#   {'Country': 'Canada',
#    'Year': 2011,
#    'Detail': 'Toronto Eglinton Crosstown starts'},
#   {'Country': 'Canada',
#    'Year': 2012,
#    'Detail': 'Vancouver Evergreen Line starts'},
#   {'Country': 'Canada', 'Year': 2013, 'Detail': 'Ottawa Confederation starts'},
#   {'Country': 'Canada',
#    'Year': 2016,
#    'Detail': 'Edmonton Valley Line Southeast starts, Vancouver Evergreen Line ends'},
#   {'Country': 'Canada', 'Year': 2017, 'Detail': 'Toronto Vaughan ends'},
#   {'Country': 'Canada', 'Year': 2019, 'Detail': 'Ottawa Confederation ends'},
#   {'Country': 'Canada',
#    'Year': 2020,
#    'Detail': 'Vancouver Broadway starts, Toronto Scarborough starts, Toronto Ontario starts, Toronto Yonge to Richmond Hill starts, Montreal Blue Line extension starts'},
#   {'Country': 'Canada',
#    'Year': 2021,
#    'Detail': 'Calgary Green Line stage 1 starts'},
#   {'Country': 'Canada',
#    'Year': 2022,
#    'Detail': 'Vancouver Expo Line Surrey-Langley extension starts, Toronto Eglinton Crosstown ends'},
#   {'Country': 'Canada',
#    'Year': 2023,
#    'Detail': 'Edmonton Valley Line Southeast ends'},
#   {'Country': 'Canada', 'Year': 2025, 'Detail': 'Vancouver Broadway ends'},
#   {'Country': 'Canada',
#    'Year': 2026,
#    'Detail': 'Montreal Blue Line extension ends'},
#   {'Country': 'Canada',
#    'Year': 2027,
#    'Detail': 'Calgary Green Line stage 1 ends'},
#   {'Country': 'Canada',
#    'Year': 2030,
#    'Detail': 'Toronto Scarborough ends, Toronto Ontario ends, Toronto Yonge to Richmond Hill ends'},
#   {'Country': 'Chile', 'Year': 2013, 'Detail': 'Santiago Project 63 starts'},
#   {'Country': 'Chile', 'Year': 2019, 'Detail': 'Santiago Project 63 ends'},
#   {'Country': 'Chile', 'Year': 2021, 'Detail': 'Santiago Line 7 starts'},
#   {'Country': 'Chile', 'Year': 2026, 'Detail': 'Santiago Line 7 ends'},
#   {'Country': 'China',
#    'Year': 1990,
#    'Detail': 'Shanghai Line 1 (Shanghai Railway Station to Jinjiang Park) starts'},
#   {'Country': 'China',
#    'Year': 1995,
#    'Detail': 'Shanghai Line 2 Phase 1 starts, Shanghai Line 1 (Shanghai Railway Station to Jinjiang Park) ends'},
#   {'Country': 'China', 'Year': 1997, 'Detail': 'Shanghai Line 3 starts'},
#   {'Country': 'China',
#    'Year': 1998,
#    'Detail': 'Shenzhen Phase 1 Expansion (Line 1 and 4) starts'},
#   {'Country': 'China',
#    'Year': 1999,
#    'Detail': 'Beijing Line 13 starts, Shanghai Line 2 Eastern Extension 1 starts, Shanghai Line 2 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2000,
#    'Detail': 'Shanghai Line 5 Phase 1 starts, Nanjing Line 1 Phase 1 starts, Wuhan Line 1 Phase 1 starts, Chongqing Line 2 starts, Guangzhou Line 3 Phase 1 starts, Shanghai Line 2 Eastern Extension 1 ends, Shanghai Line 3 ends'},
#   {'Country': 'China',
#    'Year': 2001,
#    'Detail': 'Shanghai Line 2 Western Extension 1 starts'},
#   {'Country': 'China',
#    'Year': 2002,
#    'Detail': 'Beijing Line 5 starts, Shanghai Line 6 starts, Shanghai Line 5 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2003,
#    'Detail': 'Beijing Line 10 North and East starts, Beijing Line 13 ends, Wuhan Line 1 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2004,
#    'Detail': 'Beijing Line 4 starts, Nanjing Line 4 Phase 1 starts, Shenzhen Phase 1 Expansion (Line 1 and 4) ends'},
#   {'Country': 'China',
#    'Year': 2005,
#    'Detail': 'Shanghai Line 7 Phase 1 starts, Shanghai Line 9 Phase 2 starts, Shanghai Line 10 Phase 1 starts, Wuhan Line 1 Phase 2 starts, Beijing Line 8 Phase 1 for Olympics starts, Beijing Capital Airport Express starts, Harbin Line 1 Phase 1 starts, Nanjing Line 2 Phase 1 starts, Shenyang Line 1 and 2 Phase 1 starts, Shanghai Line 4 Phase 1 ends, Nanjing Line 1 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2006,
#    'Detail': "Shanghai Line 2 Eastern Extension 2 starts, Guangzhou Line 6 Phase 1 starts, Xi'an Line 2 Phase 1 starts, Shanghai Line 2 Western Extension 1 ends, Shanghai Line 3 Northern Extension ends"},
#   {'Country': 'China',
#    'Year': 2007,
#    'Detail': 'Shanghai Line 11 Phase 1 starts, Hangzhou Line 1 Phase 1 starts, Beijing Daxing Line starts, Foshan Guangfo Line starts, Beijing Line 9 starts, Chongqing Line 1 Phase 2 starts, Chongqing Line 1 Phase 1 starts, Chongqing Line 3 starts, Guangzhou Line 2 and 8 Extension starts, Beijing Line 5 ends'},
#   {'Country': 'China',
#    'Year': 2008,
#    'Detail': 'Beijing Line 6 Phase 1 starts, Changsha First starts, Hangzhou Line 2 Phase 1 Xiaoshan section starts, Shanghai Line 9 Phase 1 ends, Beijing Line 10 North and East ends, Beijing Line 8 Phase 1 for Olympics ends, Beijing Capital Airport Express ends'},
#   {'Country': 'China',
#    'Year': 2009,
#    'Detail': 'Shanghai Line 7 Northern Extension starts, Shanghai Line 9 Phase 3 starts, Beijing Line 7 Phase 1 starts, Beijing Line 15 Phase 1 starts, Wuhan Line 4 Phase 1 starts, Fuzhou Line 1 Phase 1 starts, Nanchang Phase 1 Expansion (Line 1 and 2) starts, Zhengzhou Line 1 Phase 1 starts, Guangzhou Line 6 Phase 3 starts, Guangzhou Line 9 starts, Suzhou Line 2 starts, Beijing Line 4 ends, Shanghai Line 7 Phase 1 ends, Shanghai Line 8 Phase 2 ends, Shanghai Line 9 Phase 2 ends, Shanghai Line 11 Phase 1 ends, Shanghai Line 8 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2010,
#    'Detail': 'Kunming Line 1 Phase 1 and Line 2 Phase 1 starts, Shanghai Line 16 starts, Wuxi Line 2 Phase 1 starts, Dalian Line 4 starts, Dalian Line 1 Phase 3 starts, Qingdao Line 3 starts, Zhengzhou Line 2 Phase 1 starts, Changchun New Beihu Line starts, Changchun Line 1 South Extension starts, Shanghai Line 2 Eastern Extension 2 ends, Shanghai Line 2 Western Extension 2 ends, Shanghai Line 10 Phase 1 ends, Wuhan Line 1 Phase 2 ends, Beijing Daxing Line ends'},
#   {'Country': 'China',
#    'Year': 2011,
#    'Detail': "Wuhan Line 1 Phase 3 Hankou North starts, Beijing Line 8 Northern Extension starts, Beijing Line 6 Phase 2 starts, Changsha Line 2 Phase 2 starts, Nanning Line 1 Phase 1 starts, Shenzhen Line 3 Phase 3 North Ext starts, Xiamen Line 3 Phase 1 starts, Xiamen Line 1 Phase 1 starts, Shanghai Line 7 Northern Extension ends, Shanghai Line 6 ends, Foshan Guangfo Line ends, Xi'an Line 2 Phase 1 ends"},
#   {'Country': 'China',
#    'Year': 2012,
#    'Detail': "Hefei Line 1 Phase 1+2 starts, Changsha Line 3 Phase 1 starts, Taiyuan Line 2 Phase 1 starts, Changsha Line 2 West Extension Phase 1 starts, Chongqing Ring Line starts, Shijiazhuang Line 1 Phase 2 starts, Shijiazhuang Line 3 Phase 2 starts, Shijiazhuang First starts, Guangzhou Line 14 Phase 1 starts, Guangzhou Line 14 Branch starts, Guangzhou Line 4 South Extension starts, Guangzhou Line 21 starts, Guangzhou Line 7 starts, Nanjing Line S8 Phase 2 starts, Shenyang Line 9 Phase 1 starts, Shenyang Line 10 Phase 1 starts, Wuhan Line 3 Phase 1 starts, Xi'an Line 3 starts, Shanghai Line 9 Phase 3 ends, Hangzhou Line 1 Phase 1 ends, Beijing Line 6 Phase 1 ends, Beijing Line 9 ends"},
#   {'Country': 'China',
#    'Year': 2013,
#    'Detail': "Shanghai Line 9 Phase 3 Eastern Extension starts, Beijing Line 16 starts, Changsha Line 4 Phase 1 starts, Kunming Line 1 Feeder starts, Kunming Line 3 Phase 2 starts, Chongqing Line 4 Phase 1 starts, Chongqing Line 6 Branch (EXPO) starts, Chongqing Line 5 Phase 1 starts, Kunming Line 1 Southern Extension starts, Guangzhou Line 13 Phase 1 starts, Guiyang Line 1 Phase 1 starts, Ningbo 2013-2020 Program starts, Xuzhou First Phase Program (Lines 1, 2 and 3) starts, Chengdu Line 10 Phase 1 starts, Chengdu Line 4 Phase 2 starts, Chengdu Line 3 Phase 2 starts, Chengdu Line 7 starts, Chengdu Line 1 Phase 3 starts, Hangzhou Line 4 Phase 1 starts, Xi'an Line 4 starts, Shanghai Line 11 Phase 2 ends, Shanghai Line 11 Huaqiao ends, Wuhan Line 1 Phase 3 Hankou North ends, Beijing Line 8 Northern Extension ends, Zhengzhou Line 1 Phase 1 ends, Xi'an Line 1 Phase 1 ends"},
#   {'Country': 'China',
#    'Year': 2014,
#    'Detail': "Shanghai Line 5 Southern Extension starts, Chongqing Line 10 starts, Hefei Line 3 Phase 1 starts, Changsha Line 5 Phase 1 starts, Shanghai Line 14 starts, Wuxi Line 1 Phase 1 starts, Foshan Line 2 Phase 1 starts, Urumqi Line 1 starts, Xuzhou Line 1 starts, Hangzhou Line 2 Phase 2 starts, Hangzhou Line 5 Phase 1 starts, Nanning Line 2 Phase 1 starts, Xi'an Line 5 Phase 1 starts, Zhengzhou Line 4 starts, Kunming Line 1 Phase 1 and Line 2 Phase 1 ends, Beijing Line 7 Phase 1 ends, Beijing Line 15 Phase 1 ends, Shanghai Line 16 ends, Wuxi Line 2 Phase 1 ends, Beijing Line 6 Phase 2 ends, Nanjing Line S8 Phase 2 ends, Suzhou Line 2 ends"},
#   {'Country': 'China',
#    'Year': 2015,
#    'Detail': 'Shenzhen Line 6 Phase 1 starts, Beijing Line 17 starts, Nanning Line 3 Phase1 starts, Fuzhou Line 6 starts, Hefei Line 4 Phase 1 starts, Tianjin Z4 Phase 1 starts, Nanjing Line 3 Phase 3 starts, Nanchang Line 2 Western Extension starts, Wuhan Line 1 Phase 4 (Jinghe) starts, Fuzhou Line 1 South Extension starts, Changchun Line 2 Western Extension starts, Chengdu Line 5 Phase 1 and 2 (redesign) starts, Chengdu Line 3 Phase 3 (redesign) starts, Shenzhen Line 10 starts, Xiamen Line 2 Phase 1 starts, Kunming Line 1 Feeder ends, Changsha Line 2 West Extension Phase 1 ends, Kunming Line 1 Southern Extension ends, Changsha First ends, Changsha Line 2 Phase 2 ends, Nanjing Line 4 Phase 1 ends, Wuhan Line 3 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2016,
#    'Detail': "Beijing Capital Airport Express west extenion starts, Beijing Line 3 Phase 1+2 starts, Beijing Line 8 Phase 4 starts, Beijing Line 7 Phase 2 (Eastern Extension) starts, Wuhan Line 8 Phase 2 starts, Xiamen Line 2 Phase 2 starts, Nanjing Line 9 Line 5 starts, Nanchang Line 4 Phase 1 starts, Wuhan Line 7 South starts, Xiamen Line 3 Phase 2 starts, Wuhan Line 4 Western Extension starts, Beijing Daxing Airport Express Phase 1 starts, Guiyang S1 Phase 1 starts, Chongqing Line 6 Branch (EXPO) Phase 2 starts, Chongqing Line 9 Phase 2 starts, Wuhan Line 2 Northern Extension starts, Shanghai Line 8 Phase 3 (Pujiang Line) starts, Shanghai Line 15 starts, Chengdu Line 9 Phase 1 starts, Chengdu Line 10 Phase 2 starts, Harbin Line 2 Phase 2 North and South Ext starts, Harbin Line 1 Phase 4 starts, Harbin Line 4 Phase 1 starts, Harbin Line 5 Phase 1 starts, Shaoxing Hangshao Line starts, Foshan Line 3 Phase 1 starts, Shaoxing Line 1 starts, Chengdu Line 18 Phase 1 and 2 starts, Hangzhou Hanglin Line (Hangzhou Section) starts, Hangzhou Hanglin Line (Lin'an Section) starts, Shanghai Line 18 starts, Xi'an Line 5 Phase 2 starts, Xi'an Line 9 starts, Xi'an Line 6 Phase 1 and 2 starts, Xi'an Line 1 Phase 2 starts, Hefei Line 1 Phase 1+2 ends, Changsha Line 3 Phase 1 ends, Taiyuan Line 2 Phase 1 ends, Chongqing Ring Line ends, Shanghai Line 11 (to Disney) ends, Shenzhen Line 7 ends, Nanchang Phase 1 Expansion (Line 1 and 2) ends, Zhengzhou Line 2 Phase 1 ends, Nanning Line 1 Phase 1 ends, Xi'an Line 3 ends"},
#   {'Country': 'China',
#    'Year': 2017,
#    'Detail': 'Beijing Line 28 starts, Beijing Line 12 starts, Guangzhou Line 10 starts, Shenzhen Line 12 starts, Tianjin M8 Phase 1 starts, Beijing Line 19 Phase 1 starts, Beijing Line 25 Phase 2 (Fangshan Northern Extension) starts, Hangzhou Line 9 Phase 1 starts, Changsha Line 6 Central starts, Changsha Line 7 Phase 1 starts, Xiamen Line 6 starts, Guangzhou Line 14 Phase 2 starts, Guangzhou Line 22 starts, Hangzhou Line 6 Phase 2 starts, Wuhan Line 5 starts, Wuhan Line 11 East starts, Nanjing Line 2 Western Extension starts, Nanning Line 2 Eastern Extension starts, Fuzhou Line 4 Phase 1 starts, Hangzhou Line 4 Phase 2 starts, Guangzhou Line 8 Northern Extension starts, Guangzhou Line 18 starts, Hangzhou Line 3 Phase 1 starts, Nanjing Line S8 Southern Extension starts, Guiyang Line 2 Phase 2 starts, Hangzhou Line 7 starts, Changsha Line 2 West Extension starts, Hangzhou Line 2 Phase 3 starts, Tianjin Z2 Phase 1 starts, Hangzhou Line 5 Phase 2 starts, Changsha Line 1 North Extension Phase 1 starts, Xiamen Line 4 starts, Kunming Line 2 Phase 2 starts, Zhengzhou Line 3 Phase 1 starts, Hangzhou Line 2 Phase 1 (redesign) starts, Kunming Line 3 Phase 1 starts, Shanghai Line 9 Phase 3 Eastern Extension ends, Changsha Line 4 Phase 1 ends, Nanjing Line 3 Phase 3 ends, Wuhan Line 1 Phase 4 (Jinghe) ends, Chongqing Line 5 Phase 1 ends, Guangzhou Line 13 Phase 1 ends, Guiyang Line 1 Phase 1 ends, Fuzhou Line 1 Phase 1 ends, Nanning Line 2 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2018,
#    'Detail': "Shenzhen Line 6 (feeder) starts, Tianjin M10 Phase 1 starts, Shenzhen Line 16 starts, Guangzhou Line 12 starts, Guangzhou Line 5 Eastern Extension starts, Changsha Line 5 South Extension starts, Changsha Line 6 West starts, Hangzhou Line 8 Phase 1 starts, Guangzhou Line 7 Phase 2 starts, Guiyang Line 3 Phase 1 starts, Nanjing Line 11 Phase 1 starts, Nanchang Line 1 Eastern Extension starts, Changsha Line 6 East starts, Changsha Line 4 North Extension starts, Huizhou Line 1 starts, Urumqi Line 4 Phase 1 starts, Taiyuan Line 3 starts, Chongqing Jiangjin Line South Extension starts, Hefei Hefei-Lu'an Regional Express Line starts, Nanjing Line S4 Nanjing-Chuzhou Phase 1 (Chuzhou Section) starts, Shanghai Line 5 Southern Extension ends, Beijing Line 8 Phase 4 ends, Wuhan Line 4 Western Extension ends, Kunming Line 3 Phase 2 ends, Chongqing Line 4 Phase 1 ends, Nanchang Line 2 Western Extension ends, Shanghai Line 8 Phase 3 (Pujiang Line) ends, Qingdao Line 11 ends, Guangzhou Line 14 Phase 1 ends, Guangzhou Line 14 Branch ends, Guangzhou Line 4 South Extension ends, Guangzhou Line 21 ends, Xi'an Line 4 ends"},
#   {'Country': 'China',
#    'Year': 2019,
#    'Detail': "Beijing Line 11 West starts, Guangzhou Line 13 Phase 2 starts, Chengdu Line 18 Phase 3 starts, Tianjin M7 Phase 1 starts, Chengdu Line 8 Phase 2 starts, Tianjin M11 Phase 1 starts, Beijing Line 27 Phase 2 (Changping Southern Extension) starts, Chengdu Line 13 Phase 1 starts, Beijing Line 22 starts, Chongqing Line 5 Northern Extension starts, Beijing Line 13A starts, Nanjing Line 7 starts, Chengdu Line 30 Phase 1 starts, Chengdu Line 17 Phase 2 starts, Nanjing Line 6 starts, Chongqing Line 5A starts, Shanghai Airport Contact Line starts, Zhengzhou Line 12 Phase 1 starts, Chengdu Line 10 Phase 3 starts, Beijing Daxing Airport Express Phase 2 starts, Xi'an Line 1 Phase 3 starts, Chengdu Line 27 Phase 1 starts, Zhengzhou Line 10 Phase 1 starts, Zhengzhou Line 8 Phase 1 starts, Chengdu Line 19 Phase 2 starts, Shenyang Line 3 Phase 1 starts, Guangzhou Line 3 Eastern Extension starts, Xi'an Line 16 Phase 1 starts, Changchun Line 2 Eastern Extension starts, Changchun Line 9 (Konggang) starts, Beijing Line 13B starts, Changsha Line 5 North Extension starts, Shenzhen Line 8 Phase 2 starts, Changzhou Line 1 Phase 1 starts, Wuxi Line S1 starts, Qingdao Line 2 starts, Nantong Line 1 starts, Taiyuan Jinzhong-Taiyuan Intercity starts, Guangzhou Line 11 starts, Hangzhou K1 Airport Line starts, Hefei Line 1 South starts, Lanzhou Line 4 Phase 1 starts, Shenzhen Line 5 West Extension starts, Wuhan Line 11 Phase 3 Hanchang Section starts, Wuhan Line 11 Phase 3 Hanyang Section starts, Xi'an Airport Line starts, Nanning Line 3 Phase1 ends, Hefei Line 3 Phase 1 ends, Fuzhou Line 6 ends, Beijing Daxing Airport Express Phase 1 ends, Kunming Line 2 Phase 2 ends, Lanzhou Line 1 Phase 1 ends, Wuxi Line 1 South ends, Ningbo Ningbo-Fenghua Line ends, Ningbo Line 3 Phase 1 ends, Urumqi Line 1 ends, Xuzhou Line 1 ends, Changchun New Beihu Line ends, Changchun Line 2 Western Extension ends, Changchun Line 1 South Extension ends, Chengdu Line 18 Phase 1 and 2 ends, Xiamen Line 2 Phase 1 ends"},
#   {'Country': 'China',
#    'Year': 2020,
#    'Detail': "Shenzhen Line 12 Phase 2 starts, Shenzhen Line 13 Southern Extension starts, Hefei Line 2 Eastern Extension starts, Hefei Line 3 Southern Extension starts, Wuhan Line 12 (Ring) starts, Shenzhen Line 14 starts, Nanjing Line 10 Phase 2 starts, Fuzhou Line 5 Phase 1 starts, Shenyang Line 6 Phase 1 starts, Hefei Line 5 Phase 1 starts, Kunming Line 1 Northwestern Extension starts, Changchun Line 7 Phase 1 starts, Shenyang Line 1 Eastern Extension starts, Suzhou Line 6 starts, Xi'an Line 15 Phase 1 starts, Kunming Line 5 starts, Xi'an Line 10 Phase 1 starts, Kunming Line 4 starts, Wuhan Line 16 starts, Kunming Line 6 starts, Guilin Line 1 starts, Jiaxing Hujia Regional Railway (Zhejiang section) starts, Putian F2 Line starts, Shijiazhuang Line 6 Phase 1 starts, Shijiazhuang Line 4 starts, Wuxi Line 3 Phase 1 starts, Yiwu Phase 1 Program starts, Zibo Line 1 starts, Fuzhou Line 2 East Extension starts, Hohhot Line 2 starts, Ningbo Line 3 Southern Extension starts, Nantong Line 2 starts, Xuzhou Line 2 starts, Zhengzhou Zhengxu Regional Rail (Zhengzhou Section) starts, Beijing Yanfang Branch starts, Chongqing Bishan-Tongliang Line starts, Chongqing Jiangjin Line starts, Chongqing Line 18 Phase 2 starts, Fuzhou Line 6 East Extension starts, Guangzhou Nansha-Zhuhai (Zhongshan) intercity or Line 18 starts, Guangzhou Line 22 Northern Extension starts, Guangzhou Line 28 starts, Hangzhou Line 3 North Extension starts, Hangzhou Line 5 Phase 2 West starts, Shenzhen Line 3 Phase 3 North Ext (Phase 4) starts, Suzhou Line 5 starts, Tianjin Line 13 Phase 1 starts, Xiamen Quanzhou-Xiamen-Zhangzhou Regional Rail R1 (Zhangzhou Section) starts, Beijing Capital Airport Express west extenion ends, Shenzhen Line 6 Phase 1 ends, Tianjin M8 Phase 1 ends, Beijing Line 25 Phase 2 (Fangshan Northern Extension) ends, Beijing Line 7 Phase 2 (Eastern Extension) ends, Xiamen Line 2 Phase 2 ends, Nanjing Line 9 Line 5 ends, Nanjing Line 2 Western Extension ends, Nanning Line 4 Phase 1 ends, Chongqing Line 10 ends, Nanjing Line S8 Southern Extension ends, Wuhan Line 7 South ends, Xiamen Line 3 Phase 2 ends, Hefei Line 4 Phase 1 ends, Tianjin Z4 Phase 1 ends, Hangzhou Line 2 Phase 3 ends, Tianjin Z2 Phase 1 ends, Hangzhou Line 5 Phase 2 ends, Guiyang S1 Phase 1 ends, Chongqing Line 6 Branch (EXPO) Phase 2 ends, Chongqing Line 9 Phase 2 ends, Chengdu Line 9 Phase 1 ends, Chengdu Line 10 Phase 2 ends, Fuzhou Line 1 South Extension ends, Ningbo 2013-2020 Program ends, Qingdao Qingdao-Pingdu Intercity Rail ends, Shijiazhuang First ends, Xuzhou First Phase Program (Lines 1, 2 and 3) ends, Zhengzhou Line 3 Phase 1 ends, Changchun Line 2 ends, Chengdu Line 10 Phase 1 ends, Chengdu Line 4 Phase 2 ends, Chengdu Line 5 Phase 1 and 2 (redesign) ends, Chengdu Line 3 Phase 2 ends, Chengdu Line 7 ends, Chengdu Line 1 Phase 3 ends, Hangzhou Hanglin Line (Hangzhou Section) ends, Hangzhou Hanglin Line (Lin'an Section) ends, Hangzhou Line 5 Phase 1 ends, Shenyang Line 9 Phase 1 ends, Shenyang Line 10 Phase 1 ends, Shenzhen Line 10 ends, Shenzhen Line 3 Phase 3 North Ext ends, Xi'an Line 9 ends, Xi'an Line 5 Phase 1 ends, Xiamen Line 3 Phase 1 ends, Xiamen Line 1 Phase 1 ends, Zhengzhou Line 4 ends"},
#   {'Country': 'China',
#    'Year': 2021,
#    'Detail': "Xuzhou Line 4 Phase 1 starts, Xuzhou Line 6 Phase 1 starts, Shenzhen Line 13 Northern Extension starts, Hefei Line 6 Phase 1 starts, Shenzhen Line 13 starts, Nanchang Line 2 Eastern Extension starts, Shanghai Jiamin Line starts, Nanjing Line 5 starts, Tianjin B1 Phase 1 starts, Nanjing Line 1 Northern Extension starts, Nanjing Line 4 Phase 2 starts, Changchun Line 5 Phase 1 starts, Suzhou Line 7 starts, Taiyuan Line 1 Phase 1 starts, Guiyang S2 Phase 1 North starts, Zhengzhou Line 3 Phase 2 starts, Chongqing Line 9 Phase 1 starts, Lanzhou Line 2 Phase 1 starts, Dongguan Line 1 Phase 1 starts, Dongguan Line 1 Phase 3 starts, Chengdu Line 8 Phase 1 starts, Changzhou Line 2 Phase 1 starts, Foshan Line 11 starts, Harbin Line 2 Phase 1 starts, Harbin Line 3 Phase 2 starts, Wuxi Line 4 Phase 1 starts, Foshan Line 2 Phase 2 starts, Foshan Line 4 Phase 1 starts, Fuzhou F1 Express Line starts, Jinan Line 2 starts, Jinan Line 4 Phase 1 starts, Ningbo Line 5 Phase 1 starts, Ningbo Line 3 Phase 2 starts, Qingdao Line 8 Branch starts, Qingdao Line 6 Phase 2 South starts, Qingdao Line 15 starts, Qingdao Line 9 starts, Qingdao Line 2 Phase 2 East Section starts, Qingdao Line 5 starts, Nanchang Line 1 North Extension starts, Nanning Wuming Line starts, Nanning Airport Line starts, Taizhou Line S2 South Segment starts, Taizhou Line S2 West Segment starts, Taizhou Line S2 starts, Xuzhou Line 3 starts, Changsha Line 2 West Extension Phase 2 starts, Chengdu Line S3 starts, Chengdu Line 17 Phase 1 starts, Chongqing Line 27 starts, Chongqing Line 15 Phase 2 starts, Chongqing Line 15 Phase 1 starts, Chongqing Line 24 Phase 1 starts, Chongqing Line 4 West extension starts, Guangzhou Line 8 Eastern Extension starts, Guangzhou Line 18 North starts, Hefei Line 6 East Extension starts, Hefei Line 2 Western Extension starts, Nanjing Line S2 Nanjing-Ma'anshan Regional Rail (Anhui section) starts, Nanjing Line S4 Nanjing-Chuzhou Phase 2 (Nanjing Section) starts, Nanjing Line S3 Nanjing-He County starts, Nanjing Line S5 Nanjing-Yangzhou starts, Nanjing Line S2 Nanjing-Ma'anshan Regional Rail (Nanjing section) starts, Nanjing Line S6 starts, Shenzhen Shenhui Dapeng Branch ICR starts, Shenzhen Guangzhou-Dongguan-Shenzhen Regional Rail South Extension starts, Shenzhen Shenhui Mainline ICR starts, Xiamen Quanzhou-Xiamen-Zhangzhou Regional Rail R1 (Xiamen Section) starts, Xiamen Line 9 starts, Xiamen Quanzhou-Xiamen-Zhangzhou Regional Rail R1 (Quanzhou Section) starts, Beijing Line 28 ends, Beijing Line 11 West ends, Beijing Line 3 Phase 1+2 ends, Beijing Line 12 ends, Beijing Line 19 Phase 1 ends, Beijing Line 16 ends, Beijing Line 27 Phase 2 (Changping Southern Extension) ends, Changsha Line 6 Central ends, Hangzhou Line 10 Phase 1 ends, Wuhan Line 8 Phase 2 ends, Changsha Line 7 Phase 1 ends, Nanchang Line 3 ends, Guangzhou Line 14 Phase 2 ends, Nanning Line 5 Phase 1 ends, Guangzhou Line 22 ends, Wuhan Line 5 ends, Wuhan Line 11 East ends, Nanning Line 2 Eastern Extension ends, Fuzhou Line 4 Phase 1 ends, Nanchang Line 4 Phase 1 ends, Hangzhou Line 3 Phase 1 ends, Changsha Line 5 Phase 1 ends, Nanjing Line 11 Phase 1 ends, Hangzhou Line 7 ends, Changsha Line 2 West Extension ends, Changsha Line 1 North Extension Phase 1 ends, Nanchang Line 1 Eastern Extension ends, Shanghai Line 15 ends, Shanghai Line 14 ends, Shaoxing Hangshao Line ends, Foshan Line 2 Phase 1 ends, Dalian Line 1 Phase 3 ends, Ningbo Line 4 ends, Qingdao Line 8 ends, Qingdao Line 1 + Line 7 Phase 1 ends, Urumqi Line 2 ends, Shaoxing Line 1 ends, Shijiazhuang Line 1 Phase 2 ends, Shijiazhuang Line 3 Phase 2 ends, Guiyang Line 2 Phase 1 ends, Hangzhou Hangzhou-Haining Line ends, Hangzhou Hangfu Line ends, Hangzhou Line 6 Phase 1 ends, Shanghai Line 18 ends, Wuhu Line 1 ends, Wuhu Line 2 ends, Xi'an Line 5 Phase 2 ends"},
#   {'Country': 'China',
#    'Year': 2022,
#    'Detail': "Shenzhen Line 20 Phase 1 starts, Hefei Line 4 Southern Extension starts, Wenzhou M1 starts, Dongguan Line 1 Feeder Phase 1 starts, Dongguan Line 2 Phase 3 starts, Wenzhou S3 Phase 1 starts, Wuxi Wuxi-Yixing Intercity starts, Luoyang Line 2 starts, Shaoxing Line 2 starts, Taizhou Line S1 starts, Beijing Line M101 starts, Chengdu Line S5 starts, Chongqing Line 17 (redesign) Phase 1 starts, Chongqing Line 6 East starts, Hangzhou Line 10 Phase 2 starts, Nanjing Line S8 Phase 2 starts, Nanjing Line S4 Nanjing-Chuzhou Phase 2 (Chuzhou Section) starts, Shanghai Line 12 West Extension starts, Wuxi Line 5 Phase 1 starts, Xiamen Line 4 (Houxi to Xiang'an Airport) starts, Shenzhen Line 6 (feeder) ends, Shenzhen Line 3 Phase 4 ends, Shenzhen Line 12 Phase 2 ends, Guangzhou Line 10 ends, Shenzhen Line 12 ends, Beijing Line 17 ends, Tianjin M10 Phase 1 ends, Hangzhou Line 9 Phase 1 ends, Xiamen Line 6 ends, Beijing Line 22 ends, Guangzhou Line 5 Eastern Extension ends, Hangzhou Line 6 Phase 2 ends, Changsha Line 5 South Extension ends, Beijing Line 13A ends, Hangzhou Line 4 Phase 2 ends, Changsha Line 6 West ends, Hangzhou Line 8 Phase 1 ends, Guangzhou Line 7 Phase 2 ends, Guiyang Line 2 Phase 2 ends, Guangzhou Line 3 Eastern Extension ends, Xiamen Line 4 ends, Changsha Line 6 East ends, Changsha Line 4 North Extension ends, Beijing Line 13B ends, Changsha Line 5 North Extension ends, Foshan Line 3 Phase 1 ends, Dalian Line 4 ends, Jinan Line 3 Phase 1 ends, Shenyang Line 4 Phase 1 ends, Zhengzhou Zhengxu Regional Rail (Xucheng Section) ends, Hangzhou K1 Airport Line ends, Hangzhou Line 3 North Extension ends, Nanjing Line S4 Nanjing-Chuzhou Phase 1 (Chuzhou Section) ends, Shenzhen Line 3 Phase 3 North Ext (Phase 4) ends, Xi'an Line 6 Phase 1 and 2 ends"},
#   {'Country': 'China',
#    'Year': 2023,
#    'Detail': "Dongguan Line 1 Phase 2 starts, Dongguan Line 3 Phase 1 starts, Shenzhen Line 16 ends, Guangzhou Line 12 ends, Nanjing Line 10 Phase 2 ends, Guangzhou Line 8 Northern Extension ends, Guangzhou Line 18 ends, Guiyang Line 3 Phase 1 ends, Nanjing Line 6 ends, Xi'an Line 1 Phase 3 ends, Wuxi Line S1 ends"},
#   {'Country': 'China',
#    'Year': 2024,
#    'Detail': "Dongguan Line 3 feeder starts, Hefei Line 2 Eastern Extension ends, Hefei Line 3 Southern Extension ends, Chengdu Line 18 Phase 3 ends, Wuhan Line 12 (Ring) ends, Chengdu Line 8 Phase 2 ends, Chengdu Line 13 Phase 1 ends, Chongqing Line 5 Northern Extension ends, Chengdu Line 30 Phase 1 ends, Chengdu Line 17 Phase 2 ends, Chongqing Line 5A ends, Zhengzhou Line 12 Phase 1 ends, Chengdu Line 27 Phase 1 ends, Zhengzhou Line 10 Phase 1 ends, Zhengzhou Line 8 Phase 1 ends, Chengdu Line 19 Phase 2 ends, Xi'an Line 16 Phase 1 ends, Shenzhen Line 8 Phase 2 ends, Wuhan Line 11 Phase 3 Hanchang Section ends"},
#   {'Country': 'China',
#    'Year': 2025,
#    'Detail': "Shenzhen Line 13 Southern Extension ends, Shenzhen Line 8 Phase 3 ends, Nanjing Line 4 Phase 2 ends, Shanghai Airport Contact Line ends, Changchun Line 7 Phase 1 ends, Shenyang Line 1 Eastern Extension ends, Chengdu Line 10 Phase 3 ends, Xi'an Line 15 Phase 1 ends, Shenyang Line 3 Phase 1 ends, Changchun Line 2 Eastern Extension ends, Changchun Line 9 (Konggang) ends, Changsha Line 2 West Extension Phase 2 ends, Chongqing Line 18 Phase 2 ends, Wuhan Line 11 Phase 3 Hanyang Section ends"},
#   {'Country': 'China',
#    'Year': 2026,
#    'Detail': "Shenyang Line 6 Phase 1 ends, Xi'an Line 10 Phase 1 ends, Dongguan Line 1 Phase 1 ends, Dongguan Line 1 Phase 3 ends, Foshan Line 11 ends, Foshan Line 2 Phase 2 ends, Foshan Line 4 Phase 1 ends, Qingdao Line 8 Branch ends, Qingdao Line 6 Phase 2 South ends, Qingdao Line 15 ends, Qingdao Line 9 ends, Qingdao Line 5 ends, Chongqing Line 17 (redesign) Phase 1 ends, Chongqing Line 4 West extension ends"},
#   {'Country': 'China',
#    'Year': 2027,
#    'Detail': 'Shanghai Jiamin Line ends, Dongguan Line 1 Feeder Phase 1 ends, Dongguan Line 2 Phase 3 ends, Beijing Line M101 ends, Chongqing Line 27 ends, Chongqing Line 15 Phase 1 ends'},
#   {'Country': 'China',
#    'Year': 2028,
#    'Detail': 'Dongguan Line 1 Phase 2 ends, Dongguan Line 3 Phase 1 ends, Dongguan Line 3 feeder ends'},
#   {'Country': 'Czech Republic',
#    'Year': 2004,
#    'Detail': 'Prague Line C to Letnany starts'},
#   {'Country': 'Czech Republic',
#    'Year': 2008,
#    'Detail': 'Prague Line C to Letnany ends'},
#   {'Country': 'Czech Republic',
#    'Year': 2010,
#    'Detail': 'Prague Line A extension starts'},
#   {'Country': 'Czech Republic',
#    'Year': 2015,
#    'Detail': 'Prague Line A extension ends'},
#   {'Country': 'Czech Republic',
#    'Year': 2021,
#    'Detail': 'Prague Line D starts'},
#   {'Country': 'Czech Republic', 'Year': 2029, 'Detail': 'Prague Line D ends'},
#   {'Country': 'Denmark',
#    'Year': 2009,
#    'Detail': 'Copenhagen City Circle Line starts'},
#   {'Country': 'Denmark',
#    'Year': 2019,
#    'Detail': 'Copenhagen City Circle Line ends'},
#   {'Country': 'Dominican Republic',
#    'Year': 2005,
#    'Detail': 'Santo Domingo Line 1 starts'},
#   {'Country': 'Dominican Republic',
#    'Year': 2008,
#    'Detail': 'Santo Domingo Line 1 ends'},
#   {'Country': 'Dominican Republic',
#    'Year': 2009,
#    'Detail': 'Santo Domingo Line 2a, 2b starts'},
#   {'Country': 'Dominican Republic',
#    'Year': 2018,
#    'Detail': 'Santo Domingo Line 2a, 2b ends'},
#   {'Country': 'Ecuador', 'Year': 2012, 'Detail': 'Quito Metro starts'},
#   {'Country': 'Ecuador', 'Year': 2019, 'Detail': 'Quito Metro ends'},
#   {'Country': 'Egypt', 'Year': 1982, 'Detail': 'Cairo Line 1 starts'},
#   {'Country': 'Egypt', 'Year': 1987, 'Detail': 'Cairo Line 1 ends'},
#   {'Country': 'Egypt', 'Year': 1993, 'Detail': 'Cairo Line 2 starts'},
#   {'Country': 'Egypt', 'Year': 2005, 'Detail': 'Cairo Line 2 ends'},
#   {'Country': 'Egypt', 'Year': 2006, 'Detail': 'Cairo Line 3 Phase 1 starts'},
#   {'Country': 'Egypt', 'Year': 2012, 'Detail': 'Cairo Line 3 Phase 1 ends'},
#   {'Country': 'Egypt', 'Year': 2017, 'Detail': 'Cairo Line 6 starts'},
#   {'Country': 'Egypt',
#    'Year': 2019,
#    'Detail': 'Cairo Line 4 (4 Phases) starts'},
#   {'Country': 'Finland',
#    'Year': 2009,
#    'Detail': 'Helsinki West Metro phase 1 starts, Helsinki Ring Rail Line starts'},
#   {'Country': 'Finland',
#    'Year': 2014,
#    'Detail': 'Helsinki West Metro phase 2 starts'},
#   {'Country': 'Finland',
#    'Year': 2015,
#    'Detail': 'Helsinki Ring Rail Line ends'},
#   {'Country': 'Finland',
#    'Year': 2017,
#    'Detail': 'Helsinki West Metro phase 1 ends'},
#   {'Country': 'Finland',
#    'Year': 2023,
#    'Detail': 'Helsinki West Metro phase 2 ends'},
#   {'Country': 'France',
#    'Year': 1991,
#    'Detail': 'Paris RER D Gare de Lyon-Les Halles starts'},
#   {'Country': 'France', 'Year': 1993, 'Detail': 'Paris Line 14 starts'},
#   {'Country': 'France',
#    'Year': 1995,
#    'Detail': 'Paris RER D Gare de Lyon-Les Halles ends'},
#   {'Country': 'France',
#    'Year': 2005,
#    'Detail': 'Paris Line 13 to Courtilles starts, Lyon Line A to Vaulx starts'},
#   {'Country': 'France',
#    'Year': 2007,
#    'Detail': 'Paris Line 8 to Pointe-du-Lac starts, Paris Line 12 to Front Populaire starts, Paris Line 14 ends, Lyon Line A to Vaulx ends'},
#   {'Country': 'France',
#    'Year': 2008,
#    'Detail': 'Paris Line 4 to Montrouge starts, Paris Line 13 to Courtilles ends'},
#   {'Country': 'France',
#    'Year': 2009,
#    'Detail': 'Lyon Line B to Oullins starts'},
#   {'Country': 'France',
#    'Year': 2011,
#    'Detail': 'Paris Line 8 to Pointe-du-Lac ends'},
#   {'Country': 'France',
#    'Year': 2012,
#    'Detail': 'Paris Line 12 to Aubervilliers starts, Paris Line 12 to Front Populaire ends'},
#   {'Country': 'France',
#    'Year': 2013,
#    'Detail': 'Paris Line 4 to Montrouge ends, Lyon Line B to Oullins ends'},
#   {'Country': 'France',
#    'Year': 2014,
#    'Detail': 'Paris Line 4 to Bagneux starts, Rennes Line B starts'},
#   {'Country': 'France', 'Year': 2016, 'Detail': 'Paris Line 11 starts'},
#   {'Country': 'France',
#    'Year': 2017,
#    'Detail': 'Paris Grand Paris Express starts, Lyon Line B to Hospital-Sud starts'},
#   {'Country': 'France',
#    'Year': 2018,
#    'Detail': 'Paris RER E extension starts'},
#   {'Country': 'France',
#    'Year': 2021,
#    'Detail': 'Toulouse Line 3 starts, Paris Line 1 extension starts, Paris Line 12 to Aubervilliers ends, Paris Line 4 to Bagneux ends, Rennes Line B ends'},
#   {'Country': 'France', 'Year': 2022, 'Detail': 'Paris RER E extension ends'},
#   {'Country': 'France',
#    'Year': 2023,
#    'Detail': 'Lyon Line B to Hospital-Sud ends'},
#   {'Country': 'France', 'Year': 2024, 'Detail': 'Paris Line 11 ends'},
#   {'Country': 'France', 'Year': 2025, 'Detail': 'Toulouse Line 3 ends'},
#   {'Country': 'France',
#    'Year': 2030,
#    'Detail': 'Paris Grand Paris Express ends, Paris Line 1 extension ends'},
#   {'Country': 'Germany',
#    'Year': 1965,
#    'Detail': 'Munich S-Bahn Stammstrecke starts'},
#   {'Country': 'Germany',
#    'Year': 1968,
#    'Detail': 'Berlin Extension to Rathaus Steglitz starts'},
#   {'Country': 'Germany',
#    'Year': 1971,
#    'Detail': 'Munich S-Bahn Stammstrecke ends'},
#   {'Country': 'Germany',
#    'Year': 1974,
#    'Detail': 'Berlin Extension to Rathaus Steglitz ends'},
#   {'Country': 'Germany',
#    'Year': 1978,
#    'Detail': 'Berlin Extension to Rathaus Spandau starts'},
#   {'Country': 'Germany',
#    'Year': 1984,
#    'Detail': 'Berlin Extension to Rathaus Spandau ends'},
#   {'Country': 'Germany',
#    'Year': 1985,
#    'Detail': 'Berlin U8 to Wittenau starts'},
#   {'Country': 'Germany', 'Year': 1994, 'Detail': 'Berlin U8 to Wittenau ends'},
#   {'Country': 'Germany', 'Year': 1997, 'Detail': 'Berlin U2 to Pankow starts'},
#   {'Country': 'Germany', 'Year': 2000, 'Detail': 'Berlin U2 to Pankow ends'},
#   {'Country': 'Germany',
#    'Year': 2003,
#    'Detail': 'Leipzig City Tunnel starts, Cologne North-South Stadtbahn starts'},
#   {'Country': 'Germany',
#    'Year': 2004,
#    'Detail': 'Berlin U55 starts, Munich U3 to Moosach starts'},
#   {'Country': 'Germany',
#    'Year': 2007,
#    'Detail': 'Dusseldorf Wehrhahn Line starts, Hamburg U4 to HafenCity U starts'},
#   {'Country': 'Germany', 'Year': 2009, 'Detail': 'Berlin U55 ends'},
#   {'Country': 'Germany',
#    'Year': 2010,
#    'Detail': 'Berlin U5-U55 connection starts, Karlsruhe Kombilösung starts, Munich U3 to Moosach ends'},
#   {'Country': 'Germany',
#    'Year': 2012,
#    'Detail': 'Hamburg U4 to HafenCity U ends'},
#   {'Country': 'Germany', 'Year': 2013, 'Detail': 'Leipzig City Tunnel ends'},
#   {'Country': 'Germany',
#    'Year': 2014,
#    'Detail': 'Hamburg U4 to Elbbrücken starts, Nuremberg U3 extension to Grossreuth starts'},
#   {'Country': 'Germany',
#    'Year': 2015,
#    'Detail': 'Cologne North-South Stadtbahn ends'},
#   {'Country': 'Germany',
#    'Year': 2016,
#    'Detail': 'Munich Second Trunk Line starts, Dusseldorf Wehrhahn Line ends'},
#   {'Country': 'Germany',
#    'Year': 2018,
#    'Detail': 'Hamburg U4 to Elbbrücken ends'},
#   {'Country': 'Germany',
#    'Year': 2019,
#    'Detail': 'Frankfurt U-Bahn Europaviertel starts'},
#   {'Country': 'Germany',
#    'Year': 2020,
#    'Detail': 'Hamburg U4 to Dannerallee starts, Nuremberg U3 extension to Gebersdorf starts, Berlin U5-U55 connection ends, Nuremberg U3 extension to Grossreuth ends'},
#   {'Country': 'Germany',
#    'Year': 2021,
#    'Detail': 'Hamburg U5-East starts, Karlsruhe Kombilösung ends'},
#   {'Country': 'Germany', 'Year': 2022, 'Detail': 'Munich U5 to Pasing starts'},
#   {'Country': 'Germany',
#    'Year': 2025,
#    'Detail': 'Frankfurt U-Bahn Europaviertel ends'},
#   {'Country': 'Germany',
#    'Year': 2026,
#    'Detail': 'Nuremberg U3 extension to Gebersdorf ends'},
#   {'Country': 'Germany',
#    'Year': 2028,
#    'Detail': 'Munich Second Trunk Line ends'},
#   {'Country': 'Germany', 'Year': 2029, 'Detail': 'Munich U5 to Pasing ends'},
#   {'Country': 'Germany', 'Year': 2030, 'Detail': 'Hamburg U5-East ends'},
#   {'Country': 'Greece',
#    'Year': 2006,
#    'Detail': 'Thessaloniki Main line starts'},
#   {'Country': 'Greece',
#    'Year': 2012,
#    'Detail': 'Athens Line 3 to Piraeus starts'},
#   {'Country': 'Greece',
#    'Year': 2013,
#    'Detail': 'Thessaloniki Kalamaria Extension starts'},
#   {'Country': 'Greece', 'Year': 2019, 'Detail': 'Athens Line 4 starts'},
#   {'Country': 'Greece', 'Year': 2020, 'Detail': 'Thessaloniki Main line ends'},
#   {'Country': 'Greece',
#    'Year': 2021,
#    'Detail': 'Athens Line 3 to Piraeus ends, Thessaloniki Kalamaria Extension ends'},
#   {'Country': 'Greece', 'Year': 2027, 'Detail': 'Athens Line 4 ends'},
#   {'Country': 'Hong Kong',
#    'Year': 1975,
#    'Detail': 'Hong Kong Modified Initial System starts'},
#   {'Country': 'Hong Kong',
#    'Year': 1978,
#    'Detail': 'Hong Kong Tsuen Wan Extension starts'},
#   {'Country': 'Hong Kong',
#    'Year': 1980,
#    'Detail': 'Hong Kong Modified Initial System ends'},
#   {'Country': 'Hong Kong',
#    'Year': 1981,
#    'Detail': 'Hong Kong Island Line starts'},
#   {'Country': 'Hong Kong',
#    'Year': 1982,
#    'Detail': 'Hong Kong Tsuen Wan Extension ends'},
#   {'Country': 'Hong Kong',
#    'Year': 1986,
#    'Detail': 'Hong Kong Eastern Harbour Crossing starts, Hong Kong Island Line ends'},
#   {'Country': 'Hong Kong',
#    'Year': 1989,
#    'Detail': 'Hong Kong Eastern Harbour Crossing ends'},
#   {'Country': 'Hong Kong',
#    'Year': 1994,
#    'Detail': 'Hong Kong Airport Railway starts'},
#   {'Country': 'Hong Kong',
#    'Year': 1997,
#    'Detail': 'Hong Kong Quarry Bay Congestion Relief Works (Kwung Tong Extension) starts'},
#   {'Country': 'Hong Kong',
#    'Year': 1998,
#    'Detail': 'Hong Kong Airport Railway ends'},
#   {'Country': 'Hong Kong',
#    'Year': 1999,
#    'Detail': 'Hong Kong Tseung Kwan O Extension starts'},
#   {'Country': 'Hong Kong',
#    'Year': 2001,
#    'Detail': "Hong Kong Penny's Bay Rail Link (Disneyland Resort Line) starts, Hong Kong Quarry Bay Congestion Relief Works (Kwung Tong Extension) ends"},
#   {'Country': 'Hong Kong',
#    'Year': 2002,
#    'Detail': 'Hong Kong Tseung Kwan O Extension ends'},
#   {'Country': 'Hong Kong',
#    'Year': 2005,
#    'Detail': "Hong Kong Penny's Bay Rail Link (Disneyland Resort Line) ends"},
#   {'Country': 'Hong Kong',
#    'Year': 2009,
#    'Detail': 'Hong Kong West Island Line starts'},
#   {'Country': 'Hong Kong',
#    'Year': 2011,
#    'Detail': 'Hong Kong South Island Line (East) starts, Hong Kong Kwun Tong Line extension starts'},
#   {'Country': 'Hong Kong',
#    'Year': 2012,
#    'Detail': 'Hong Kong Sha Tin-Central Link starts'},
#   {'Country': 'Hong Kong',
#    'Year': 2016,
#    'Detail': 'Hong Kong West Island Line ends, Hong Kong South Island Line (East) ends, Hong Kong Kwun Tong Line extension ends'},
#   {'Country': 'Hong Kong',
#    'Year': 2022,
#    'Detail': 'Hong Kong Sha Tin-Central Link ends'},
#   {'Country': 'Hong Kong',
#    'Year': 2023,
#    'Detail': 'Hong Kong Tung Chung Line extension starts, Hong Kong Tuen Mun South Extension starts'},
#   {'Country': 'Hong Kong',
#    'Year': 2029,
#    'Detail': 'Hong Kong Tung Chung Line extension ends'},
#   {'Country': 'Hong Kong',
#    'Year': 2030,
#    'Detail': 'Hong Kong Tuen Mun South Extension ends'},
#   {'Country': 'Hungary', 'Year': 2006, 'Detail': 'Budapest Line 4 starts'},
#   {'Country': 'Hungary', 'Year': 2014, 'Detail': 'Budapest Line 4 ends'},
#   {'Country': 'India', 'Year': 2006, 'Detail': 'Bangalore Phase 1 starts'},
#   {'Country': 'India',
#    'Year': 2009,
#    'Detail': 'Mumbai Monorail starts, Gurgaon Phase 1 starts, Chennai Phase 1 starts'},
#   {'Country': 'India', 'Year': 2011, 'Detail': 'Jaipur Phase 1 starts'},
#   {'Country': 'India',
#    'Year': 2012,
#    'Detail': 'Delhi Phase 3 starts, Hyderabad Phase 1 starts'},
#   {'Country': 'India',
#    'Year': 2013,
#    'Detail': 'Kochi Metro starts, Gurgaon Phase 2 starts, Gurgaon Phase 1 ends'},
#   {'Country': 'India',
#    'Year': 2014,
#    'Detail': 'Nagpur Phase 1 starts, Lucknow Line 1 starts'},
#   {'Country': 'India',
#    'Year': 2015,
#    'Detail': 'Ahmadabad Phase 1 starts, Delhi Noida Metro starts'},
#   {'Country': 'India',
#    'Year': 2016,
#    'Detail': 'Mumbai Line 3 starts, Mumbai Line 2A starts, Mumbai Line 7 starts, Chennai Phase 1 extension starts'},
#   {'Country': 'India',
#    'Year': 2017,
#    'Detail': 'Mumbai Line 5 starts, Mumbai Line 6 starts, Bangalore Phase 2 starts, Kochi Metro ends, Bangalore Phase 1 ends, Gurgaon Phase 2 ends'},
#   {'Country': 'India',
#    'Year': 2018,
#    'Detail': 'Mumbai Line 2B starts, Mumbai Line 4 starts'},
#   {'Country': 'India',
#    'Year': 2019,
#    'Detail': 'Mumbai Line 4A starts, Mumbai Line 7A + 9 starts, Delhi Phase 4 first half starts, Delhi Phase 4 second half starts, Kanpur Line 1 and 2 starts, Mumbai Monorail ends, Chennai Phase 1 ends, Delhi Noida Metro ends, Lucknow Line 1 ends'},
#   {'Country': 'India',
#    'Year': 2020,
#    'Detail': 'Mumbai Line 10 starts, Mumbai Line 11 starts, Mumbai Line 12 starts, Hyderabad Airport express starts, Chennai Phase 2 starts, Delhi Phase 3 ends, Nagpur Phase 1 ends, Hyderabad Phase 1 ends, Chennai Phase 1 extension ends, Jaipur Phase 1 ends'},
#   {'Country': 'India',
#    'Year': 2021,
#    'Detail': 'Surat Line 1 and 2 starts, Mumbai Line 2A ends, Mumbai Line 7 ends'},
#   {'Country': 'India',
#    'Year': 2022,
#    'Detail': 'Mumbai Line 3 ends, Mumbai Line 4 ends, Mumbai Line 4A ends, Mumbai Line 6 ends, Mumbai Line 7A + 9 ends, Kanpur Line 1 and 2 ends'},
#   {'Country': 'India',
#    'Year': 2023,
#    'Detail': 'Mumbai Line 2B ends, Ahmadabad Phase 1 ends, Surat Line 1 and 2 ends'},
#   {'Country': 'India',
#    'Year': 2024,
#    'Detail': 'Mumbai Line 5 ends, Mumbai Line 10 ends, Bangalore Phase 2 ends'},
#   {'Country': 'India',
#    'Year': 2025,
#    'Detail': 'Delhi Phase 4 first half ends, Delhi Phase 4 second half ends'},
#   {'Country': 'India',
#    'Year': 2026,
#    'Detail': 'Mumbai Line 11 ends, Mumbai Line 12 ends, Chennai Phase 2 ends'},
#   {'Country': 'Indonesia',
#    'Year': 2013,
#    'Detail': 'Jakarta MRT first phase starts'},
#   {'Country': 'Indonesia',
#    'Year': 2019,
#    'Detail': 'Jakarta MRT first phase ends'},
#   {'Country': 'Iran',
#    'Year': 2012,
#    'Detail': 'Tehran Line 3 extension to SW starts'},
#   {'Country': 'Iran',
#    'Year': 2014,
#    'Detail': 'Tehran Line 3 extension to SW ends'},
#   {'Country': 'Iran', 'Year': 2019, 'Detail': 'Tehran Line 7 ends'},
#   {'Country': 'Iran', 'Year': 2020, 'Detail': 'Tehran Line 6 ends'},
#   {'Country': 'Israel', 'Year': 2015, 'Detail': 'Tel Aviv Red Line starts'},
#   {'Country': 'Israel', 'Year': 2018, 'Detail': 'Tel Aviv Green Line starts'},
#   {'Country': 'Israel', 'Year': 2022, 'Detail': 'Tel Aviv Red Line ends'},
#   {'Country': 'Israel', 'Year': 2024, 'Detail': 'Tel Aviv Green Line ends'},
#   {'Country': 'Italy', 'Year': 1984, 'Detail': 'Milan Tunnel Section starts'},
#   {'Country': 'Italy',
#    'Year': 1986,
#    'Detail': 'Naples Line 1 (Piscinola - Dante) starts'},
#   {'Country': 'Italy',
#    'Year': 1998,
#    'Detail': 'Genova Principe - De Ferrari starts'},
#   {'Country': 'Italy',
#    'Year': 1999,
#    'Detail': 'Naples Line 1 - city center starts, Naples Line 1/MCNE (Piscinola-Secondigliano) starts'},
#   {'Country': 'Italy',
#    'Year': 2000,
#    'Detail': 'Turin Line 1 phases 1-3 starts'},
#   {'Country': 'Italy',
#    'Year': 2001,
#    'Detail': 'Catania Galatea-Stesicoro starts, Naples MCNE (Piscinola- Aversa) starts'},
#   {'Country': 'Italy',
#    'Year': 2002,
#    'Detail': 'Naples Line 6 (Mostra-Municipio) starts'},
#   {'Country': 'Italy',
#    'Year': 2003,
#    'Detail': 'Brescia Metro starts, Milan M1 (Molino Dorino-Rho MilanoFiera) starts, Naples Line 1 (Piscinola - Dante) ends'},
#   {'Country': 'Italy', 'Year': 2004, 'Detail': 'Milan Tunnel Section ends'},
#   {'Country': 'Italy',
#    'Year': 2005,
#    'Detail': 'Rome Line B1 extension starts, Milan M1 (Molino Dorino-Rho MilanoFiera) ends'},
#   {'Country': 'Italy',
#    'Year': 2006,
#    'Detail': 'Genova De Ferrari - Brignole starts, Genova Principe - De Ferrari ends'},
#   {'Country': 'Italy',
#    'Year': 2007,
#    'Detail': 'Milan M5 phase 1 starts, Rome Line C - section T6a starts, Rome Line C - section T4-5 starts, Catania Borgo-Nesima starts'},
#   {'Country': 'Italy',
#    'Year': 2009,
#    'Detail': 'Naples MCNE (Piscinola- Aversa) ends'},
#   {'Country': 'Italy',
#    'Year': 2010,
#    'Detail': 'Milan M5 phase 2 starts, Milan M1 (Sesto FS - Monza Bettola) starts'},
#   {'Country': 'Italy',
#    'Year': 2011,
#    'Detail': 'Turin Line 1 phases 1-3 ends, Milan M2 (Famagosta-Assago) ends, Milan M3 (Maciachini-Comasina) ends'},
#   {'Country': 'Italy',
#    'Year': 2012,
#    'Detail': 'Turin Line 1 south (phase 4) starts, Genova De Ferrari - Brignole ends'},
#   {'Country': 'Italy',
#    'Year': 2013,
#    'Detail': 'Rome Line C - section T3 starts, Milan M5 phase 1 ends, Rome Line C - section T6a ends, Rome Line C - section T4-5 ends, Brescia Metro ends'},
#   {'Country': 'Italy',
#    'Year': 2014,
#    'Detail': 'Naples Line 1 airport extension starts'},
#   {'Country': 'Italy',
#    'Year': 2015,
# ...
#   {'Country': 'South Korea', 'Year': 2016, 'Detail': 'Incheon Line 2 ends'},
#   {'Country': 'South Korea',
#    'Year': 2017,
#    'Detail': 'Seoul Sillim Light Metro starts, Busan Line 1 extension ends, Seoul Ui Light Metro ends'},
#   {'Country': 'South Korea',
#    'Year': 2018,
#    'Detail': 'Seoul GTX A starts, Seoul Sinbundang Phase 2 ends'},
#   {'Country': 'South Korea',
#    'Year': 2019,
#    'Detail': 'Seoul Sin Ansan Line starts, Seoul Gimpo Urban Railway ends'},
#   {'Country': 'South Korea',
#    'Year': 2020,
#    'Detail': 'Seoul 2020s program starts, Incheon Line 2 Goyang Extension Project starts, Seoul Line 5 Hanam Line ends'},
#   {'Country': 'South Korea',
#    'Year': 2021,
#    'Detail': 'Seoul Line 9 Phase 4 starts, Seoul Line 7 extension ends'},
#   {'Country': 'South Korea',
#    'Year': 2022,
#    'Detail': 'Seoul Sinbundang Phase 3 Section 1 starts, Seoul Sinbundang Phase 3 Section 2 starts, Seoul Sinbundang Phase 3 Section 3 starts, Seoul Line 7 Extension 2 starts, Seoul Sillim Light Metro ends, Seoul Jinjeop Line ends'},
#   {'Country': 'South Korea',
#    'Year': 2025,
#    'Detail': 'Seoul GTX A ends, Seoul Sin Ansan Line ends'},
#   {'Country': 'South Korea',
#    'Year': 2028,
#    'Detail': 'Seoul 2020s program ends, Seoul Line 9 Phase 4 ends'},
#   {'Country': 'Spain',
#    'Year': 1995,
#    'Detail': 'Madrid 1995-98 program starts'},
#   {'Country': 'Spain', 'Year': 1998, 'Detail': 'Madrid 1995-98 program ends'},
#   {'Country': 'Spain',
#    'Year': 1999,
#    'Detail': 'Madrid 1999-2003 program starts'},
#   {'Country': 'Spain',
#    'Year': 2001,
#    'Detail': 'Barcelona L3 to Trinitat Nova starts'},
#   {'Country': 'Spain',
#    'Year': 2003,
#    'Detail': 'Madrid Chamartin-Atocha tunnel starts, Barcelona L9/10 starts, Seville Line 1 starts, Madrid 1999-2003 program ends'},
#   {'Country': 'Spain',
#    'Year': 2006,
#    'Detail': 'Barcelona Sabadell tunnel starts, Barcelona L2 to Badalona starts, Malaga Lines 1-2 starts'},
#   {'Country': 'Spain',
#    'Year': 2007,
#    'Detail': "Barcelona L5 to Vall d'Hebron starts, Bilbao Line 3 starts"},
#   {'Country': 'Spain',
#    'Year': 2008,
#    'Detail': 'Madrid Line 2 extension starts, Barcelona Terrassa tunnel starts, Madrid Chamartin-Atocha tunnel ends, Barcelona L3 to Trinitat Nova ends'},
#   {'Country': 'Spain',
#    'Year': 2009,
#    'Detail': 'Madrid Line 9 extension starts, Seville Line 1 ends'},
#   {'Country': 'Spain',
#    'Year': 2010,
#    'Detail': "Barcelona L2 to Badalona ends, Barcelona L5 to Vall d'Hebron ends"},
#   {'Country': 'Spain', 'Year': 2011, 'Detail': 'Madrid Line 2 extension ends'},
#   {'Country': 'Spain', 'Year': 2014, 'Detail': 'Malaga Lines 1-2 ends'},
#   {'Country': 'Spain',
#    'Year': 2015,
#    'Detail': 'Madrid Line 9 extension ends, Barcelona Terrassa tunnel ends'},
#   {'Country': 'Spain', 'Year': 2016, 'Detail': 'Bilbao Line 3 ends'},
#   {'Country': 'Spain',
#    'Year': 2017,
#    'Detail': 'Barcelona Sabadell tunnel ends'},
#   {'Country': 'Spain',
#    'Year': 2020,
#    'Detail': 'Madrid Eje Transversal starts'},
#   {'Country': 'Spain', 'Year': 2026, 'Detail': 'Barcelona L9/10 ends'},
#   {'Country': 'Spain', 'Year': 2028, 'Detail': 'Madrid Eje Transversal ends'},
#   {'Country': 'Sweden', 'Year': 2005, 'Detail': 'Malmo Citytunneln starts'},
#   {'Country': 'Sweden', 'Year': 2007, 'Detail': 'Stockholm Citybanan starts'},
#   {'Country': 'Sweden', 'Year': 2010, 'Detail': 'Malmo Citytunneln ends'},
#   {'Country': 'Sweden', 'Year': 2017, 'Detail': 'Stockholm Citybanan ends'},
#   {'Country': 'Sweden', 'Year': 2018, 'Detail': 'Gothenburg West Link starts'},
#   {'Country': 'Sweden',
#    'Year': 2020,
#    'Detail': 'Stockholm Arenastaden starts, Stockholm Nacka/Söderort starts, Stockholm Barkarby starts'},
#   {'Country': 'Sweden',
#    'Year': 2026,
#    'Detail': 'Stockholm Barkarby ends, Gothenburg West Link ends'},
#   {'Country': 'Sweden',
#    'Year': 2030,
#    'Detail': 'Stockholm Arenastaden ends, Stockholm Nacka/Söderort ends'},
#   {'Country': 'Switzerland',
#    'Year': 2007,
#    'Detail': 'Zurich Durchmesserlinie starts'},
#   {'Country': 'Switzerland',
#    'Year': 2008,
#    'Detail': 'Lucerne Zentralbahn starts'},
#   {'Country': 'Switzerland',
#    'Year': 2013,
#    'Detail': 'Geneva CEVA starts, Lucerne Zentralbahn ends'},
#   {'Country': 'Switzerland',
#    'Year': 2014,
#    'Detail': 'Zurich Durchmesserlinie ends'},
#   {'Country': 'Switzerland', 'Year': 2019, 'Detail': 'Geneva CEVA ends'},
#   {'Country': 'Taiwan',
#    'Year': 1988,
#    'Detail': 'Taipei System to 2012, ex-Neihu starts'},
#   {'Country': 'Taiwan',
#    'Year': 2001,
#    'Detail': 'Kaohsiung Red and Orange Lines starts'},
#   {'Country': 'Taiwan',
#    'Year': 2002,
#    'Detail': 'Taipei Neihu Line starts, Taipei Xinyi Line starts'},
#   {'Country': 'Taiwan', 'Year': 2006, 'Detail': 'Taipei Airport MRT starts'},
#   {'Country': 'Taiwan',
#    'Year': 2008,
#    'Detail': 'Kaohsiung Urban Railway Underground starts, Kaohsiung Red and Orange Lines ends'},
#   {'Country': 'Taiwan', 'Year': 2009, 'Detail': 'Taipei Neihu Line ends'},
#   {'Country': 'Taiwan', 'Year': 2010, 'Detail': 'Taichung Green Line starts'},
#   {'Country': 'Taiwan',
#    'Year': 2011,
#    'Detail': 'Taipei Circular Line first section starts'},
#   {'Country': 'Taiwan',
#    'Year': 2012,
#    'Detail': 'Taipei System to 2012, ex-Neihu ends'},
#   {'Country': 'Taiwan', 'Year': 2013, 'Detail': 'Taipei Xinyi Line ends'},
#   {'Country': 'Taiwan', 'Year': 2014, 'Detail': 'Taipei Danhai LRT starts'},
#   {'Country': 'Taiwan',
#    'Year': 2016,
#    'Detail': 'Taipei Sanying Line starts, Taipei Xinyi Line East Extension starts'},
#   {'Country': 'Taiwan', 'Year': 2017, 'Detail': 'Taipei Airport MRT ends'},
#   {'Country': 'Taiwan',
#    'Year': 2018,
#    'Detail': 'Kaohsiung Urban Railway Underground ends'},
#   {'Country': 'Taiwan',
#    'Year': 2019,
#    'Detail': 'Taipei Taoyuan MRT Green Line starts, Taipei Taoyuan MRT Brown Line starts, Taipei Taoyuan Underground starts, Tainan Underground Project starts'},
#   {'Country': 'Taiwan',
#    'Year': 2020,
#    'Detail': 'Taipei Circular Line first section ends, Taichung Green Line ends'},
#   {'Country': 'Taiwan',
#    'Year': 2021,
#    'Detail': 'Taipei Wanda Line Phase 2 starts'},
#   {'Country': 'Taiwan',
#    'Year': 2022,
#    'Detail': 'Taipei Xinyi Line East Extension ends'},
#   {'Country': 'Taiwan',
#    'Year': 2023,
#    'Detail': 'Taipei Keelung MRT starts, Taipei Sanying Line ends'},
#   {'Country': 'Taiwan',
#    'Year': 2024,
#    'Detail': 'Taipei Danhai LRT ends, Tainan Underground Project ends'},
#   {'Country': 'Taiwan',
#    'Year': 2026,
#    'Detail': 'Taipei Taoyuan MRT Green Line ends'},
#   {'Country': 'Taiwan',
#    'Year': 2028,
#    'Detail': 'Taipei Wanda Line Phase 2 ends'},
#   {'Country': 'Taiwan',
#    'Year': 2030,
#    'Detail': 'Taipei Taoyuan Underground ends'},
#   {'Country': 'Taiwan', 'Year': 2032, 'Detail': 'Taipei Keelung MRT ends'},
#   {'Country': 'Thailand',
#    'Year': 2011,
#    'Detail': 'Bangkok Blue Line extension starts'},
#   {'Country': 'Thailand',
#    'Year': 2012,
#    'Detail': 'Bangkok Sukhumvit Line to Kheka starts'},
#   {'Country': 'Thailand',
#    'Year': 2015,
#    'Detail': 'Bangkok Sukhumvit Line to Khu Khot starts'},
#   {'Country': 'Thailand',
#    'Year': 2017,
#    'Detail': 'Bangkok Pink Line starts, Bangkok Yellow Line starts, Bangkok Orange Line starts'},
#   {'Country': 'Thailand',
#    'Year': 2018,
#    'Detail': 'Bangkok Sukhumvit Line to Kheka ends'},
#   {'Country': 'Thailand',
#    'Year': 2020,
#    'Detail': 'Bangkok Brown Line starts, Bangkok Sukhumvit Line to Khu Khot ends, Bangkok Blue Line extension ends'},
#   {'Country': 'Thailand',
#    'Year': 2022,
#    'Detail': 'Chiang Mai Red Line starts, Bangkok Pink Line ends, Bangkok Yellow Line ends'},
#   {'Country': 'Thailand', 'Year': 2025, 'Detail': 'Bangkok Orange Line ends'},
#   {'Country': 'Thailand', 'Year': 2027, 'Detail': 'Chiang Mai Red Line ends'},
#   {'Country': 'Turkey',
#    'Year': 1987,
#    'Detail': 'Istanbul M1A-M1B (LR) starts'},
#   {'Country': 'Turkey', 'Year': 1992, 'Detail': 'Istanbul M2 starts'},
#   {'Country': 'Turkey', 'Year': 1995, 'Detail': 'Izmir M1 (Phase 1) starts'},
#   {'Country': 'Turkey', 'Year': 1996, 'Detail': 'Adana First stage starts'},
#   {'Country': 'Turkey', 'Year': 1997, 'Detail': 'Bursa Bursaray starts'},
#   {'Country': 'Turkey', 'Year': 2000, 'Detail': 'Izmir M1 (Phase 1) ends'},
#   {'Country': 'Turkey', 'Year': 2003, 'Detail': 'Ankara M4 starts'},
#   {'Country': 'Turkey', 'Year': 2004, 'Detail': 'Istanbul BC1 starts'},
#   {'Country': 'Turkey',
#    'Year': 2005,
#    'Detail': 'Istanbul M4 Phase 1 starts, Izmir M1  (Phase 2) starts'},
#   {'Country': 'Turkey', 'Year': 2006, 'Detail': 'Istanbul M3 Phase 1 starts'},
#   {'Country': 'Turkey',
#    'Year': 2010,
#    'Detail': 'Izmir M1 (Phase 3) starts, Adana First stage ends'},
#   {'Country': 'Turkey',
#    'Year': 2011,
#    'Detail': 'Istanbul M5 Phase 1 starts, Istanbul CR3 starts'},
#   {'Country': 'Turkey',
#    'Year': 2012,
#    'Detail': 'Istanbul M4 Phase 1 ends, Izmir M1 (Phase 3) ends'},
#   {'Country': 'Turkey',
#    'Year': 2013,
#    'Detail': 'Istanbul M4 Phase 2 starts, Istanbul M6 starts, Istanbul M3 Phase 1 ends, Istanbul BC1 ends'},
#   {'Country': 'Turkey',
#    'Year': 2014,
#    'Detail': 'Istanbul M7 Phase1-2 starts, Istanbul M2 ends, Izmir M1  (Phase 2) ends, Bursa Bursaray ends, Istanbul M1A-M1B (LR) ends'},
#   {'Country': 'Turkey',
#    'Year': 2015,
#    'Detail': 'Istanbul M4 Phase 3 starts, Istanbul M3 Phase 2 starts, Istanbul M6 ends'},
#   {'Country': 'Turkey',
#    'Year': 2016,
#    'Detail': 'Istanbul M8 starts, Istanbul M5 Phase 2-M13 starts, Istanbul M11 Phase 1 starts, Istanbul M9 starts, Istanbul M4 Phase 2 ends'},
#   {'Country': 'Turkey',
#    'Year': 2017,
#    'Detail': 'Istanbul M12  starts, Istanbul M3 Phase 3 starts, Istanbul M7 Phase 3 starts, Istanbul M1B starts, Istanbul M4 P4-M10 starts, Ankara M4 ends'},
#   {'Country': 'Turkey',
#    'Year': 2018,
#    'Detail': 'Istanbul M11 Phase 2 starts, Istanbul M5 Phase 1 ends'},
#   {'Country': 'Turkey', 'Year': 2019, 'Detail': 'Istanbul CR3 ends'},
#   {'Country': 'Turkey',
#    'Year': 2022,
#    'Detail': 'Istanbul M4 Phase 3 ends, Istanbul M8 ends, Istanbul M11 Phase 1 ends, Istanbul M11 Phase 2 ends, Istanbul M3 Phase 3 ends'},
#   {'Country': 'Turkey',
#    'Year': 2023,
#    'Detail': 'Istanbul M3 Phase 2 ends, Istanbul M12  ends, Istanbul M9 ends'},
#   {'Country': 'Turkey',
#    'Year': 2024,
#    'Detail': 'Istanbul M7 Phase1-2 ends, Istanbul M4 P4-M10 ends'},
#   {'Country': 'Turkey',
#    'Year': 2027,
#    'Detail': 'Istanbul M5 Phase 2-M13 ends, Istanbul M7 Phase 3 ends, Istanbul M1B ends'},
#   {'Country': 'Ukraine',
#    'Year': 2018,
#    'Detail': 'Kyiv M3 to Vynohradar starts, Kharkiv M3 extension starts'},
#   {'Country': 'Ukraine', 'Year': 2021, 'Detail': 'Kyiv M4 starts'},
#   {'Country': 'Ukraine', 'Year': 2022, 'Detail': 'Kyiv M3 to Vynohradar ends'},
#   {'Country': 'Ukraine', 'Year': 2024, 'Detail': 'Kharkiv M3 extension ends'},
#   {'Country': 'Ukraine', 'Year': 2026, 'Detail': 'Kyiv M4 ends'},
#   {'Country': 'United Arab Emirates',
#    'Year': 2005,
#    'Detail': 'Dubai Phase 1 - Red Line starts'},
#   {'Country': 'United Arab Emirates',
#    'Year': 2006,
#    'Detail': 'Dubai Phase 2 - Green Line starts'},
#   {'Country': 'United Arab Emirates',
#    'Year': 2010,
#    'Detail': 'Dubai Phase 1 - Red Line ends, Dubai Phase 2 - Green Line ends'},
#   {'Country': 'United Arab Emirates',
#    'Year': 2016,
#    'Detail': 'Dubai Phase 3 (Red Line Extension/Route 2020) starts'},
#   {'Country': 'United Arab Emirates',
#    'Year': 2020,
#    'Detail': 'Dubai Phase 3 (Red Line Extension/Route 2020) ends'},
#   {'Country': 'United Kingdom',
#    'Year': 1993,
#    'Detail': 'London Jubilee line extension starts'},
#   {'Country': 'United Kingdom',
#    'Year': 1999,
#    'Detail': 'London Jubilee line extension ends'},
#   {'Country': 'United Kingdom',
#    'Year': 2009,
#    'Detail': 'London Crossrail starts'},
#   {'Country': 'United Kingdom',
#    'Year': 2015,
#    'Detail': 'London Northern Line Extension starts'},
#   {'Country': 'United Kingdom',
#    'Year': 2021,
#    'Detail': 'London Northern Line Extension ends, London Crossrail ends'},
#   {'Country': 'United States',
#    'Year': 1976,
#    'Detail': 'Philadelphia Center City Commuter Connection starts'},
#   {'Country': 'United States',
#    'Year': 1984,
#    'Detail': 'Philadelphia Center City Commuter Connection ends'},
#   {'Country': 'United States',
#    'Year': 1987,
#    'Detail': 'Chicago Orange Line starts'},
#   {'Country': 'United States',
#    'Year': 1993,
#    'Detail': 'Chicago Orange Line ends'},
#   {'Country': 'United States',
#    'Year': 2007,
#    'Detail': 'New York 7 extension starts, New York Second Avenue Phase 1 starts, New York East Side Access starts'},
#   {'Country': 'United States',
#    'Year': 2009,
#    'Detail': 'Seattle U-Link starts, Miami Metrorail extension to MIA starts, Washington Silver Line Phase 1 starts'},
#   {'Country': 'United States',
#    'Year': 2010,
#    'Detail': 'San Francisco Central Subway starts'},
#   {'Country': 'United States', 'Year': 2011, 'Detail': 'Honolulu HART starts'},
#   {'Country': 'United States',
#    'Year': 2012,
#    'Detail': 'Miami Metrorail extension to MIA ends'},
#   {'Country': 'United States',
#    'Year': 2013,
#    'Detail': 'Boston Green Line Extension starts, Washington Silver Line Phase 2 starts'},
#   {'Country': 'United States',
#    'Year': 2014,
#    'Detail': 'Los Angeles Purple Phase 1 starts, Los Angeles Regional Connector starts, Los Angeles Crenshaw/LAX Line starts, New York 7 extension ends, Washington Silver Line Phase 1 ends'},
#   {'Country': 'United States',
#    'Year': 2016,
#    'Detail': 'Seattle U-Link ends, New York Second Avenue Phase 1 ends'},
#   {'Country': 'United States',
#    'Year': 2018,
#    'Detail': 'Los Angeles Purple Phase 2 starts'},
#   {'Country': 'United States',
#    'Year': 2019,
#    'Detail': 'New York Second Avenue Phase 2 starts, New York Gateway starts'},
#   {'Country': 'United States',
#    'Year': 2020,
#    'Detail': 'Los Angeles Purple Phase 3 starts'},
#   {'Country': 'United States',
#    'Year': 2021,
#    'Detail': 'San Francisco Central Subway ends'},
#   {'Country': 'United States',
#    'Year': 2022,
#    'Detail': 'San Francisco BART to San Jose starts, Los Angeles Regional Connector ends, Boston Green Line Extension ends, New York East Side Access ends, Los Angeles Crenshaw/LAX Line ends, Washington Silver Line Phase 2 ends'},
#   {'Country': 'United States',
#    'Year': 2024,
#    'Detail': 'Los Angeles Purple Phase 1 ends'},
#   {'Country': 'United States',
#    'Year': 2026,
#    'Detail': 'Seattle West Seattle and Ballard starts, Los Angeles Purple Phase 2 ends, New York Gateway ends, Honolulu HART ends'},
#   {'Country': 'United States',
#    'Year': 2027,
#    'Detail': 'Los Angeles Purple Phase 3 ends'},
#   {'Country': 'United States',
#    'Year': 2029,
#    'Detail': 'New York Second Avenue Phase 2 ends'},
#   {'Country': 'United States',
#    'Year': 2030,
#    'Detail': 'San Francisco BART to San Jose ends'},
#   {'Country': 'United States',
#    'Year': 2036,
#    'Detail': 'Seattle West Seattle and Ballard ends'},
#   {'Country': 'Uzbekistan',
#    'Year': 2017,
#    'Detail': 'Tashkent Sergeli Line starts, Tashkent Yunusabad Line extension starts'},
#   {'Country': 'Uzbekistan',
#    'Year': 2020,
#    'Detail': 'Tashkent Sergeli Line ends, Tashkent Yunusabad Line extension ends'},
#   {'Country': 'Vietnam', 'Year': 2010, 'Detail': 'Hanoi Line 3 starts'},
#   {'Country': 'Vietnam', 'Year': 2011, 'Detail': 'Hanoi Line 2 starts'},
#   {'Country': 'Vietnam',
#    'Year': 2012,
#    'Detail': 'Ho Chi Minh City Line 1 starts'},
#   {'Country': 'Vietnam', 'Year': 2013, 'Detail': 'Hanoi Line 3 ends'},
#   {'Country': 'Vietnam',
#    'Year': 2020,
#    'Detail': 'Ho Chi Minh City Line 2 first phase starts, Hanoi Line 2 ends'},
#   {'Country': 'Vietnam',
#    'Year': 2021,
#    'Detail': 'Ho Chi Minh City Line 1 ends'},
#   {'Country': 'Vietnam',
#    'Year': 2025,
#    'Detail': 'Ho Chi Minh City Line 5 first phase starts'},
#   {'Country': 'Vietnam',
#    'Year': 2026,
#    'Detail': 'Ho Chi Minh City Line 2 first phase ends'},
#   {'Country': 'Vietnam',
#    'Year': 2029,
#    'Detail': 'Ho Chi Minh City Line 5 first phase ends'}]}

# %%
#save the data on file
import json
import os
folder = r'C:\Users\elife\Documents\NYU\CCP\ANALYSIS\240226_update_charts'
file = "data_time.js"

# To export Np formats
def np_encoder(object):
    if isinstance(object, np.generic):
        return object.item()

with open(os.path.join(folder,file), "w") as outfile: 
    json_text = json.dumps(data_dict, indent=1 , default=np_encoder)
    test = "var data = " + json_text
    outfile.write( test )

print('done')
# Out:
# done

# %%
agg5_functions={'Country':'first','Start year':'first','Length':'sum','Real cost (2021 dollars)':'sum','Phase':'count'}
df_heat=df.groupby(['Country','Start year'], as_index=False).aggregate(agg5_functions)
df_heat['Start year'] = df_heat['Start year'].astype( pd.Int64Dtype() )
df_heat.sample(10)
# Out:
#        Country  Start year   Length  Real cost (2021 dollars)  Phase
# 51       China        2007  264.118              50360.239649      9
# 36      Canada        2022   16.000               3144.120000      1
# 214  Singapore        2002   35.500              12127.796587      1
# 278     Turkey        2018   32.000               3164.811836      1
# 147      Italy        1999    7.600               3143.689327      2
# 151      Italy        2003   15.800               1348.616251      2
# 260   Thailand        2020   22.100               4103.394013      1
# 59       China        2015  380.860              73522.354417     15
# 109    Germany        2022    3.800               1333.800000      1
# 4    Australia        2018    9.000               8683.236000      1

# %%
df_heat= df_heat.rename({'Phase': '# Projects starting'}, axis='columns')
df_heat['Mean Cost/km']=(df_heat['Real cost (2021 dollars)']/df_heat['Length']).round(2)

# %%
df_heat['Square Root of Cost/km']=df_heat['Mean Cost/km']**(1/2)
df_heat.sample(10)
# Out:
#                   Country  Start year  Length  Real cost (2021 dollars)  \
# 78                  Egypt        2006    4.30               3789.136606
# 281  United Arab Emirates        2005   35.00              10489.161290
# 247                Taiwan        2006   51.00               9106.627356
# 52                  China        2008   94.52              21953.816840
# 236                 Spain        2020   10.50                988.000000
# 83                 France        1991    2.50                590.906046
# 289         United States        2007    7.10              21100.692518
# 267                Turkey        2003    9.22               1366.928679
# 293         United States        2013   25.90               5768.186324
# 103               Germany        2010    7.00               2919.164794
#
#      # Projects starting  Mean Cost/km  Square Root of Cost/km
# 78                     1        881.19               29.684845
# 281                    1        299.69               17.311557
# 247                    1        178.56               13.362634
# 52                     3        232.27               15.240407
# 236                    1         94.10                9.700515
# 83                     1        236.36               15.374004
# 289                    3       2971.93               54.515411
# 267                    1        148.26               12.176206
# 293                    2        222.71               14.923471
# 103                    2        417.02               20.421068

# %%
#create json dictionary. This is the format the vega library reads data in. Add data-elif to the top because that is what our map jsons have at the top.
data_dict = df_heat.to_dict(
    orient= 'records'
)

data_dict = {
    "data-elif": data_dict
}

data_dict
# Out:
# {'data-elif': [{'Country': 'Argentina',
#    'Start year': 2020,
#    'Length': 20.0,
#    'Real cost (2021 dollars)': 4646.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 232.3,
#    'Square Root of Cost/km': 15.241391012633985},
#   {'Country': 'Australia',
#    'Start year': 2013,
#    'Length': 36.0,
#    'Real cost (2021 dollars)': 6076.325023853472,
#    '# Projects starting': 1,
#    'Mean Cost/km': 168.79,
#    'Square Root of Cost/km': 12.991920566259632},
#   {'Country': 'Australia',
#    'Start year': 2016,
#    'Length': 8.5,
#    'Real cost (2021 dollars)': 1384.9191699156136,
#    '# Projects starting': 1,
#    'Mean Cost/km': 162.93,
#    'Square Root of Cost/km': 12.764403628842203},
#   {'Country': 'Australia',
#    'Start year': 2017,
#    'Length': 30.0,
#    'Real cost (2021 dollars)': 10695.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 356.5,
#    'Square Root of Cost/km': 18.881207588499205},
#   {'Country': 'Australia',
#    'Start year': 2018,
#    'Length': 9.0,
#    'Real cost (2021 dollars)': 8683.235999999999,
#    '# Projects starting': 1,
#    'Mean Cost/km': 964.8,
#    'Square Root of Cost/km': 31.06122985330748},
#   {'Country': 'Austria',
#    'Start year': 1999,
#    'Length': 12.8,
#    'Real cost (2021 dollars)': 2254.614695340502,
#    '# Projects starting': 1,
#    'Mean Cost/km': 176.14,
#    'Square Root of Cost/km': 13.271774561075093},
#   {'Country': 'Austria',
#    'Start year': 2010,
#    'Length': 4.2,
#    'Real cost (2021 dollars)': 490.9689277594363,
#    '# Projects starting': 1,
#    'Mean Cost/km': 116.9,
#    'Square Root of Cost/km': 10.812030336620408},
#   {'Country': 'Austria',
#    'Start year': 2012,
#    'Length': 4.7,
#    'Real cost (2021 dollars)': 891.7360358117772,
#    '# Projects starting': 1,
#    'Mean Cost/km': 189.73,
#    'Square Root of Cost/km': 13.774251340817038},
#   {'Country': 'Austria',
#    'Start year': 2019,
#    'Length': 9.0,
#    'Real cost (2021 dollars)': 2860.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 317.78,
#    'Square Root of Cost/km': 17.826384939184948},
#   {'Country': 'Bahrain',
#    'Start year': 2018,
#    'Length': 28.6,
#    'Real cost (2021 dollars)': 2400.6659313063988,
#    '# Projects starting': 1,
#    'Mean Cost/km': 83.94,
#    'Square Root of Cost/km': 9.161877536837087},
#   {'Country': 'Bahrain',
#    'Start year': 2020,
#    'Length': 72.7,
#    'Real cost (2021 dollars)': 9319.968265032836,
#    '# Projects starting': 1,
#    'Mean Cost/km': 128.2,
#    'Square Root of Cost/km': 11.322543883774529},
#   {'Country': 'Bangladesh',
#    'Start year': 2015,
#    'Length': 21.3,
#    'Real cost (2021 dollars)': 11352.59550413249,
#    '# Projects starting': 1,
#    'Mean Cost/km': 532.99,
#    'Square Root of Cost/km': 23.086576186173644},
#   {'Country': 'Bangladesh',
#    'Start year': 2020,
#    'Length': 50.8,
#    'Real cost (2021 dollars)': 30015.68,
#    '# Projects starting': 2,
#    'Mean Cost/km': 590.86,
#    'Square Root of Cost/km': 24.307611976498226},
#   {'Country': 'Belgium',
#    'Start year': 2020,
#    'Length': 4.8,
#    'Real cost (2021 dollars)': 3380.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 704.17,
#    'Square Root of Cost/km': 26.53620168750607},
#   {'Country': 'Brazil',
#    'Start year': 2000,
#    'Length': 33.0,
#    'Real cost (2021 dollars)': 3512.3161755098135,
#    '# Projects starting': 1,
#    'Mean Cost/km': 106.43,
#    'Square Root of Cost/km': 10.316491651719591},
#   {'Country': 'Brazil',
#    'Start year': 2010,
#    'Length': 28.0,
#    'Real cost (2021 dollars)': 11412.409426156752,
#    '# Projects starting': 2,
#    'Mean Cost/km': 407.59,
#    'Square Root of Cost/km': 20.18885831343615},
#   {'Country': 'Brazil',
#    'Start year': 2012,
#    'Length': 7.7,
#    'Real cost (2021 dollars)': 3375.7361243630394,
#    '# Projects starting': 1,
#    'Mean Cost/km': 438.41,
#    'Square Root of Cost/km': 20.938242524147054},
#   {'Country': 'Brazil',
#    'Start year': 2015,
#    'Length': 15.9,
#    'Real cost (2021 dollars)': 4422.444486517189,
#    '# Projects starting': 1,
#    'Mean Cost/km': 278.14,
#    'Square Root of Cost/km': 16.67752979310785},
#   {'Country': 'Brazil',
#    'Start year': 2020,
#    'Length': 23.3,
#    'Real cost (2021 dollars)': 1584.6999999999998,
#    '# Projects starting': 1,
#    'Mean Cost/km': 68.01,
#    'Square Root of Cost/km': 8.246817568007675},
#   {'Country': 'Bulgaria',
#    'Start year': 2008,
#    'Length': 17.0,
#    'Real cost (2021 dollars)': 3927.608599625784,
#    '# Projects starting': 1,
#    'Mean Cost/km': 231.04,
#    'Square Root of Cost/km': 15.2},
#   {'Country': 'Bulgaria',
#    'Start year': 2009,
#    'Length': 5.1,
#    'Real cost (2021 dollars)': 854.7405028983379,
#    '# Projects starting': 1,
#    'Mean Cost/km': 167.6,
#    'Square Root of Cost/km': 12.946041866145807},
#   {'Country': 'Bulgaria',
#    'Start year': 2012,
#    'Length': 1.3,
#    'Real cost (2021 dollars)': 79.80209347120845,
#    '# Projects starting': 1,
#    'Mean Cost/km': 61.39,
#    'Square Root of Cost/km': 7.835177087979569},
#   {'Country': 'Bulgaria',
#    'Start year': 2013,
#    'Length': 3.0,
#    'Real cost (2021 dollars)': 167.2043863206272,
#    '# Projects starting': 1,
#    'Mean Cost/km': 55.73,
#    'Square Root of Cost/km': 7.465252842335616},
#   {'Country': 'Bulgaria',
#    'Start year': 2016,
#    'Length': 12.0,
#    'Real cost (2021 dollars)': 1791.3088842604948,
#    '# Projects starting': 1,
#    'Mean Cost/km': 149.28,
#    'Square Root of Cost/km': 12.218019479441011},
#   {'Country': 'Bulgaria',
#    'Start year': 2021,
#    'Length': 3.1,
#    'Real cost (2021 dollars)': 373.5,
#    '# Projects starting': 1,
#    'Mean Cost/km': 120.48,
#    'Square Root of Cost/km': 10.976338187209794},
#   {'Country': 'Canada',
#    'Start year': 1994,
#    'Length': 5.5,
#    'Real cost (2021 dollars)': 1346.538036809816,
#    '# Projects starting': 1,
#    'Mean Cost/km': 244.83,
#    'Square Root of Cost/km': 15.647044449352089},
#   {'Country': 'Canada',
#    'Start year': 1998,
#    'Length': 19.9,
#    'Real cost (2021 dollars)': 1529.5170731707321,
#    '# Projects starting': 1,
#    'Mean Cost/km': 76.86,
#    'Square Root of Cost/km': 8.766983517721474},
#   {'Country': 'Canada',
#    'Start year': 2001,
#    'Length': 5.2,
#    'Real cost (2021 dollars)': 865.6265034409741,
#    '# Projects starting': 1,
#    'Mean Cost/km': 166.47,
#    'Square Root of Cost/km': 12.902325371807983},
#   {'Country': 'Canada',
#    'Start year': 2005,
#    'Length': 18.4,
#    'Real cost (2021 dollars)': 2196.856256812416,
#    '# Projects starting': 1,
#    'Mean Cost/km': 119.39,
#    'Square Root of Cost/km': 10.92657311328671},
#   {'Country': 'Canada',
#    'Start year': 2009,
#    'Length': 8.6,
#    'Real cost (2021 dollars)': 3014.9522873319975,
#    '# Projects starting': 1,
#    'Mean Cost/km': 350.58,
#    'Square Root of Cost/km': 18.723781669310288},
#   {'Country': 'Canada',
#    'Start year': 2011,
#    'Length': 19.0,
#    'Real cost (2021 dollars)': 4966.5094351414755,
#    '# Projects starting': 1,
#    'Mean Cost/km': 261.4,
#    'Square Root of Cost/km': 16.167869371070513},
#   {'Country': 'Canada',
#    'Start year': 2012,
#    'Length': 10.9,
#    'Real cost (2021 dollars)': 1325.7998403284676,
#    '# Projects starting': 1,
#    'Mean Cost/km': 121.63,
#    'Square Root of Cost/km': 11.028599185753375},
#   {'Country': 'Canada',
#    'Start year': 2013,
#    'Length': 12.5,
#    'Real cost (2021 dollars)': 1967.8622290183205,
#    '# Projects starting': 1,
#    'Mean Cost/km': 157.43,
#    'Square Root of Cost/km': 12.547111221313056},
#   {'Country': 'Canada',
#    'Start year': 2016,
#    'Length': 13.1,
#    'Real cost (2021 dollars)': 1530.0668160856148,
#    '# Projects starting': 1,
#    'Mean Cost/km': 116.8,
#    'Square Root of Cost/km': 10.807404868885037},
#   {'Country': 'Canada',
#    'Start year': 2020,
#    'Length': 42.199999999999996,
#    'Real cost (2021 dollars)': 24187.345245967557,
#    '# Projects starting': 5,
#    'Mean Cost/km': 573.16,
#    'Square Root of Cost/km': 23.940760221847594},
#   {'Country': 'Canada',
#    'Start year': 2021,
#    'Length': 20.0,
#    'Real cost (2021 dollars)': 4620.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 231.0,
#    'Square Root of Cost/km': 15.198684153570664},
#   {'Country': 'Canada',
#    'Start year': 2022,
#    'Length': 16.0,
#    'Real cost (2021 dollars)': 3144.1200000000003,
#    '# Projects starting': 1,
#    'Mean Cost/km': 196.51,
#    'Square Root of Cost/km': 14.018202452525786},
#   {'Country': 'Chile',
#    'Start year': 2013,
#    'Length': 37.0,
#    'Real cost (2021 dollars)': 5757.944559950335,
#    '# Projects starting': 1,
#    'Mean Cost/km': 155.62,
#    'Square Root of Cost/km': 12.47477454706096},
#   {'Country': 'Chile',
#    'Start year': 2021,
#    'Length': 24.8,
#    'Real cost (2021 dollars)': 4930.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 198.79,
#    'Square Root of Cost/km': 14.099290762304323},
#   {'Country': 'China',
#    'Start year': 1990,
#    'Length': 16.1,
#    'Real cost (2021 dollars)': 3497.984445538058,
#    '# Projects starting': 1,
#    'Mean Cost/km': 217.27,
#    'Square Root of Cost/km': 14.740081410901366},
#   {'Country': 'China',
#    'Start year': 1995,
#    'Length': 16.3,
#    'Real cost (2021 dollars)': 8047.3111548556435,
#    '# Projects starting': 1,
#    'Mean Cost/km': 493.7,
#    'Square Root of Cost/km': 22.219360926903367},
#   {'Country': 'China',
#    'Start year': 1997,
#    'Length': 24.975,
#    'Real cost (2021 dollars)': 5565.600782944785,
#    '# Projects starting': 1,
#    'Mean Cost/km': 222.85,
#    'Square Root of Cost/km': 14.928161306738348},
#   {'Country': 'China',
#    'Start year': 1998,
#    'Length': 21.446,
#    'Real cost (2021 dollars)': 6475.1272727272735,
#    '# Projects starting': 1,
#    'Mean Cost/km': 301.93,
#    'Square Root of Cost/km': 17.376133056580798},
#   {'Country': 'China',
#    'Start year': 1999,
#    'Length': 43.57,
#    'Real cost (2021 dollars)': 4109.620459617648,
#    '# Projects starting': 2,
#    'Mean Cost/km': 94.32,
#    'Square Root of Cost/km': 9.711848433743187},
#   {'Country': 'China',
#    'Start year': 2000,
#    'Length': 104.17,
#    'Real cost (2021 dollars)': 19432.97718939394,
#    '# Projects starting': 5,
#    'Mean Cost/km': 186.55,
#    'Square Root of Cost/km': 13.658330791132569},
#   {'Country': 'China',
#    'Start year': 2001,
#    'Length': 6.155,
#    'Real cost (2021 dollars)': 1776.4229456167284,
#    '# Projects starting': 1,
#    'Mean Cost/km': 288.61,
#    'Square Root of Cost/km': 16.988525539316235},
#   {'Country': 'China',
#    'Start year': 2002,
#    'Length': 60.690000000000005,
#    'Real cost (2021 dollars)': 12834.60245080571,
#    '# Projects starting': 2,
#    'Mean Cost/km': 211.48,
#    'Square Root of Cost/km': 14.542351941828391},
#   {'Country': 'China',
#    'Start year': 2003,
#    'Length': 24.64,
#    'Real cost (2021 dollars)': 6688.963129032258,
#    '# Projects starting': 1,
#    'Mean Cost/km': 271.47,
#    'Square Root of Cost/km': 16.47634668244147},
#   {'Country': 'China',
#    'Start year': 2004,
#    'Length': 72.1,
#    'Real cost (2021 dollars)': 14991.286065103845,
#    '# Projects starting': 2,
#    'Mean Cost/km': 207.92,
#    'Square Root of Cost/km': 14.419431334140747},
#   {'Country': 'China',
#    'Start year': 2005,
#    'Length': 227.087,
#    'Real cost (2021 dollars)': 46170.768219816644,
#    '# Projects starting': 9,
#    'Mean Cost/km': 203.32,
#    'Square Root of Cost/km': 14.259032225224823},
#   {'Country': 'China',
#    'Start year': 2006,
#    'Length': 81.86,
#    'Real cost (2021 dollars)': 14971.902740214593,
#    '# Projects starting': 3,
#    'Mean Cost/km': 182.9,
#    'Square Root of Cost/km': 13.52405264704334},
#   {'Country': 'China',
#    'Start year': 2007,
#    'Length': 264.118,
#    'Real cost (2021 dollars)': 50360.23964884101,
#    '# Projects starting': 9,
#    'Mean Cost/km': 190.67,
#    'Square Root of Cost/km': 13.808330818748514},
#   {'Country': 'China',
#    'Start year': 2008,
#    'Length': 94.52,
#    'Real cost (2021 dollars)': 21953.816839907817,
#    '# Projects starting': 3,
#    'Mean Cost/km': 232.27,
#    'Square Root of Cost/km': 15.240406818717144},
#   {'Country': 'China',
#    'Start year': 2009,
#    'Length': 258.707,
#    'Real cost (2021 dollars)': 47868.4500187672,
#    '# Projects starting': 11,
#    'Mean Cost/km': 185.03,
#    'Square Root of Cost/km': 13.602573285963212},
#   {'Country': 'China',
#    'Start year': 2010,
#    'Length': 229.714,
#    'Real cost (2021 dollars)': 41096.515952060676,
#    '# Projects starting': 9,
#    'Mean Cost/km': 178.9,
#    'Square Root of Cost/km': 13.375350462698165},
#   {'Country': 'China',
#    'Start year': 2011,
#    'Length': 137.954,
#    'Real cost (2021 dollars)': 24826.928792025476,
#    '# Projects starting': 8,
#    'Mean Cost/km': 179.97,
#    'Square Root of Cost/km': 13.415289784421356},
#   {'Country': 'China',
#    'Start year': 2012,
#    'Length': 579.41,
#    'Real cost (2021 dollars)': 94450.37607146899,
#    '# Projects starting': 18,
#    'Mean Cost/km': 163.01,
#    'Square Root of Cost/km': 12.767536959022284},
#   {'Country': 'China',
#    'Start year': 2013,
#    'Length': 562.828,
#    'Real cost (2021 dollars)': 107088.36312568448,
#    '# Projects starting': 20,
#    'Mean Cost/km': 190.27,
#    'Square Root of Cost/km': 13.793839204514457},
#   {'Country': 'China',
#    'Start year': 2014,
#    'Length': 413.04100000000005,
#    'Real cost (2021 dollars)': 84191.68747727883,
#    '# Projects starting': 14,
#    'Mean Cost/km': 203.83,
#    'Square Root of Cost/km': 14.27690442638039},
#   {'Country': 'China',
#    'Start year': 2015,
#    'Length': 380.86,
#    'Real cost (2021 dollars)': 73522.35441732015,
#    '# Projects starting': 15,
#    'Mean Cost/km': 193.04,
#    'Square Root of Cost/km': 13.893883546366725},
#   {'Country': 'China',
#    'Start year': 2016,
#    'Length': 834.152,
#    'Real cost (2021 dollars)': 160518.45703306416,
#    '# Projects starting': 35,
#    'Mean Cost/km': 192.43,
#    'Square Root of Cost/km': 13.871914071244818},
#   {'Country': 'China',
#    'Start year': 2017,
#    'Length': 864.2800000000001,
#    'Real cost (2021 dollars)': 181595.79025053183,
#    '# Projects starting': 36,
#    'Mean Cost/km': 210.11,
#    'Square Root of Cost/km': 14.495171609884444},
#   {'Country': 'China',
#    'Start year': 2018,
#    'Length': 470.0040000000001,
#    'Real cost (2021 dollars)': 84475.03049794874,
#    '# Projects starting': 20,
#    'Mean Cost/km': 179.73,
#    'Square Root of Cost/km': 13.406341782902597},
#   {'Country': 'China',
#    'Start year': 2019,
#    'Length': 1132.3706,
#    'Real cost (2021 dollars)': 217405.30145618203,
#    '# Projects starting': 46,
#    'Mean Cost/km': 191.99,
#    'Square Root of Cost/km': 13.856045611934164},
#   {'Country': 'China',
#    'Start year': 2020,
#    'Length': 1389.1919999999996,
#    'Real cost (2021 dollars)': 232916.35848019453,
#    '# Projects starting': 48,
#    'Mean Cost/km': 167.66,
#    'Square Root of Cost/km': 12.948358969382953},
#   {'Country': 'China',
#    'Start year': 2021,
#    'Length': 2038.8370000000007,
#    'Real cost (2021 dollars)': 339768.8486311917,
#    '# Projects starting': 70,
#    'Mean Cost/km': 166.65,
#    'Square Root of Cost/km': 12.909298973995451},
#   {'Country': 'China',
#    'Start year': 2022,
#    'Length': 477.51599999999996,
#    'Real cost (2021 dollars)': 71196.62544155019,
#    '# Projects starting': 20,
#    'Mean Cost/km': 149.1,
#    'Square Root of Cost/km': 12.21065108829173},
#   {'Country': 'China',
#    'Start year': 2023,
#    'Length': 61.04,
#    'Real cost (2021 dollars)': 9644.480887986638,
#    '# Projects starting': 2,
#    'Mean Cost/km': 158.0,
#    'Square Root of Cost/km': 12.569805089976535},
#   {'Country': 'China',
#    'Start year': 2024,
#    'Length': 1.8,
#    'Real cost (2021 dollars)': 327.17525989900525,
#    '# Projects starting': 1,
#    'Mean Cost/km': 181.76,
#    'Square Root of Cost/km': 13.481839637082173},
#   {'Country': 'Czech Republic',
#    'Start year': 2004,
#    'Length': 4.6,
#    'Real cost (2021 dollars)': 1391.1406250000002,
#    '# Projects starting': 1,
#    'Mean Cost/km': 302.42,
#    'Square Root of Cost/km': 17.39022714055225},
#   {'Country': 'Czech Republic',
#    'Start year': 2010,
#    'Length': 6.1,
#    'Real cost (2021 dollars)': 1792.7919231338801,
#    '# Projects starting': 1,
#    'Mean Cost/km': 293.9,
#    'Square Root of Cost/km': 17.14351189225825},
#   {'Country': 'Czech Republic',
#    'Start year': 2021,
#    'Length': 10.5,
#    'Real cost (2021 dollars)': 5664.8,
#    '# Projects starting': 1,
#    'Mean Cost/km': 539.5,
#    'Square Root of Cost/km': 23.22713929867387},
#   {'Country': 'Denmark',
#    'Start year': 2009,
#    'Length': 15.5,
#    'Real cost (2021 dollars)': 3996.2855585969187,
#    '# Projects starting': 1,
#    'Mean Cost/km': 257.82,
#    'Square Root of Cost/km': 16.05677427131614},
#   {'Country': 'Dominican Republic',
#    'Start year': 2005,
#    'Length': 14.5,
#    'Real cost (2021 dollars)': 2080.1662216708337,
#    '# Projects starting': 1,
#    'Mean Cost/km': 143.46,
#    'Square Root of Cost/km': 11.977478866606278},
#   {'Country': 'Dominican Republic',
#    'Start year': 2009,
#    'Length': 16.5,
#    'Real cost (2021 dollars)': 2846.34160949328,
#    '# Projects starting': 1,
#    'Mean Cost/km': 172.51,
#    'Square Root of Cost/km': 13.134306224540373},
#   {'Country': 'Ecuador',
#    'Start year': 2012,
#    'Length': 22.9,
#    'Real cost (2021 dollars)': 4311.68436753928,
#    '# Projects starting': 1,
#    'Mean Cost/km': 188.28,
#    'Square Root of Cost/km': 13.721515951235126},
#   {'Country': 'Egypt',
#    'Start year': 1982,
#    'Length': 44.0,
#    'Real cost (2021 dollars)': 5802.240536971832,
#    '# Projects starting': 1,
#    'Mean Cost/km': 131.87,
#    'Square Root of Cost/km': 11.483466375620212},
#   {'Country': 'Egypt',
#    'Start year': 1993,
#    'Length': 22.0,
#    'Real cost (2021 dollars)': 13458.31541218638,
#    '# Projects starting': 1,
#    'Mean Cost/km': 611.74,
#    'Square Root of Cost/km': 24.733378256922364},
#   {'Country': 'Egypt',
#    'Start year': 2006,
#    'Length': 4.3,
#    'Real cost (2021 dollars)': 3789.136605806924,
#    '# Projects starting': 1,
#    'Mean Cost/km': 881.19,
#    'Square Root of Cost/km': 29.684844618087528},
#   {'Country': 'Egypt',
#    'Start year': 2017,
#    'Length': 21.0,
#    'Real cost (2021 dollars)': 13707.686031331594,
#    '# Projects starting': 1,
#    'Mean Cost/km': 652.75,
#    'Square Root of Cost/km': 25.548972582082435},
#   {'Country': 'Egypt',
#    'Start year': 2019,
#    'Length': 19.0,
#    'Real cost (2021 dollars)': 13736.260693037937,
#    '# Projects starting': 1,
#    'Mean Cost/km': 722.96,
#    'Square Root of Cost/km': 26.887915501206113},
#   {'Country': 'Finland',
#    'Start year': 2009,
#    'Length': 31.5,
#    'Real cost (2021 dollars)': 2957.9271192274455,
#    '# Projects starting': 2,
#    'Mean Cost/km': 93.9,
#    'Square Root of Cost/km': 9.690201236300513},
#   {'Country': 'Finland',
#    'Start year': 2014,
#    'Length': 7.0,
#    'Real cost (2021 dollars)': 1688.416533589267,
#    '# Projects starting': 1,
#    'Mean Cost/km': 241.2,
#    'Square Root of Cost/km': 15.53061492665374},
#   {'Country': 'France',
#    'Start year': 1991,
#    'Length': 2.5,
#    'Real cost (2021 dollars)': 590.9060461956523,
#    '# Projects starting': 1,
#    'Mean Cost/km': 236.36,
#    'Square Root of Cost/km': 15.374004032782091},
#   {'Country': 'France',
#    'Start year': 1993,
#    'Length': 9.2,
#    'Real cost (2021 dollars)': 2171.776495500265,
#    '# Projects starting': 1,
#    'Mean Cost/km': 236.06,
#    'Square Root of Cost/km': 15.36424420529692},
#   {'Country': 'France',
#    'Start year': 2005,
#    'Length': 2.9,
#    'Real cost (2021 dollars)': 354.5056423611112,
#    '# Projects starting': 2,
#    'Mean Cost/km': 122.24,
#    'Square Root of Cost/km': 11.056219968868202},
#   {'Country': 'France',
#    'Start year': 2007,
#    'Length': 2.8,
#    'Real cost (2021 dollars)': 628.3264394781608,
#    '# Projects starting': 2,
#    'Mean Cost/km': 224.4,
#    'Square Root of Cost/km': 14.979986648859205},
#   {'Country': 'France',
#    'Start year': 2008,
#    'Length': 1.5,
#    'Real cost (2021 dollars)': 299.34495404850134,
#    '# Projects starting': 1,
#    'Mean Cost/km': 199.56,
#    'Square Root of Cost/km': 14.126570709128242},
#   {'Country': 'France',
#    'Start year': 2009,
#    'Length': 1.8,
#    'Real cost (2021 dollars)': 347.65844073282096,
#    '# Projects starting': 1,
#    'Mean Cost/km': 193.14,
#    'Square Root of Cost/km': 13.897481786280563},
#   {'Country': 'France',
#    'Start year': 2012,
#    'Length': 1.7,
#    'Real cost (2021 dollars)': 294.18927951388895,
#    '# Projects starting': 1,
#    'Mean Cost/km': 173.05,
#    'Square Root of Cost/km': 13.154847015454038},
#   {'Country': 'France',
#    'Start year': 2014,
#    'Length': 15.8,
#    'Real cost (2021 dollars)': 2421.6527318695366,
#    '# Projects starting': 2,
#    'Mean Cost/km': 153.27,
#    'Square Root of Cost/km': 12.380226169178009},
#   {'Country': 'France',
#    'Start year': 2016,
#    'Length': 6.3,
#    'Real cost (2021 dollars)': 1612.9820728575294,
#    '# Projects starting': 1,
#    'Mean Cost/km': 256.03,
#    'Square Root of Cost/km': 16.00093747253579},
#   {'Country': 'France',
#    'Start year': 2017,
#    'Length': 202.5,
#    'Real cost (2021 dollars)': 55923.69543606078,
#    '# Projects starting': 2,
#    'Mean Cost/km': 276.17,
#    'Square Root of Cost/km': 16.61836333698358},
#   {'Country': 'France',
#    'Start year': 2018,
#    'Length': 8.0,
#    'Real cost (2021 dollars)': 2761.7002186468294,
#    '# Projects starting': 1,
#    'Mean Cost/km': 345.21,
#    'Square Root of Cost/km': 18.579827770999387},
#   {'Country': 'France',
#    'Start year': 2021,
#    'Length': 31.9,
#    'Real cost (2021 dollars)': 5909.16744789833,
#    '# Projects starting': 2,
#    'Mean Cost/km': 185.24,
#    'Square Root of Cost/km': 13.610290224679266},
#   {'Country': 'Germany',
#    'Start year': 1965,
#    'Length': 11.4,
#    'Real cost (2021 dollars)': 2476.2852,
#    '# Projects starting': 1,
#    'Mean Cost/km': 217.22,
#    'Square Root of Cost/km': 14.738385257551114},
#   {'Country': 'Germany',
#    'Start year': 1968,
#    'Length': 1.5,
#    'Real cost (2021 dollars)': 307.95408,
#    '# Projects starting': 1,
#    'Mean Cost/km': 205.3,
#    'Square Root of Cost/km': 14.328293687665674},
#   {'Country': 'Germany',
#    'Start year': 1978,
#    'Length': 4.9,
#    'Real cost (2021 dollars)': 1064.0626399999999,
#    '# Projects starting': 1,
#    'Mean Cost/km': 217.16,
#    'Square Root of Cost/km': 14.736349615830916},
#   {'Country': 'Germany',
#    'Start year': 1985,
#    'Length': 3.6,
#    'Real cost (2021 dollars)': 707.7586346793607,
#    '# Projects starting': 1,
#    'Mean Cost/km': 196.6,
#    'Square Root of Cost/km': 14.021412197064887},
#   {'Country': 'Germany',
#    'Start year': 1997,
#    'Length': 0.8,
#    'Real cost (2021 dollars)': 116.69996319018406,
#    '# Projects starting': 1,
#    'Mean Cost/km': 145.87,
#    'Square Root of Cost/km': 12.077665337307538},
#   {'Country': 'Germany',
#    'Start year': 2003,
#    'Length': 7.6,
#    'Real cost (2021 dollars)': 3278.310336473629,
#    '# Projects starting': 2,
#    'Mean Cost/km': 431.36,
#    'Square Root of Cost/km': 20.76920797719547},
#   {'Country': 'Germany',
#    'Start year': 2004,
#    'Length': 3.5,
#    'Real cost (2021 dollars)': 853.1912367007169,
#    '# Projects starting': 2,
#    'Mean Cost/km': 243.77,
#    'Square Root of Cost/km': 15.613135495473035},
#   {'Country': 'Germany',
#    'Start year': 2007,
#    'Length': 7.3,
#    'Real cost (2021 dollars)': 1961.11545400736,
#    '# Projects starting': 2,
#    'Mean Cost/km': 268.65,
#    'Square Root of Cost/km': 16.390546055577282},
#   {'Country': 'Germany',
#    'Start year': 2010,
#    'Length': 7.0,
#    'Real cost (2021 dollars)': 2919.1647939588956,
#    '# Projects starting': 2,
#    'Mean Cost/km': 417.02,
#    'Square Root of Cost/km': 20.421067552897423},
#   {'Country': 'Germany',
#    'Start year': 2014,
#    'Length': 2.4000000000000004,
#    'Real cost (2021 dollars)': 360.4122538155022,
#    '# Projects starting': 2,
#    'Mean Cost/km': 150.17,
#    'Square Root of Cost/km': 12.254386969571346},
#   {'Country': 'Germany',
#    'Start year': 2016,
#    'Length': 7.2,
#    'Real cost (2021 dollars)': 5440.266315960297,
#    '# Projects starting': 1,
#    'Mean Cost/km': 755.59,
#    'Square Root of Cost/km': 27.48799738067508},
#   {'Country': 'Germany',
#    'Start year': 2019,
#    'Length': 2.7,
#    'Real cost (2021 dollars)': 485.55,
#    '# Projects starting': 1,
#    'Mean Cost/km': 179.83,
#    'Square Root of Cost/km': 13.410070842467611},
#   {'Country': 'Germany',
#    'Start year': 2020,
#    'Length': 4.7,
#    'Real cost (2021 dollars)': 921.7,
#    '# Projects starting': 2,
#    'Mean Cost/km': 196.11,
#    'Square Root of Cost/km': 14.003928020380568},
#   {'Country': 'Germany',
#    'Start year': 2021,
#    'Length': 5.8,
#    'Real cost (2021 dollars)': 3718.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 641.03,
#    'Square Root of Cost/km': 25.318570259791528},
#   {'Country': 'Germany',
#    'Start year': 2022,
#    'Length': 3.8,
#    'Real cost (2021 dollars)': 1333.8000000000002,
#    '# Projects starting': 1,
#    'Mean Cost/km': 351.0,
#    'Square Root of Cost/km': 18.734993995195193},
#   {'Country': 'Greece',
#    'Start year': 2006,
#    'Length': 9.5,
#    'Real cost (2021 dollars)': 1654.6458164368753,
#    '# Projects starting': 1,
#    'Mean Cost/km': 174.17,
#    'Square Root of Cost/km': 13.197348218486924},
#   {'Country': 'Greece',
#    'Start year': 2012,
#    'Length': 7.6,
#    'Real cost (2021 dollars)': 1089.041827946685,
#    '# Projects starting': 1,
#    'Mean Cost/km': 143.29,
#    'Square Root of Cost/km': 11.970380110923797},
#   {'Country': 'Greece',
#    'Start year': 2013,
#    'Length': 4.8,
#    'Real cost (2021 dollars)': 814.8334978785902,
#    '# Projects starting': 1,
#    'Mean Cost/km': 169.76,
#    'Square Root of Cost/km': 13.029197979921864},
#   {'Country': 'Greece',
#    'Start year': 2019,
#    'Length': 12.8,
#    'Real cost (2021 dollars)': 1726.4,
#    '# Projects starting': 1,
#    'Mean Cost/km': 134.88,
#    'Square Root of Cost/km': 11.61378491276638},
#   {'Country': 'Hong Kong',
#    'Start year': 1975,
#    'Length': 15.6,
#    'Real cost (2021 dollars)': 23080.74570747525,
#    '# Projects starting': 1,
#    'Mean Cost/km': 1479.53,
#    'Square Root of Cost/km': 38.4646591041699},
#   {'Country': 'Hong Kong',
#    'Start year': 1978,
#    'Length': 10.5,
#    'Real cost (2021 dollars)': 7963.065105582526,
#    '# Projects starting': 1,
#    'Mean Cost/km': 758.39,
#    'Square Root of Cost/km': 27.538881604015803},
#   {'Country': 'Hong Kong',
#    'Start year': 1981,
#    'Length': 12.5,
#    'Real cost (2021 dollars)': 11678.49032421687,
#    '# Projects starting': 1,
#    'Mean Cost/km': 934.28,
#    'Square Root of Cost/km': 30.565994176535465},
#   {'Country': 'Hong Kong',
#    'Start year': 1986,
#    'Length': 4.6,
#    'Real cost (2021 dollars)': 1127.071091408451,
#    '# Projects starting': 1,
#    'Mean Cost/km': 245.02,
#    'Square Root of Cost/km': 15.653114706025763},
#   {'Country': 'Hong Kong',
#    'Start year': 1994,
#    'Length': 34.0,
#    'Real cost (2021 dollars)': 10986.2878138942,
#    '# Projects starting': 1,
#    'Mean Cost/km': 323.13,
#    'Square Root of Cost/km': 17.975817088522014},
#   {'Country': 'Hong Kong',
#    'Start year': 1997,
#    'Length': 2.1,
#    'Real cost (2021 dollars)': 919.1673235294119,
#    '# Projects starting': 1,
#    'Mean Cost/km': 437.7,
#    'Square Root of Cost/km': 20.921281031523858},
#   {'Country': 'Hong Kong',
#    'Start year': 1999,
#    'Length': 4.0,
#    'Real cost (2021 dollars)': 4748.426666666667,
#    '# Projects starting': 1,
#    'Mean Cost/km': 1187.11,
#    'Square Root of Cost/km': 34.45446270078812},
#   {'Country': 'Hong Kong',
#    'Start year': 2001,
#    'Length': 3.5,
#    'Real cost (2021 dollars)': 622.9364673913044,
#    '# Projects starting': 1,
#    'Mean Cost/km': 177.98,
#    'Square Root of Cost/km': 13.340914511381893},
#   {'Country': 'Hong Kong',
#    'Start year': 2009,
#    'Length': 3.0,
#    'Real cost (2021 dollars)': 4004.3472956610376,
#    '# Projects starting': 1,
#    'Mean Cost/km': 1334.78,
#    'Square Root of Cost/km': 36.534641095814806},
#   {'Country': 'Hong Kong',
#    'Start year': 2011,
#    'Length': 9.6,
#    'Real cost (2021 dollars)': 5054.267410294604,
#    '# Projects starting': 2,
#    'Mean Cost/km': 526.49,
#    'Square Root of Cost/km': 22.945369903316006},
#   {'Country': 'Hong Kong',
#    'Start year': 2012,
#    'Length': 17.0,
#    'Real cost (2021 dollars)': 16058.68684073107,
#    '# Projects starting': 1,
#    'Mean Cost/km': 944.63,
#    'Square Root of Cost/km': 30.73483365824517},
#   {'Country': 'Hong Kong',
#    'Start year': 2023,
#    'Length': 4.2,
#    'Real cost (2021 dollars)': 5794.731998263356,
#    '# Projects starting': 2,
#    'Mean Cost/km': 1379.7,
#    'Square Root of Cost/km': 37.14431315827498},
#   {'Country': 'Hungary',
#    'Start year': 2006,
#    'Length': 7.4,
#    'Real cost (2021 dollars)': 4448.532692519353,
#    '# Projects starting': 1,
#    'Mean Cost/km': 601.15,
#    'Square Root of Cost/km': 24.518360467209057},
#   {'Country': 'India',
#    'Start year': 2006,
#    'Length': 42.3,
#    'Real cost (2021 dollars)': 11105.79590022184,
#    '# Projects starting': 1,
#    'Mean Cost/km': 262.55,
#    'Square Root of Cost/km': 16.203394706048485},
#   {'Country': 'India',
#    'Start year': 2009,
#    'Length': 70.8,
#    'Real cost (2021 dollars)': 15054.848908442917,
#    '# Projects starting': 3,
#    'Mean Cost/km': 212.64,
#    'Square Root of Cost/km': 14.582180906846547},
#   {'Country': 'India',
#    'Start year': 2011,
#    'Length': 12.1,
#    'Real cost (2021 dollars)': 2427.7786386531466,
#    '# Projects starting': 1,
#    'Mean Cost/km': 200.64,
#    'Square Root of Cost/km': 14.164744967700619},
#   {'Country': 'India',
#    'Start year': 2012,
#    'Length': 232.6,
#    'Real cost (2021 dollars)': 33801.95708875158,
#    '# Projects starting': 2,
#    'Mean Cost/km': 145.32,
#    'Square Root of Cost/km': 12.05487453273571},
#   {'Country': 'India',
#    'Start year': 2013,
#    'Length': 19.3,
#    'Real cost (2021 dollars)': 4520.507210875169,
#    '# Projects starting': 2,
#    'Mean Cost/km': 234.22,
#    'Square Root of Cost/km': 15.304247776352812},
#   {'Country': 'India',
#    'Start year': 2014,
#    'Length': 61.1,
#    'Real cost (2021 dollars)': 9275.89447749608,
#    '# Projects starting': 2,
#    'Mean Cost/km': 151.81,
#    'Square Root of Cost/km': 12.32112007895386},
#   {'Country': 'India',
#    'Start year': 2015,
#    'Length': 69.7,
#    'Real cost (2021 dollars)': 8587.495419082765,
#    '# Projects starting': 2,
#    'Mean Cost/km': 123.21,
#    'Square Root of Cost/km': 11.1},
#   {'Country': 'India',
#    'Start year': 2016,
#    'Length': 77.69999999999999,
#    'Real cost (2021 dollars)': 24429.318994179586,
#    '# Projects starting': 4,
#    'Mean Cost/km': 314.41,
#    'Square Root of Cost/km': 17.731610191970724},
#   {'Country': 'India',
#    'Start year': 2017,
#    'Length': 113.30000000000001,
#    'Real cost (2021 dollars)': 22388.610413203354,
#    '# Projects starting': 3,
#    'Mean Cost/km': 197.6,
#    'Square Root of Cost/km': 14.057026712644463},
#   {'Country': 'India',
#    'Start year': 2018,
#    'Length': 55.8,
#    'Real cost (2021 dollars)': 12565.28086711925,
#    '# Projects starting': 2,
#    'Mean Cost/km': 225.18,
#    'Square Root of Cost/km': 15.00599880047976},
#   {'Country': 'India',
#    'Start year': 2019,
#    'Length': 152.585,
#    'Real cost (2021 dollars)': 30257.44745385628,
#    '# Projects starting': 5,
#    'Mean Cost/km': 198.3,
#    'Square Root of Cost/km': 14.08190328045183},
#   {'Country': 'India',
#    'Start year': 2020,
#    'Length': 192.7,
#    'Real cost (2021 dollars)': 42905.87972922002,
#    '# Projects starting': 5,
#    'Mean Cost/km': 222.66,
#    'Square Root of Cost/km': 14.921796138535065},
#   {'Country': 'India',
#    'Start year': 2021,
#    'Length': 40.35,
#    'Real cost (2021 dollars)': 5192.7696000000005,
#    '# Projects starting': 1,
#    'Mean Cost/km': 128.69,
#    'Square Root of Cost/km': 11.344161493913951},
#   {'Country': 'Indonesia',
#    'Start year': 2013,
#    'Length': 15.7,
#    'Real cost (2021 dollars)': 3312.8536231139096,
#    '# Projects starting': 1,
#    'Mean Cost/km': 211.01,
#    'Square Root of Cost/km': 14.52618325645109},
#   {'Country': 'Iran',
#    'Start year': 2012,
#    'Length': 12.0,
#    'Real cost (2021 dollars)': 2791.622488270368,
#    '# Projects starting': 1,
#    'Mean Cost/km': 232.64,
#    'Square Root of Cost/km': 15.252540771950095},
#   {'Country': 'Israel',
#    'Start year': 2015,
#    'Length': 24.0,
#    'Real cost (2021 dollars)': 5089.9070754698205,
#    '# Projects starting': 1,
#    'Mean Cost/km': 212.08,
#    'Square Root of Cost/km': 14.562966730718024},
#   {'Country': 'Israel',
#    'Start year': 2018,
#    'Length': 38.6,
#    'Real cost (2021 dollars)': 5611.814026451736,
#    '# Projects starting': 1,
#    'Mean Cost/km': 145.38,
#    'Square Root of Cost/km': 12.057362895757928},
#   {'Country': 'Italy',
#    'Start year': 1984,
#    'Length': 7.8,
#    'Real cost (2021 dollars)': 2054.2945506692163,
#    '# Projects starting': 1,
#    'Mean Cost/km': 263.37,
#    'Square Root of Cost/km': 16.228678319567493},
#   {'Country': 'Italy',
#    'Start year': 1986,
#    'Length': 13.7,
#    'Real cost (2021 dollars)': 3972.706304514156,
#    '# Projects starting': 1,
#    'Mean Cost/km': 289.98,
#    'Square Root of Cost/km': 17.02879913558205},
#   {'Country': 'Italy',
#    'Start year': 1998,
#    'Length': 2.5,
#    'Real cost (2021 dollars)': 415.1157976653697,
#    '# Projects starting': 1,
#    'Mean Cost/km': 166.05,
#    'Square Root of Cost/km': 12.886038956948719},
#   {'Country': 'Italy',
#    'Start year': 1999,
#    'Length': 7.6,
#    'Real cost (2021 dollars)': 3143.6893269787647,
#    '# Projects starting': 2,
#    'Mean Cost/km': 413.64,
#    'Square Root of Cost/km': 20.33814150801395},
#   {'Country': 'Italy',
#    'Start year': 2000,
#    'Length': 13.2,
#    'Real cost (2021 dollars)': 1973.655017921147,
#    '# Projects starting': 1,
#    'Mean Cost/km': 149.52,
#    'Square Root of Cost/km': 12.227837094106219},
#   {'Country': 'Italy',
#    'Start year': 2001,
#    'Length': 12.5,
#    'Real cost (2021 dollars)': 1232.4692845185377,
#    '# Projects starting': 2,
#    'Mean Cost/km': 98.6,
#    'Square Root of Cost/km': 9.929753269845127},
#   {'Country': 'Italy',
#    'Start year': 2002,
#    'Length': 3.3,
#    'Real cost (2021 dollars)': 1237.1629197249033,
#    '# Projects starting': 1,
#    'Mean Cost/km': 374.9,
#    'Square Root of Cost/km': 19.362334569984064},
#   {'Country': 'Italy',
#    'Start year': 2003,
#    'Length': 15.799999999999999,
#    'Real cost (2021 dollars)': 1348.6162505211028,
#    '# Projects starting': 2,
#    'Mean Cost/km': 85.36,
#    'Square Root of Cost/km': 9.239047569960878},
#   {'Country': 'Italy',
#    'Start year': 2005,
#    'Length': 4.7,
#    'Real cost (2021 dollars)': 1167.5854813279095,
#    '# Projects starting': 1,
#    'Mean Cost/km': 248.42,
#    'Square Root of Cost/km': 15.761345120261785},
#   {'Country': 'Italy',
#    'Start year': 2006,
#    'Length': 1.5,
#    'Real cost (2021 dollars)': 328.3918391699334,
#    '# Projects starting': 1,
#    'Mean Cost/km': 218.93,
#    'Square Root of Cost/km': 14.796283317103658},
#   {'Country': 'Italy',
#    'Start year': 2007,
#    'Length': 19.6,
#    'Real cost (2021 dollars)': 3573.034345150976,
#    '# Projects starting': 4,
#    'Mean Cost/km': 182.3,
#    'Square Root of Cost/km': 13.501851724856113},
#   {'Country': 'Italy',
#    'Start year': 2010,
#    'Length': 8.4,
#    'Real cost (2021 dollars)': 1364.7731242039008,
#    '# Projects starting': 2,
#    'Mean Cost/km': 162.47,
#    'Square Root of Cost/km': 12.746372032857035},
#   {'Country': 'Italy',
#    'Start year': 2012,
#    'Length': 1.9,
#    'Real cost (2021 dollars)': 277.3974467411368,
#    '# Projects starting': 1,
#    'Mean Cost/km': 146.0,
#    'Square Root of Cost/km': 12.083045973594572},
#   {'Country': 'Italy',
#    'Start year': 2013,
#    'Length': 2.7,
#    'Real cost (2021 dollars)': 1207.8385747908262,
#    '# Projects starting': 1,
#    'Mean Cost/km': 447.35,
#    'Square Root of Cost/km': 21.150650108211806},
#   {'Country': 'Italy',
#    'Start year': 2014,
#    'Length': 3.5,
#    'Real cost (2021 dollars)': 898.3684076712157,
#    '# Projects starting': 1,
#    'Mean Cost/km': 256.68,
#    'Square Root of Cost/km': 16.021235907382426},
#   {'Country': 'Italy',
#    'Start year': 2015,
#    'Length': 16.9,
#    'Real cost (2021 dollars)': 2468.288058493581,
#    '# Projects starting': 2,
#    'Mean Cost/km': 146.05,
#    'Square Root of Cost/km': 12.085114811204733},
#   {'Country': 'Italy',
#    'Start year': 2017,
#    'Length': 6.4,
#    'Real cost (2021 dollars)': 570.2901306358696,
#    '# Projects starting': 1,
#    'Mean Cost/km': 89.11,
#    'Square Root of Cost/km': 9.439809320108113},
#   {'Country': 'Italy',
#    'Start year': 2018,
#    'Length': 3.4,
#    'Real cost (2021 dollars)': 462.76526113650516,
#    '# Projects starting': 1,
#    'Mean Cost/km': 136.11,
#    'Square Root of Cost/km': 11.666619047521866},
#   {'Country': 'Italy',
#    'Start year': 2019,
#    'Length': 2.1,
#    'Real cost (2021 dollars)': 161.20000000000002,
#    '# Projects starting': 1,
#    'Mean Cost/km': 76.76,
#    'Square Root of Cost/km': 8.761278445523804},
#   {'Country': 'Italy',
#    'Start year': 2020,
#    'Length': 1.5,
#    'Real cost (2021 dollars)': 81.9,
#    '# Projects starting': 1,
#    'Mean Cost/km': 54.6,
#    'Square Root of Cost/km': 7.389181280764467},
#   {'Country': 'Italy',
#    'Start year': 2022,
#    'Length': 27.400000000000002,
#    'Real cost (2021 dollars)': 2701.4,
#    '# Projects starting': 3,
#    'Mean Cost/km': 98.59,
#    'Square Root of Cost/km': 9.92924971989324},
#   {'Country': 'Italy',
#    'Start year': 2024,
#    'Length': 9.4,
#    'Real cost (2021 dollars)': 2488.0438157574454,
#    '# Projects starting': 1,
#    'Mean Cost/km': 264.69,
#    'Square Root of Cost/km': 16.269296235547497},
#   {'Country': 'Japan',
#    'Start year': 1988,
#    'Length': 12.0,
#    'Real cost (2021 dollars)': 1828.5103348017624,
#    '# Projects starting': 1,
#    'Mean Cost/km': 152.38,
#    'Square Root of Cost/km': 12.344229421069587},
#   {'Country': 'Japan',
#    'Start year': 1991,
#    'Length': 16.0,
#    'Real cost (2021 dollars)': 2583.8162992125986,
#    '# Projects starting': 1,
#    'Mean Cost/km': 161.49,
#    'Square Root of Cost/km': 12.707871576310488},
#   {'Country': 'Japan',
#    'Start year': 1992,
#    'Length': 27.8,
#    'Real cost (2021 dollars)': 10290.744470588237,
#    '# Projects starting': 1,
#    'Mean Cost/km': 370.17,
#    'Square Root of Cost/km': 19.239802493788755},
#   {'Country': 'Japan',
#    'Start year': 1993,
#    'Length': 4.1,
#    'Real cost (2021 dollars)': 2691.5799202453986,
#    '# Projects starting': 1,
#    'Mean Cost/km': 656.48,
#    'Square Root of Cost/km': 25.62186566196927},
#   {'Country': 'Japan',
#    'Start year': 1997,
#    'Length': 58.3,
#    'Real cost (2021 dollars)': 11185.17034782609,
#    '# Projects starting': 1,
#    'Mean Cost/km': 191.86,
#    'Square Root of Cost/km': 13.851353724455961},
#   {'Country': 'Japan',
#    'Start year': 1999,
#    'Length': 20.3,
#    'Real cost (2021 dollars)': 1318.6195388208096,
#    '# Projects starting': 1,
#    'Mean Cost/km': 64.96,
#    'Square Root of Cost/km': 8.059776671843954},
#   {'Country': 'Japan',
#    'Start year': 2001,
#    'Length': 8.9,
#    'Real cost (2021 dollars)': 2653.7559555320277,
#    '# Projects starting': 1,
#    'Mean Cost/km': 298.17,
#    'Square Root of Cost/km': 17.267599717389793},
#   {'Country': 'Japan',
#    'Start year': 2003,
#    'Length': 3.8,
#    'Real cost (2021 dollars)': 1370.979166666667,
#    '# Projects starting': 1,
#    'Mean Cost/km': 360.78,
#    'Square Root of Cost/km': 18.99420964399414},
#   {'Country': 'Japan',
#    'Start year': 2008,
#    'Length': 3.8,
#    'Real cost (2021 dollars)': 433.66957263969346,
#    '# Projects starting': 1,
#    'Mean Cost/km': 114.12,
#    'Square Root of Cost/km': 10.682696288858914},
#   {'Country': 'Japan',
#    'Start year': 2010,
#    'Length': 12.7,
#    'Real cost (2021 dollars)': 4355.8404176500135,
#    '# Projects starting': 2,
#    'Mean Cost/km': 342.98,
#    'Square Root of Cost/km': 18.51971922033377},
#   {'Country': 'Japan',
#    'Start year': 2014,
#    'Length': 1.6,
#    'Real cost (2021 dollars)': 633.4327199162111,
#    '# Projects starting': 1,
#    'Mean Cost/km': 395.9,
#    'Square Root of Cost/km': 19.897235988950825},
#   {'Country': 'Japan',
#    'Start year': 2015,
#    'Length': 5.4,
#    'Real cost (2021 dollars)': 1877.7720448583673,
#    '# Projects starting': 2,
#    'Mean Cost/km': 347.74,
#    'Square Root of Cost/km': 18.647788072583836},
#   {'Country': 'Japan',
#    'Start year': 2018,
#    'Length': 8.9,
#    'Real cost (2021 dollars)': 1112.891491334092,
#    '# Projects starting': 1,
#    'Mean Cost/km': 125.04,
#    'Square Root of Cost/km': 11.18212859879549},
#   {'Country': 'Japan',
#    'Start year': 2022,
#    'Length': 5.6,
#    'Real cost (2021 dollars)': 3000.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 535.71,
#    'Square Root of Cost/km': 23.145409912118645},
#   {'Country': 'Kuwait',
#    'Start year': 2020,
#    'Length': 160.0,
#    'Real cost (2021 dollars)': 31828.19895599492,
#    '# Projects starting': 1,
#    'Mean Cost/km': 198.93,
#    'Square Root of Cost/km': 14.104254677224175},
#   {'Country': 'Malaysia',
#    'Start year': 2012,
#    'Length': 51.0,
#    'Real cost (2021 dollars)': 16825.742599351175,
#    '# Projects starting': 1,
#    'Mean Cost/km': 329.92,
#    'Square Root of Cost/km': 18.163700063588365},
#   {'Country': 'Malaysia',
#    'Start year': 2016,
#    'Length': 52.2,
#    'Real cost (2021 dollars)': 22651.05148695322,
#    '# Projects starting': 1,
#    'Mean Cost/km': 433.93,
#    'Square Root of Cost/km': 20.83098653448751},
#   {'Country': 'Mexico',
#    'Start year': 2008,
#    'Length': 24.5,
#    'Real cost (2021 dollars)': 7739.028261547493,
#    '# Projects starting': 1,
#    'Mean Cost/km': 315.88,
#    'Square Root of Cost/km': 17.773013250431116},
#   {'Country': 'Mexico',
#    'Start year': 2014,
#    'Length': 21.5,
#    'Real cost (2021 dollars)': 3691.1261015013056,
#    '# Projects starting': 1,
#    'Mean Cost/km': 171.68,
#    'Square Root of Cost/km': 13.10267148332736},
#   {'Country': 'Netherlands',
#    'Start year': 2003,
#    'Length': 9.7,
#    'Real cost (2021 dollars)': 5090.073507133968,
#    '# Projects starting': 1,
#    'Mean Cost/km': 524.75,
#    'Square Root of Cost/km': 22.907422377910613},
#   {'Country': 'New Zealand',
#    'Start year': 2013,
#    'Length': 3.5,
#    'Real cost (2021 dollars)': 3228.308741333376,
#    '# Projects starting': 1,
#    'Mean Cost/km': 922.37,
#    'Square Root of Cost/km': 30.370544940781027},
#   {'Country': 'Norway',
#    'Start year': 2013,
#    'Length': 1.6,
#    'Real cost (2021 dollars)': 162.8892128784807,
#    '# Projects starting': 1,
#    'Mean Cost/km': 101.81,
#    'Square Root of Cost/km': 10.090094152187085},
#   {'Country': 'Norway',
#    'Start year': 2020,
#    'Length': 8.2,
#    'Real cost (2021 dollars)': 2719.2,
#    '# Projects starting': 1,
#    'Mean Cost/km': 331.61,
#    'Square Root of Cost/km': 18.210161998181125},
#   {'Country': 'Pakistan',
#    'Start year': 2015,
#    'Length': 27.1,
#    'Real cost (2021 dollars)': 6675.864188968669,
#    '# Projects starting': 1,
#    'Mean Cost/km': 246.34,
#    'Square Root of Cost/km': 15.695222202950807},
#   {'Country': 'Panama',
#    'Start year': 2010,
#    'Length': 13.7,
#    'Real cost (2021 dollars)': 4125.626062527767,
#    '# Projects starting': 1,
#    'Mean Cost/km': 301.14,
#    'Square Root of Cost/km': 17.353385836775484},
#   {'Country': 'Panama',
#    'Start year': 2015,
#    'Length': 21.0,
#    'Real cost (2021 dollars)': 4732.799694027414,
#    '# Projects starting': 1,
#    'Mean Cost/km': 225.37,
#    'Square Root of Cost/km': 15.012328267127655},
#   {'Country': 'Panama',
#    'Start year': 2020,
#    'Length': 26.7,
#    'Real cost (2021 dollars)': 5459.541221972792,
#    '# Projects starting': 1,
#    'Mean Cost/km': 204.48,
#    'Square Root of Cost/km': 14.299650345375582},
#   {'Country': 'Peru',
#    'Start year': 2014,
#    'Length': 35.0,
#    'Real cost (2021 dollars)': 11752.558107151377,
#    '# Projects starting': 1,
#    'Mean Cost/km': 335.79,
#    'Square Root of Cost/km': 18.324573664890544},
#   {'Country': 'Philippines',
#    'Start year': 2015,
#    'Length': 22.8,
#    'Real cost (2021 dollars)': 4112.9962725053465,
#    '# Projects starting': 1,
#    'Mean Cost/km': 180.39,
#    'Square Root of Cost/km': 13.430934442547175},
#   {'Country': 'Philippines',
#    'Start year': 2019,
#    'Length': 39.3,
#    'Real cost (2021 dollars)': 26282.8,
#    '# Projects starting': 2,
#    'Mean Cost/km': 668.77,
#    'Square Root of Cost/km': 25.860587773675988},
#   {'Country': 'Philippines',
#    'Start year': 2021,
#    'Length': 15.6,
#    'Real cost (2021 dollars)': 3261.5,
#    '# Projects starting': 1,
#    'Mean Cost/km': 209.07,
#    'Square Root of Cost/km': 14.459253092743069},
#   {'Country': 'Poland',
#    'Start year': 2010,
#    'Length': 6.5,
#    'Real cost (2021 dollars)': 3878.5365079226817,
#    '# Projects starting': 1,
#    'Mean Cost/km': 596.7,
#    'Square Root of Cost/km': 24.42744358298674},
#   {'Country': 'Poland',
#    'Start year': 2015,
#    'Length': 6.5,
#    'Real cost (2021 dollars)': 1412.2984699738902,
#    '# Projects starting': 2,
#    'Mean Cost/km': 217.28,
#    'Square Root of Cost/km': 14.740420618150623},
#   {'Country': 'Poland',
#    'Start year': 2018,
#    'Length': 9.25,
#    'Real cost (2021 dollars)': 1870.7023936386017,
#    '# Projects starting': 2,
#    'Mean Cost/km': 202.24,
#    'Square Root of Cost/km': 14.221111067704943},
#   {'Country': 'Portugal',
#    'Start year': 2019,
#    'Length': 6.0,
#    'Real cost (2021 dollars)': 400.40000000000003,
#    '# Projects starting': 1,
#    'Mean Cost/km': 66.73,
#    'Square Root of Cost/km': 8.16884324736373},
#   {'Country': 'Portugal',
#    'Start year': 2021,
#    'Length': 2.0,
#    'Real cost (2021 dollars)': 280.8,
#    '# Projects starting': 1,
#    'Mean Cost/km': 140.4,
#    'Square Root of Cost/km': 11.8490505948789},
#   {'Country': 'Qatar',
#    'Start year': 2013,
#    'Length': 124.0,
#    'Real cost (2021 dollars)': 104685.84331013881,
#    '# Projects starting': 1,
#    'Mean Cost/km': 844.24,
#    'Square Root of Cost/km': 29.05580836941213},
#   {'Country': 'Romania',
#    'Start year': 2014,
#    'Length': 6.9,
#    'Real cost (2021 dollars)': 2100.760105496923,
#    '# Projects starting': 1,
#    'Mean Cost/km': 304.46,
#    'Square Root of Cost/km': 17.448782192462602},
#   {'Country': 'Romania',
#    'Start year': 2023,
#    'Length': 21.0,
#    'Real cost (2021 dollars)': 4446.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 211.71,
#    'Square Root of Cost/km': 14.550257729676131},
#   {'Country': 'Russia',
#    'Start year': 2013,
#    'Length': 6.4,
#    'Real cost (2021 dollars)': 2064.505376926507,
#    '# Projects starting': 1,
#    'Mean Cost/km': 322.58,
#    'Square Root of Cost/km': 17.960512242138307},
#   {'Country': 'Russia',
#    'Start year': 2014,
#    'Length': 5.0,
#    'Real cost (2021 dollars)': 1712.7062544009136,
#    '# Projects starting': 1,
#    'Mean Cost/km': 342.54,
#    'Square Root of Cost/km': 18.50783617822462},
#   {'Country': 'Russia',
#    'Start year': 2015,
#    'Length': 2.5,
#    'Real cost (2021 dollars)': 509.1829404975689,
#    '# Projects starting': 1,
#    'Mean Cost/km': 203.67,
#    'Square Root of Cost/km': 14.271299870719554},
#   {'Country': 'Russia',
#    'Start year': 2016,
#    'Length': 11.6,
#    'Real cost (2021 dollars)': 1771.145609310772,
#    '# Projects starting': 1,
#    'Mean Cost/km': 152.68,
#    'Square Root of Cost/km': 12.35637487291479},
#   {'Country': 'Russia',
#    'Start year': 2017,
#    'Length': 66.7,
#    'Real cost (2021 dollars)': 21625.198819626694,
#    '# Projects starting': 1,
#    'Mean Cost/km': 324.22,
#    'Square Root of Cost/km': 18.006110074083185},
#   {'Country': 'Saudi Arabia',
#    'Start year': 2009,
#    'Length': 188.0,
#    'Real cost (2021 dollars)': 47459.76373041787,
#    '# Projects starting': 1,
#    'Mean Cost/km': 252.45,
#    'Square Root of Cost/km': 15.888675212238432},
#   {'Country': 'Saudi Arabia',
#    'Start year': 2014,
#    'Length': 336.6,
#    'Real cost (2021 dollars)': 80497.37556508962,
#    '# Projects starting': 6,
#    'Mean Cost/km': 239.15,
#    'Square Root of Cost/km': 15.464475419489663},
#   {'Country': 'Saudi Arabia',
#    'Start year': 2015,
#    'Length': 50.9,
#    'Real cost (2021 dollars)': 18589.20477770576,
#    '# Projects starting': 2,
#    'Mean Cost/km': 365.21,
#    'Square Root of Cost/km': 19.110468335443795},
#   {'Country': 'Serbia',
#    'Start year': 2021,
#    'Length': 42.0,
#    'Real cost (2021 dollars)': 12200.0,
#    '# Projects starting': 2,
#    'Mean Cost/km': 290.48,
#    'Square Root of Cost/km': 17.043473824311757},
#   {'Country': 'Singapore',
#    'Start year': 2002,
#    'Length': 35.5,
#    'Real cost (2021 dollars)': 12127.796587280916,
#    '# Projects starting': 1,
#    'Mean Cost/km': 341.63,
#    'Square Root of Cost/km': 18.48323564747255},
#   {'Country': 'Singapore',
#    'Start year': 2008,
#    'Length': 41.9,
#    'Real cost (2021 dollars)': 29245.69718720873,
#    '# Projects starting': 1,
#    'Mean Cost/km': 697.99,
#    'Square Root of Cost/km': 26.41950037377694},
#   {'Country': 'Singapore',
#    'Start year': 2014,
#    'Length': 43.0,
# ...
#    '# Projects starting': 2,
#    'Mean Cost/km': 124.93,
#    'Square Root of Cost/km': 11.177208953938367},
#   {'Country': 'Spain',
#    'Start year': 2009,
#    'Length': 3.0,
#    'Real cost (2021 dollars)': 293.04707875641355,
#    '# Projects starting': 1,
#    'Mean Cost/km': 97.68,
#    'Square Root of Cost/km': 9.88331928048467},
#   {'Country': 'Spain',
#    'Start year': 2020,
#    'Length': 10.5,
#    'Real cost (2021 dollars)': 988.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 94.1,
#    'Square Root of Cost/km': 9.70051545022222},
#   {'Country': 'Sweden',
#    'Start year': 2005,
#    'Length': 17.0,
#    'Real cost (2021 dollars)': 1370.4564031620555,
#    '# Projects starting': 1,
#    'Mean Cost/km': 80.62,
#    'Square Root of Cost/km': 8.978864070694021},
#   {'Country': 'Sweden',
#    'Start year': 2007,
#    'Length': 7.4,
#    'Real cost (2021 dollars)': 2469.9930549526866,
#    '# Projects starting': 1,
#    'Mean Cost/km': 333.78,
#    'Square Root of Cost/km': 18.269646958822165},
#   {'Country': 'Sweden',
#    'Start year': 2018,
#    'Length': 8.0,
#    'Real cost (2021 dollars)': 2829.2219990025033,
#    '# Projects starting': 1,
#    'Mean Cost/km': 353.65,
#    'Square Root of Cost/km': 18.805584277017292},
#   {'Country': 'Sweden',
#    'Start year': 2020,
#    'Length': 18.9,
#    'Real cost (2021 dollars)': 4058.638510251785,
#    '# Projects starting': 3,
#    'Mean Cost/km': 214.74,
#    'Square Root of Cost/km': 14.654009690183775},
#   {'Country': 'Switzerland',
#    'Start year': 2007,
#    'Length': 9.6,
#    'Real cost (2021 dollars)': 1715.371225740177,
#    '# Projects starting': 1,
#    'Mean Cost/km': 178.68,
#    'Square Root of Cost/km': 13.367123849205559},
#   {'Country': 'Switzerland',
#    'Start year': 2008,
#    'Length': 1.5,
#    'Real cost (2021 dollars)': 186.07130241772754,
#    '# Projects starting': 1,
#    'Mean Cost/km': 124.05,
#    'Square Root of Cost/km': 11.13777356566383},
#   {'Country': 'Switzerland',
#    'Start year': 2013,
#    'Length': 8.8,
#    'Real cost (2021 dollars)': 1203.026550058957,
#    '# Projects starting': 1,
#    'Mean Cost/km': 136.71,
#    'Square Root of Cost/km': 11.692305161943047},
#   {'Country': 'Taiwan',
#    'Start year': 1988,
#    'Length': 93.90000000000002,
#    'Real cost (2021 dollars)': 58228.32221073172,
#    '# Projects starting': 1,
#    'Mean Cost/km': 620.11,
#    'Square Root of Cost/km': 24.902007951167313},
#   {'Country': 'Taiwan',
#    'Start year': 2001,
#    'Length': 43.0,
#    'Real cost (2021 dollars)': 17268.52075383801,
#    '# Projects starting': 1,
#    'Mean Cost/km': 401.59,
#    'Square Root of Cost/km': 20.03971057675235},
#   {'Country': 'Taiwan',
#    'Start year': 2002,
#    'Length': 21.3,
#    'Real cost (2021 dollars)': 9254.063824233996,
#    '# Projects starting': 2,
#    'Mean Cost/km': 434.46,
#    'Square Root of Cost/km': 20.8437040854067},
#   {'Country': 'Taiwan',
#    'Start year': 2006,
#    'Length': 51.0,
#    'Real cost (2021 dollars)': 9106.627355860923,
#    '# Projects starting': 1,
#    'Mean Cost/km': 178.56,
#    'Square Root of Cost/km': 13.362634470792052},
#   {'Country': 'Taiwan',
#    'Start year': 2008,
#    'Length': 15.4,
#    'Real cost (2021 dollars)': 7713.448348665206,
#    '# Projects starting': 1,
#    'Mean Cost/km': 500.87,
#    'Square Root of Cost/km': 22.380125111357174},
#   {'Country': 'Taiwan',
#    'Start year': 2010,
#    'Length': 16.7,
#    'Real cost (2021 dollars)': 4504.38370874663,
#    '# Projects starting': 1,
#    'Mean Cost/km': 269.72,
#    'Square Root of Cost/km': 16.423154386414325},
#   {'Country': 'Taiwan',
#    'Start year': 2011,
#    'Length': 15.4,
#    'Real cost (2021 dollars)': 5311.5548157305175,
#    '# Projects starting': 1,
#    'Mean Cost/km': 344.91,
#    'Square Root of Cost/km': 18.571752744423453},
#   {'Country': 'Taiwan',
#    'Start year': 2014,
#    'Length': 14.0,
#    'Real cost (2021 dollars)': 1146.9825563421068,
#    '# Projects starting': 1,
#    'Mean Cost/km': 81.93,
#    'Square Root of Cost/km': 9.0515192095029},
#   {'Country': 'Taiwan',
#    'Start year': 2016,
#    'Length': 15.69,
#    'Real cost (2021 dollars)': 4166.326576624149,
#    '# Projects starting': 2,
#    'Mean Cost/km': 265.54,
#    'Square Root of Cost/km': 16.29539812339668},
#   {'Country': 'Taiwan',
#    'Start year': 2019,
#    'Length': 65.39999999999999,
#    'Real cost (2021 dollars)': 16845.735730527682,
#    '# Projects starting': 4,
#    'Mean Cost/km': 257.58,
#    'Square Root of Cost/km': 16.049299050114307},
#   {'Country': 'Taiwan',
#    'Start year': 2021,
#    'Length': 13.3,
#    'Real cost (2021 dollars)': 4074.731324893373,
#    '# Projects starting': 1,
#    'Mean Cost/km': 306.37,
#    'Square Root of Cost/km': 17.5034282356343},
#   {'Country': 'Taiwan',
#    'Start year': 2023,
#    'Length': 16.0,
#    'Real cost (2021 dollars)': 2822.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 176.38,
#    'Square Root of Cost/km': 13.2808132281122},
#   {'Country': 'Thailand',
#    'Start year': 2011,
#    'Length': 26.9,
#    'Real cost (2021 dollars)': 6638.456893767114,
#    '# Projects starting': 1,
#    'Mean Cost/km': 246.78,
#    'Square Root of Cost/km': 15.709232953903255},
#   {'Country': 'Thailand',
#    'Start year': 2012,
#    'Length': 12.8,
#    'Real cost (2021 dollars)': 2490.443029198136,
#    '# Projects starting': 1,
#    'Mean Cost/km': 194.57,
#    'Square Root of Cost/km': 13.948835076808386},
#   {'Country': 'Thailand',
#    'Start year': 2015,
#    'Length': 19.0,
#    'Real cost (2021 dollars)': 5270.629599135118,
#    '# Projects starting': 1,
#    'Mean Cost/km': 277.4,
#    'Square Root of Cost/km': 16.655329477377503},
#   {'Country': 'Thailand',
#    'Start year': 2017,
#    'Length': 100.80000000000001,
#    'Real cost (2021 dollars)': 28632.775709055495,
#    '# Projects starting': 3,
#    'Mean Cost/km': 284.06,
#    'Square Root of Cost/km': 16.854079624826745},
#   {'Country': 'Thailand',
#    'Start year': 2020,
#    'Length': 22.1,
#    'Real cost (2021 dollars)': 4103.394013469289,
#    '# Projects starting': 1,
#    'Mean Cost/km': 185.67,
#    'Square Root of Cost/km': 13.626077939010916},
#   {'Country': 'Thailand',
#    'Start year': 2022,
#    'Length': 15.8,
#    'Real cost (2021 dollars)': 2187.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 138.42,
#    'Square Root of Cost/km': 11.765202930676546},
#   {'Country': 'Turkey',
#    'Start year': 1987,
#    'Length': 26.6,
#    'Real cost (2021 dollars)': 3053.369268292684,
#    '# Projects starting': 1,
#    'Mean Cost/km': 114.79,
#    'Square Root of Cost/km': 10.714009520249643},
#   {'Country': 'Turkey',
#    'Start year': 1992,
#    'Length': 23.5,
#    'Real cost (2021 dollars)': 7392.76847826087,
#    '# Projects starting': 1,
#    'Mean Cost/km': 314.59,
#    'Square Root of Cost/km': 17.736685146892583},
#   {'Country': 'Turkey',
#    'Start year': 1995,
#    'Length': 11.6,
#    'Real cost (2021 dollars)': 1994.871165644172,
#    '# Projects starting': 1,
#    'Mean Cost/km': 171.97,
#    'Square Root of Cost/km': 13.113733259449806},
#   {'Country': 'Turkey',
#    'Start year': 1996,
#    'Length': 13.9,
#    'Real cost (2021 dollars)': 1435.4958333333336,
#    '# Projects starting': 1,
#    'Mean Cost/km': 103.27,
#    'Square Root of Cost/km': 10.16218480446011},
#   {'Country': 'Turkey',
#    'Start year': 1997,
#    'Length': 39.0,
#    'Real cost (2021 dollars)': 1199.6067708333335,
#    '# Projects starting': 1,
#    'Mean Cost/km': 30.76,
#    'Square Root of Cost/km': 5.546169849544819},
#   {'Country': 'Turkey',
#    'Start year': 2003,
#    'Length': 9.22,
#    'Real cost (2021 dollars)': 1366.9286788714826,
#    '# Projects starting': 1,
#    'Mean Cost/km': 148.26,
#    'Square Root of Cost/km': 12.17620630574236},
#   {'Country': 'Turkey',
#    'Start year': 2004,
#    'Length': 13.6,
#    'Real cost (2021 dollars)': 3914.304418352079,
#    '# Projects starting': 1,
#    'Mean Cost/km': 287.82,
#    'Square Root of Cost/km': 16.96525861871843},
#   {'Country': 'Turkey',
#    'Start year': 2005,
#    'Length': 27.049999999999997,
#    'Real cost (2021 dollars)': 3133.6494826100898,
#    '# Projects starting': 2,
#    'Mean Cost/km': 115.85,
#    'Square Root of Cost/km': 10.763363786474933},
#   {'Country': 'Turkey',
#    'Start year': 2006,
#    'Length': 16.1,
#    'Real cost (2021 dollars)': 2672.2213009502148,
#    '# Projects starting': 1,
#    'Mean Cost/km': 165.98,
#    'Square Root of Cost/km': 12.883322552819983},
#   {'Country': 'Turkey',
#    'Start year': 2010,
#    'Length': 2.25,
#    'Real cost (2021 dollars)': 127.69159638835418,
#    '# Projects starting': 1,
#    'Mean Cost/km': 56.75,
#    'Square Root of Cost/km': 7.533259586659682},
#   {'Country': 'Turkey',
#    'Start year': 2011,
#    'Length': 82.7,
#    'Real cost (2021 dollars)': 5690.1905095415095,
#    '# Projects starting': 2,
#    'Mean Cost/km': 68.81,
#    'Square Root of Cost/km': 8.295179322956196},
#   {'Country': 'Turkey',
#    'Start year': 2013,
#    'Length': 7.7,
#    'Real cost (2021 dollars)': 682.2875845527393,
#    '# Projects starting': 2,
#    'Mean Cost/km': 88.61,
#    'Square Root of Cost/km': 9.413288479590966},
#   {'Country': 'Turkey',
#    'Start year': 2014,
#    'Length': 23.75,
#    'Real cost (2021 dollars)': 2849.002217815276,
#    '# Projects starting': 1,
#    'Mean Cost/km': 119.96,
#    'Square Root of Cost/km': 10.952625256074453},
#   {'Country': 'Turkey',
#    'Start year': 2015,
#    'Length': 16.4,
#    'Real cost (2021 dollars)': 1609.1786478832319,
#    '# Projects starting': 2,
#    'Mean Cost/km': 98.12,
#    'Square Root of Cost/km': 9.905553997631834},
#   {'Country': 'Turkey',
#    'Start year': 2016,
#    'Length': 83.0,
#    'Real cost (2021 dollars)': 9037.271059825822,
#    '# Projects starting': 4,
#    'Mean Cost/km': 108.88,
#    'Square Root of Cost/km': 10.434557968596465},
#   {'Country': 'Turkey',
#    'Start year': 2017,
#    'Length': 61.400000000000006,
#    'Real cost (2021 dollars)': 10123.94283936927,
#    '# Projects starting': 5,
#    'Mean Cost/km': 164.89,
#    'Square Root of Cost/km': 12.840950120610234},
#   {'Country': 'Turkey',
#    'Start year': 2018,
#    'Length': 32.0,
#    'Real cost (2021 dollars)': 3164.8118356638633,
#    '# Projects starting': 1,
#    'Mean Cost/km': 98.9,
#    'Square Root of Cost/km': 9.944847912361455},
#   {'Country': 'Ukraine',
#    'Start year': 2018,
#    'Length': 7.2,
#    'Real cost (2021 dollars)': 2249.020853866335,
#    '# Projects starting': 2,
#    'Mean Cost/km': 312.36,
#    'Square Root of Cost/km': 17.6737092880923},
#   {'Country': 'Ukraine',
#    'Start year': 2021,
#    'Length': 20.0,
#    'Real cost (2021 dollars)': 6000.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 300.0,
#    'Square Root of Cost/km': 17.320508075688775},
#   {'Country': 'United Arab Emirates',
#    'Start year': 2005,
#    'Length': 35.0,
#    'Real cost (2021 dollars)': 10489.161290322581,
#    '# Projects starting': 1,
#    'Mean Cost/km': 299.69,
#    'Square Root of Cost/km': 17.311556833514427},
#   {'Country': 'United Arab Emirates',
#    'Start year': 2006,
#    'Length': 22.5,
#    'Real cost (2021 dollars)': 9193.625000000002,
#    '# Projects starting': 1,
#    'Mean Cost/km': 408.61,
#    'Square Root of Cost/km': 20.21410398706804},
#   {'Country': 'United Arab Emirates',
#    'Start year': 2016,
#    'Length': 15.0,
#    'Real cost (2021 dollars)': 6220.838142220852,
#    '# Projects starting': 1,
#    'Mean Cost/km': 414.72,
#    'Square Root of Cost/km': 20.364675298172568},
#   {'Country': 'United Kingdom',
#    'Start year': 1993,
#    'Length': 16.0,
#    'Real cost (2021 dollars)': 8462.415551306565,
#    '# Projects starting': 1,
#    'Mean Cost/km': 528.9,
#    'Square Root of Cost/km': 22.9978259842099},
#   {'Country': 'United Kingdom',
#    'Start year': 2009,
#    'Length': 21.0,
#    'Real cost (2021 dollars)': 21332.15517874245,
#    '# Projects starting': 1,
#    'Mean Cost/km': 1015.82,
#    'Square Root of Cost/km': 31.871931224825396},
#   {'Country': 'United Kingdom',
#    'Start year': 2015,
#    'Length': 3.2,
#    'Real cost (2021 dollars)': 1950.0288838120105,
#    '# Projects starting': 1,
#    'Mean Cost/km': 609.38,
#    'Square Root of Cost/km': 24.685623346393342},
#   {'Country': 'United States',
#    'Start year': 1976,
#    'Length': 2.9,
#    'Real cost (2021 dollars)': 1085.1953883495146,
#    '# Projects starting': 1,
#    'Mean Cost/km': 374.21,
#    'Square Root of Cost/km': 19.344508264621254},
#   {'Country': 'United States',
#    'Start year': 1987,
#    'Length': 14.4,
#    'Real cost (2021 dollars)': 1036.6105585309872,
#    '# Projects starting': 1,
#    'Mean Cost/km': 71.99,
#    'Square Root of Cost/km': 8.484692098125894},
#   {'Country': 'United States',
#    'Start year': 2007,
#    'Length': 7.1000000000000005,
#    'Real cost (2021 dollars)': 21100.69251828813,
#    '# Projects starting': 3,
#    'Mean Cost/km': 2971.93,
#    'Square Root of Cost/km': 54.51541066524217},
#   {'Country': 'United States',
#    'Start year': 2009,
#    'Length': 27.8,
#    'Real cost (2021 dollars)': 6293.472196733451,
#    '# Projects starting': 3,
#    'Mean Cost/km': 226.38,
#    'Square Root of Cost/km': 15.045929682143274},
#   {'Country': 'United States',
#    'Start year': 2010,
#    'Length': 2.7,
#    'Real cost (2021 dollars)': 1911.4959279535012,
#    '# Projects starting': 1,
#    'Mean Cost/km': 707.96,
#    'Square Root of Cost/km': 26.60751773465537},
#   {'Country': 'United States',
#    'Start year': 2011,
#    'Length': 32.0,
#    'Real cost (2021 dollars)': 12270.465857184388,
#    '# Projects starting': 1,
#    'Mean Cost/km': 383.45,
#    'Square Root of Cost/km': 19.581879378650047},
#   {'Country': 'United States',
#    'Start year': 2013,
#    'Length': 25.9,
#    'Real cost (2021 dollars)': 5768.186324046166,
#    '# Projects starting': 2,
#    'Mean Cost/km': 222.71,
#    'Square Root of Cost/km': 14.923471446014162},
#   {'Country': 'United States',
#    'Start year': 2014,
#    'Length': 23.1,
#    'Real cost (2021 dollars)': 7191.421213859481,
#    '# Projects starting': 3,
#    'Mean Cost/km': 311.32,
#    'Square Root of Cost/km': 17.644262523551387},
#   {'Country': 'United States',
#    'Start year': 2018,
#    'Length': 4.2,
#    'Real cost (2021 dollars)': 2400.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 571.43,
#    'Square Root of Cost/km': 23.90460206738443},
#   {'Country': 'United States',
#    'Start year': 2019,
#    'Length': 7.9,
#    'Real cost (2021 dollars)': 16449.0,
#    '# Projects starting': 2,
#    'Mean Cost/km': 2082.15,
#    'Square Root of Cost/km': 45.63058185033366},
#   {'Country': 'United States',
#    'Start year': 2020,
#    'Length': 4.2,
#    'Real cost (2021 dollars)': 3600.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 857.14,
#    'Square Root of Cost/km': 29.276953393411684},
#   {'Country': 'United States',
#    'Start year': 2022,
#    'Length': 9.6,
#    'Real cost (2021 dollars)': 9100.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 947.92,
#    'Square Root of Cost/km': 30.788309469667215},
#   {'Country': 'United States',
#    'Start year': 2026,
#    'Length': 19.0,
#    'Real cost (2021 dollars)': 12920.783003813596,
#    '# Projects starting': 1,
#    'Mean Cost/km': 680.04,
#    'Square Root of Cost/km': 26.077576574520876},
#   {'Country': 'Uzbekistan',
#    'Start year': 2017,
#    'Length': 9.84,
#    'Real cost (2021 dollars)': 1440.60081957094,
#    '# Projects starting': 2,
#    'Mean Cost/km': 146.4,
#    'Square Root of Cost/km': 12.09958676980334},
#   {'Country': 'Vietnam',
#    'Start year': 2010,
#    'Length': 12.5,
#    'Real cost (2021 dollars)': 5121.183632144063,
#    '# Projects starting': 1,
#    'Mean Cost/km': 409.69,
#    'Square Root of Cost/km': 20.24080037943164},
#   {'Country': 'Vietnam',
#    'Start year': 2011,
#    'Length': 11.5,
#    'Real cost (2021 dollars)': 2816.8912445098877,
#    '# Projects starting': 1,
#    'Mean Cost/km': 244.95,
#    'Square Root of Cost/km': 15.650878569588354},
#   {'Country': 'Vietnam',
#    'Start year': 2012,
#    'Length': 19.7,
#    'Real cost (2021 dollars)': 6202.322398930032,
#    '# Projects starting': 1,
#    'Mean Cost/km': 314.84,
#    'Square Root of Cost/km': 17.743731287415283},
#   {'Country': 'Vietnam',
#    'Start year': 2020,
#    'Length': 11.3,
#    'Real cost (2021 dollars)': 6048.0,
#    '# Projects starting': 1,
#    'Mean Cost/km': 535.22,
#    'Square Root of Cost/km': 23.13482223834884},
#   {'Country': 'Vietnam',
#    'Start year': 2025,
#    'Length': 8.9,
#    'Real cost (2021 dollars)': 5241.6,
#    '# Projects starting': 1,
#    'Mean Cost/km': 588.94,
#    'Square Root of Cost/km': 24.268086039076096}]}

# %%
#save the data on file
import json
import os
folder = r'C:\Users\elife\Documents\NYU\CCP\ANALYSIS\240226_update_charts'
file = "data_heat.js"

# To export Np formats
def np_encoder(object):
    if isinstance(object, np.generic):
        return object.item()

with open(os.path.join(folder,file), "w") as outfile: 
    json_text = json.dumps(data_dict, indent=1 , default=np_encoder)
    test = "var data = " + json_text
    outfile.write( test )

print('done')
# Out:
# done

# %%
len(df_gr_co)
# Out:
# 59

# %%
df_gr_co['GDP in $'].median()
# Out:
# 34287.0

# %%
df_gr_co[['Country','GDP in $']].sort_values(by=['GDP in $'])
# Out:
#                  Country  GDP in $
# 34              Pakistan      5426
# 4             Bangladesh      5995
# 22                 India      6525
# 57            Uzbekistan      7746
# 37           Philippines      8394
# 14               Ecuador     10890
# 58               Vietnam     10904
# 36                  Peru     11908
# 23             Indonesia     12072
# 15                 Egypt     12606
# 53               Ukraine     13087
# 6                 Brazil     14834
# 24                  Iran     15791
# 10                 China     17189
# 13    Dominican Republic     17934
# 51              Thailand     18198
# 30                Mexico     18671
# 44                Serbia     19094
# 0              Argentina     20769
# 7               Bulgaria     24564
# 9                  Chile     25089
# 35                Panama     26780
# 52                Turkey     27235
# 29              Malaysia     27921
# 19                Greece     27949
# 42                Russia     29916
# 41               Romania     32202
# 21               Hungary     33274
# 39              Portugal     34177
# 38                Poland     34287
# 47                 Spain     37756
# 25                Israel     39489
# 11        Czech Republic     41608
# 26                 Italy     41988
# 27                 Japan     42100
# 3                Bahrain     43821
# 32           New Zealand     44658
# 46           South Korea     45226
# 55        United Kingdom     46527
# 8                 Canada     46572
# 43          Saudi Arabia     46778
# 17                France     46991
# 28                Kuwait     47303
# 16               Finland     50937
# 5                Belgium     53070
# 1              Australia     53317
# 18               Germany     54845
# 48                Sweden     55065
# 2                Austria     55686
# 50                Taiwan     55724
# 20             Hong Kong     58980
# 31           Netherlands     59267
# 12               Denmark     60230
# 33                Norway     62645
# 56         United States     63028
# 54  United Arab Emirates     66766
# 49           Switzerland     71745
# 40                 Qatar     89961
# 45             Singapore     99681
